# %%
# !pip install owlready2
# Out:
# Requirement already satisfied: owlready2 in ./venv/lib/python3.10/site-packages (0.46)

# %%
from owlready2 import *

# %% [markdown]
# Load ontology

# %%
ONTOLOGY_NAME = './outputs/maintie_gold.owl'

# %%
onto = get_ontology(f"file://{ONTOLOGY_NAME}").load()

# %% [markdown]
# Setup inference/reasoning engine

# %%
# owlready2.JAVA_EXE = r"C:\Program Files\Java\jre-1.8\bin\java.exe"

# %%
# sync_reasoner(infer_property_values = True)

# %% [markdown]
# Setup helper functions

# %%
from IPython.core.magic import (register_line_magic, register_cell_magic, register_line_cell_magic)
from IPython.core.magic_arguments import (argument, magic_arguments, parse_argstring)

# %%
def query_helper(query: str):
    """SPARQL query helper function. Returns attributes of query results."""
    try:
        results = list(default_world.sparql(query))
        output = ""

        if results:
            print(f'Results found: {len(results)}\n')
            print(results, '\n')
            for idx, result in enumerate(results):
                output += f"Result {idx + 1}:\n"
                for x in result:
                    output += f"Type: {x.is_a}, Label: {x.label}, Comment: {x.comment}\n"
                output += "\n"
        else:
            output = "No results found.\n"
        
        return output
    except Exception as e:
        return f"An error occurred: {e}\n{results}\n"

# %%
# Define the magic function
@register_cell_magic
def sparql_query(line, cell):
    """Magic function for SPARQL queries."""
    cell = cell.replace('"""\n', "")
    cell = cell.replace('\n"""', "")

    formatted_query = cell.replace('ONTOLOGY_NAME', ONTOLOGY_NAME)
    result = query_helper(formatted_query)
    print(result)

# %% [markdown]
# **Find all of the instances of the `#AirConditioner` class**

# %%
# %%sparql_query
# """
# PREFIX rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#>
# PREFIX owl: <http://www.w3.org/2002/07/owl#>
#
# SELECT ?ac
# WHERE {
#   ?ac rdf:type <file://ONTOLOGY_NAME#AirConditioner> .
# }
# """
# Out:
# Results found: 46
#
# [[maintie_gold.TCUXM3KS], [maintie_gold.QX4WE50U], [maintie_gold.0LODB56W], [maintie_gold.U48IZ5BD], [maintie_gold.3DD9W9A5], [maintie_gold.Y2NCJ4Y3], [maintie_gold.ERPUW3N5], [maintie_gold.UOFD9X3K], [maintie_gold.FCUY8M3H], [maintie_gold.3GPX3SJP], [maintie_gold.8CTYN18B], [maintie_gold.F8RI1U4W], [maintie_gold.PFMJT40P], [maintie_gold.3EW26NSP], [maintie_gold.KK2ZQ1ZQ], [maintie_gold.ZZ9F7FA6], [maintie_gold.5X79W8W7], [maintie_gold.27HNVPOY], [maintie_gold.RCBMGRJB], [maintie_gold.UUDDQR42], [maintie_gold.P3ONI0BF], [maintie_gold.F7VQFHIA], [maintie_gold.60V6MH0C], [maintie_gold.BFEFUUYM], [maintie_gold.AAK8139A], [maintie_gold.VTHJB4MW], [maintie_gold.G796V4V1], [maintie_gold.IMHJVFWO], [maintie_gold.FFUEIVOM], [maintie_gold.WV0LDLD9], [maintie_gold.K8TCJN1Y], [maintie_gold.VWYBWN8Z], [maintie_gold.XBWH0XU5], [maintie_gold.Q5I1E8WO], [maintie_gold.HF45P16A], [maintie_gold.2PX672L9], [maintie_gold.B4LUUU0I], [maintie_gold.4EGCZY9B], [maintie_gold.D118UQ3Y], [maintie_gold.FCEY90TI], [maintie_gold.IEICRISP], [maintie_gold.U7HQAAM3], [maintie_gold.L3OVUK6R], [maintie_gold.0X3FDFS8], [maintie_gold.UEVPBVST], [maintie_gold.0JIT8NSN]]
#
# Result 1:
# Type: [maintie_gold.AirConditioner], Label: ['0_air_conditioner'], Comment: ['<id> air conditioner thermostat not working']
#
# Result 2:
# Type: [maintie_gold.AirConditioner], Label: ['1_air_conditioner'], Comment: ['<id> air conditioner thermostat unserviceable']
#
# Result 3:
# Type: [maintie_gold.AirConditioner], Label: ['2_air_conditioner'], Comment: ['<id> air conditioner unserviceable']
#
# Result 4:
# Type: [maintie_gold.AirConditioner], Label: ['3_air_conditioner'], Comment: ['<id> air conditioner unserviceable when stationary']
#
# Result 5:
# Type: [maintie_gold.AirConditioner], Label: ['4_air_conditioner'], Comment: ['<id> air conditioner warm']
#
# Result 6:
# Type: [maintie_gold.AirConditioner], Label: ['52_air_conditioner'], Comment: ['<id> bearing on air conditioner compressor unserviceable']
#
# Result 7:
# Type: [maintie_gold.AirConditioner], Label: ['64_air_conditioner'], Comment: ['<id> blown air conditioner hose']
#
# Result 8:
# Type: [maintie_gold.AirConditioner], Label: ['65_air_conditioner'], Comment: ['<id> blown air conditioner hose to radiator']
#
# Result 9:
# Type: [maintie_gold.AirConditioner], Label: ['97_air_conditioner'], Comment: ['<id> broken air conditioner guard']
#
# Result 10:
# Type: [maintie_gold.AirConditioner], Label: ['263_air_conditioner'], Comment: ['<id> dragline air conditioner units need cleaning']
#
# Result 11:
# Type: [maintie_gold.AirConditioner], Label: ['290_air_conditioner'], Comment: ['operator cabin air conditioner air outlet modifications']
#
# Result 12:
# Type: [maintie_gold.AirConditioner], Label: ['451_air_conditioner'], Comment: ['<id> repair air conditioner and wiring fault']
#
# Result 13:
# Type: [maintie_gold.AirConditioner], Label: ['518_air_conditioner'], Comment: ['<id> - air conditioner compressor']
#
# Result 14:
# Type: [maintie_gold.AirConditioner], Label: ['519_air_conditioner'], Comment: ['<id> - air conditioner compressor corroded']
#
# Result 15:
# Type: [maintie_gold.AirConditioner], Label: ['520_air_conditioner'], Comment: ['<id> - air conditioner compressor unserviceable']
#
# Result 16:
# Type: [maintie_gold.AirConditioner], Label: ['521_air_conditioner'], Comment: ['<id> - air conditioner fault']
#
# Result 17:
# Type: [maintie_gold.AirConditioner], Label: ['522_air_conditioner'], Comment: ['<id> - air conditioner no good']
#
# Result 18:
# Type: [maintie_gold.AirConditioner], Label: ['523_air_conditioner'], Comment: ['<id> - air conditioner system leaking']
#
# Result 19:
# Type: [maintie_gold.AirConditioner], Label: ['535_air_conditioner'], Comment: ['<id> - change out air conditioner belts']
#
# Result 20:
# Type: [maintie_gold.AirConditioner], Label: ['536_air_conditioner'], Comment: ['<id> - change out air conditioner compressor']
#
# Result 21:
# Type: [maintie_gold.AirConditioner], Label: ['537_air_conditioner'], Comment: ['<id> - change out air conditioner condenser']
#
# Result 22:
# Type: [maintie_gold.AirConditioner], Label: ['570_air_conditioner'], Comment: ['<id> - change out number <num> air conditioner compressor']
#
# Result 23:
# Type: [maintie_gold.AirConditioner], Label: ['575_air_conditioner'], Comment: ['<id> - change out right hand engine air conditioner compressor PO']
#
# Result 24:
# Type: [maintie_gold.AirConditioner], Label: ['675_air_conditioner'], Comment: ['<id> - repair / replace air conditioner blower fans']
#
# Result 25:
# Type: [maintie_gold.AirConditioner], Label: ['676_air_conditioner'], Comment: ['<id> - repair air conditioner']
#
# Result 26:
# Type: [maintie_gold.AirConditioner], Label: ['677_air_conditioner'], Comment: ['<id> - repair blown air conditioner hose']
#
# Result 27:
# Type: [maintie_gold.AirConditioner], Label: ['707_air_conditioner'], Comment: ['<id> - replace failed air conditioner compressor']
#
# Result 28:
# Type: [maintie_gold.AirConditioner], Label: ['790_air_conditioner'], Comment: ['<id> air conditioner accessory drive leaking oil']
#
# Result 29:
# Type: [maintie_gold.AirConditioner], Label: ['791_air_conditioner'], Comment: ['<id> air conditioner belt broken']
#
# Result 30:
# Type: [maintie_gold.AirConditioner], Label: ['792_air_conditioner'], Comment: ['<id> air conditioner compressor not working']
#
# Result 31:
# Type: [maintie_gold.AirConditioner], Label: ['793_air_conditioner'], Comment: ['<id> air conditioner compressor tripping out']
#
# Result 32:
# Type: [maintie_gold.AirConditioner], Label: ['794_air_conditioner'], Comment: ['<id> air conditioner drive leaking']
#
# Result 33:
# Type: [maintie_gold.AirConditioner], Label: ['795_air_conditioner'], Comment: ['<id> air conditioner drive leaking oil']
#
# Result 34:
# Type: [maintie_gold.AirConditioner], Label: ['796_air_conditioner'], Comment: ['<id> air conditioner fan unserviceable - fit new']
#
# Result 35:
# Type: [maintie_gold.AirConditioner], Label: ['797_air_conditioner'], Comment: ['<id> air conditioner fault']
#
# Result 36:
# Type: [maintie_gold.AirConditioner], Label: ['798_air_conditioner'], Comment: ['<id> air conditioner needs a boost not cold']
#
# Result 37:
# Type: [maintie_gold.AirConditioner], Label: ['799_air_conditioner'], Comment: ['<id> air conditioner not cold PO']
#
# Result 38:
# Type: [maintie_gold.AirConditioner], Label: ['800_air_conditioner'], Comment: ['<id> air conditioner not cold electrical faults']
#
# Result 39:
# Type: [maintie_gold.AirConditioner], Label: ['801_air_conditioner'], Comment: ['<id> air conditioner pressure switch unserviceable']
#
# Result 40:
# Type: [maintie_gold.AirConditioner], Label: ['806_air_conditioner'], Comment: ['air conditioner fan speed resistor not working <num> and <num>']
#
# Result 41:
# Type: [maintie_gold.AirConditioner], Label: ['821_air_conditioner'], Comment: ['blown air conditioner fuse']
#
# Result 42:
# Type: [maintie_gold.AirConditioner], Label: ['834_air_conditioner'], Comment: ['carry out <num> hour air conditioner service']
#
# Result 43:
# Type: [maintie_gold.AirConditioner], Label: ['984_air_conditioner'], Comment: ['repair earth terminal on air conditioner compressor']
#
# Result 44:
# Type: [maintie_gold.AirConditioner], Label: ['1002_air_conditioner'], Comment: ['replace air conditioner louver']
#
# Result 45:
# Type: [maintie_gold.AirConditioner], Label: ['1009_air_conditioner'], Comment: ['replace cabin air conditioner cover and louver']
#
# Result 46:
# Type: [maintie_gold.AirConditioner], Label: ['1028_air_conditioner'], Comment: ['replace seized air conditioner control cable']

# %% [markdown]
# **Get the types of Pumps in the ontology**

# %%
# %%sparql_query
# """
# PREFIX rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#>
# PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
# PREFIX owl: <http://www.w3.org/2002/07/owl#>
#
# SELECT ?subclass
# WHERE {
#   ?subclass rdfs:subClassOf* <file://ONTOLOGY_NAME#Pump> .
# }
# """
# Out:
# Results found: 11
#
# [[maintie_gold.Pump], [maintie_gold.LubePump], [maintie_gold.CoolantPump], [maintie_gold.HydraulicPump], [maintie_gold.GreasePump], [maintie_gold.ScavengePump], [maintie_gold.WaterPump], [maintie_gold.ImplementPump], [maintie_gold.OilPump], [maintie_gold.JacketWaterPump], [maintie_gold.AuxiliaryWaterPump]]
#
# Result 1:
# Type: [maintie_gold.LiquidFlowGeneratingObject], Label: [], Comment: []
#
# Result 2:
# Type: [maintie_gold.Pump], Label: [], Comment: []
#
# Result 3:
# Type: [maintie_gold.Pump], Label: [], Comment: []
#
# Result 4:
# Type: [maintie_gold.Pump], Label: [], Comment: []
#
# Result 5:
# Type: [maintie_gold.Pump], Label: [], Comment: []
#
# Result 6:
# Type: [maintie_gold.Pump], Label: [], Comment: []
#
# Result 7:
# Type: [maintie_gold.Pump], Label: [], Comment: []
#
# Result 8:
# Type: [maintie_gold.Pump], Label: [], Comment: []
#
# Result 9:
# Type: [maintie_gold.Pump], Label: [], Comment: []
#
# Result 10:
# Type: [maintie_gold.WaterPump], Label: [], Comment: []
#
# Result 11:
# Type: [maintie_gold.WaterPump], Label: [], Comment: []

# %% [markdown]
# **Find parts associated with the AirConditioner class**

# %%
# %%sparql_query
# """
# PREFIX rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#>
# PREFIX owl: <http://www.w3.org/2002/07/owl#>
#
# SELECT DISTINCT ?part
# WHERE {
#   ?ac rdf:type <file://ONTOLOGY_NAME#AirConditioner> .
#   ?ac <file://ONTOLOGY_NAME#has_part> ?part .
# }
# """
# Out:
# Results found: 33
#
# [[maintie_gold.BZ3GSDWE], [maintie_gold.EPJ6M2MY], [maintie_gold.WZFQ1Z9Q], [maintie_gold.SHWZAJEU], [maintie_gold.AQ1IB3ZH], [maintie_gold.W2RPEL9C], [maintie_gold.UMU0X7ZB], [maintie_gold.KQO961RC], [maintie_gold.BF49MVI3], [maintie_gold.BFJY988W], [maintie_gold.SIJ979KX], [maintie_gold.OBTSLC4V], [maintie_gold.YTAUTZ3S], [maintie_gold.E9OTZGTA], [maintie_gold.NSGO0LOH], [maintie_gold.FBLBOLFX], [maintie_gold.8EPI02YJ], [maintie_gold.9OA1PUIU], [maintie_gold.T6BNGN5B], [maintie_gold.YRETXKB0], [maintie_gold.DYIQ6HOU], [maintie_gold.3WJL5S9Y], [maintie_gold.0RBMS2F4], [maintie_gold.JSU0GAPG], [maintie_gold.P6KZJ40E], [maintie_gold.JU0NPE2Q], [maintie_gold.YC0LF837], [maintie_gold.EAFDAZ0B], [maintie_gold.JC3TENPR], [maintie_gold.DZ7FIA8D], [maintie_gold.N9GVBPCA], [maintie_gold.49C7DHM6], [maintie_gold.OYW9QRAZ]]
#
# Result 1:
# Type: [maintie_gold.Thermostat], Label: ['0_thermostat'], Comment: ['<id> air conditioner thermostat not working']
#
# Result 2:
# Type: [maintie_gold.Thermostat], Label: ['1_thermostat'], Comment: ['<id> air conditioner thermostat unserviceable']
#
# Result 3:
# Type: [maintie_gold.Compressor], Label: ['52_compressor'], Comment: ['<id> bearing on air conditioner compressor unserviceable']
#
# Result 4:
# Type: [maintie_gold.Hose], Label: ['64_hose'], Comment: ['<id> blown air conditioner hose']
#
# Result 5:
# Type: [maintie_gold.Hose], Label: ['65_hose'], Comment: ['<id> blown air conditioner hose to radiator']
#
# Result 6:
# Type: [maintie_gold.Guard], Label: ['97_guard'], Comment: ['<id> broken air conditioner guard']
#
# Result 7:
# Type: [maintie_gold.AirOutlet], Label: ['290_air_outlet'], Comment: ['operator cabin air conditioner air outlet modifications']
#
# Result 8:
# Type: [maintie_gold.Compressor], Label: ['518_compressor'], Comment: ['<id> - air conditioner compressor']
#
# Result 9:
# Type: [maintie_gold.Compressor], Label: ['519_compressor'], Comment: ['<id> - air conditioner compressor corroded']
#
# Result 10:
# Type: [maintie_gold.Compressor], Label: ['520_compressor'], Comment: ['<id> - air conditioner compressor unserviceable']
#
# Result 11:
# Type: [maintie_gold.Belts], Label: ['535_belts'], Comment: ['<id> - change out air conditioner belts']
#
# Result 12:
# Type: [maintie_gold.Compressor], Label: ['536_compressor'], Comment: ['<id> - change out air conditioner compressor']
#
# Result 13:
# Type: [maintie_gold.Condenser], Label: ['537_condenser'], Comment: ['<id> - change out air conditioner condenser']
#
# Result 14:
# Type: [maintie_gold.Compressor], Label: ['570_compressor'], Comment: ['<id> - change out number <num> air conditioner compressor']
#
# Result 15:
# Type: [maintie_gold.Compressor], Label: ['575_compressor'], Comment: ['<id> - change out right hand engine air conditioner compressor PO']
#
# Result 16:
# Type: [maintie_gold.Blower], Label: ['675_blower'], Comment: ['<id> - repair / replace air conditioner blower fans']
#
# Result 17:
# Type: [maintie_gold.Hose], Label: ['677_hose'], Comment: ['<id> - repair blown air conditioner hose']
#
# Result 18:
# Type: [maintie_gold.Compressor], Label: ['707_compressor'], Comment: ['<id> - replace failed air conditioner compressor']
#
# Result 19:
# Type: [maintie_gold.AccessoryDrive], Label: ['790_accessory_drive'], Comment: ['<id> air conditioner accessory drive leaking oil']
#
# Result 20:
# Type: [maintie_gold.Belt], Label: ['791_belt'], Comment: ['<id> air conditioner belt broken']
#
# Result 21:
# Type: [maintie_gold.Compressor], Label: ['792_compressor'], Comment: ['<id> air conditioner compressor not working']
#
# Result 22:
# Type: [maintie_gold.Compressor], Label: ['793_compressor'], Comment: ['<id> air conditioner compressor tripping out']
#
# Result 23:
# Type: [maintie_gold.Drive], Label: ['794_drive'], Comment: ['<id> air conditioner drive leaking']
#
# Result 24:
# Type: [maintie_gold.Drive], Label: ['795_drive'], Comment: ['<id> air conditioner drive leaking oil']
#
# Result 25:
# Type: [maintie_gold.Fan], Label: ['796_fan'], Comment: ['<id> air conditioner fan unserviceable - fit new']
#
# Result 26:
# Type: [maintie_gold.PressureSwitch], Label: ['801_pressure_switch'], Comment: ['<id> air conditioner pressure switch unserviceable']
#
# Result 27:
# Type: [maintie_gold.Fan], Label: ['806_fan'], Comment: ['air conditioner fan speed resistor not working <num> and <num>']
#
# Result 28:
# Type: [maintie_gold.Fuse], Label: ['821_fuse'], Comment: ['blown air conditioner fuse']
#
# Result 29:
# Type: [maintie_gold.Compressor], Label: ['984_compressor'], Comment: ['repair earth terminal on air conditioner compressor']
#
# Result 30:
# Type: [maintie_gold.Louver], Label: ['1002_louver'], Comment: ['replace air conditioner louver']
#
# Result 31:
# Type: [maintie_gold.Cover], Label: ['1009_cover'], Comment: ['replace cabin air conditioner cover and louver']
#
# Result 32:
# Type: [maintie_gold.Louver], Label: ['1009_louver'], Comment: ['replace cabin air conditioner cover and louver']
#
# Result 33:
# Type: [maintie_gold.ControlCable], Label: ['1028_control_cable'], Comment: ['replace seized air conditioner control cable']

# %% [markdown]
# **Find all the `FailedStates` of an objects descendants**

# %%
# %%sparql_query
# """
# PREFIX rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#>
# PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
# PREFIX owl: <http://www.w3.org/2002/07/owl#>
#
# SELECT ?failedStateInstance ?objectInstance
# WHERE {
#   # Find subclasses of FailedState
#   ?subclassFailedState rdfs:subClassOf* <file://ONTOLOGY_NAME#FailedState> .
#
#   # Find instances of FailedState
#   ?failedStateInstance rdf:type ?subclassFailedState .
#
#   # Find all object instances associated with the failed states instances
#   ?failedStateInstance <file://ONTOLOGY_NAME#has_patient> ?objectInstance .
# }
# """
# Out:
# Results found: 226
#
# [[maintie_gold.3AGOQE26, maintie_gold.BZ3GSDWE], [maintie_gold.Z4S6PPFG, maintie_gold.MNW9JF2F], [maintie_gold.BR4K8LCA, maintie_gold.E7WE97RH], [maintie_gold.0IQEJ99T, maintie_gold.XLAQZ4HJ], [maintie_gold.U10DMAAF, maintie_gold.84TNOQGV], [maintie_gold.R0A12GRO, maintie_gold.OF0V6AYT], [maintie_gold.JQMENE04, maintie_gold.GZKDAOKY], [maintie_gold.PMS3L36C, maintie_gold.YARL329T], [maintie_gold.YMO65YMA, maintie_gold.YR1GLQ8J], [maintie_gold.S7BHH7E3, maintie_gold.WFT8JCG0], [maintie_gold.6P2VYIFC, maintie_gold.LU1JH9OU], [maintie_gold.N1SYPTVN, maintie_gold.KFMFPN36], [maintie_gold.AYD16229, maintie_gold.DOJ0E238], [maintie_gold.BLLY5THF, maintie_gold.SS8XNIAW], [maintie_gold.S126PRLX, maintie_gold.DYIQ6HOU], [maintie_gold.9OIXCXWZ, maintie_gold.PQN4JSBO], [maintie_gold.45TMZZEE, maintie_gold.7OSB0UV7], [maintie_gold.S9YCMU1S, maintie_gold.RQ94BYGV], [maintie_gold.7ZCZ6GM6, maintie_gold.8MKXAVRC], [maintie_gold.9VTMV2W1, maintie_gold.HGTGCIR4], [maintie_gold.MBV19DP2, maintie_gold.JGTO02XU], [maintie_gold.LZXSQG5X, maintie_gold.EPJ6M2MY], [maintie_gold.F62DSA72, maintie_gold.0LODB56W], [maintie_gold.058FJELD, maintie_gold.U48IZ5BD], [maintie_gold.UPB23I0H, maintie_gold.2HBMVCHE], [maintie_gold.E5OFAVKW, maintie_gold.OE4CG1D1], [maintie_gold.F5O5XO6G, maintie_gold.3SMSHKUI], [maintie_gold.4W3XO4KG, maintie_gold.MWH4HD9J], [maintie_gold.12AUSH3W, maintie_gold.09ZHCW3P], [maintie_gold.Y1WJDWM5, maintie_gold.3LI2F1E9], [maintie_gold.3XEA3F2G, maintie_gold.COR9EIG3], [maintie_gold.H5ON9SY1, maintie_gold.W54EQSEK], [maintie_gold.ALBNOKFE, maintie_gold.40OT0GKD], [maintie_gold.LLJ070EG, maintie_gold.F9PK7NJQ], [maintie_gold.SKCXWLST, maintie_gold.19KPS9ZB], [maintie_gold.3B1ES86A, maintie_gold.RAVZAQJE], [maintie_gold.HKBRSWO5, maintie_gold.Q9ZOKMQF], [maintie_gold.1ZF7SPV3, maintie_gold.O4NMXUL5], [maintie_gold.JVRKVTLM, maintie_gold.EMJJFI63], [maintie_gold.A2E88E6V, maintie_gold.MV11SQCY], [maintie_gold.8Y26YIPC, maintie_gold.7YU6CZVN], [maintie_gold.1IR8U11H, maintie_gold.8YG5JD6J], [maintie_gold.9VC1PY7Y, maintie_gold.IZVHLLBP], [maintie_gold.JTYL0KSN, maintie_gold.O7D1H40I], [maintie_gold.PHQY19NM, maintie_gold.D0VVPD6N], [maintie_gold.DXWATRGE, maintie_gold.Z08YX6PX], [maintie_gold.Y52CPBFD, maintie_gold.I6B2B4PR], [maintie_gold.2RDC3F75, maintie_gold.BFJY988W], [maintie_gold.8ZAZX473, maintie_gold.P6KZJ40E], [maintie_gold.MRXC0LQ9, maintie_gold.JU0NPE2Q], [maintie_gold.JJ8V3642, maintie_gold.1DM153KU], [maintie_gold.Y6UQTL3G, maintie_gold.4YEVUJGX], [maintie_gold.2ITSCT00, maintie_gold.WOIKVJUF], [maintie_gold.Q2OL1K8U, maintie_gold.BDK50C07], [maintie_gold.49W2XB96, maintie_gold.YY6QIB3Y], [maintie_gold.3WVSEM0I, maintie_gold.M3JA00ZU], [maintie_gold.P3A58DTC, maintie_gold.Y7APTLGH], [maintie_gold.LE07MKB4, maintie_gold.CUZW3FZH], [maintie_gold.WTYZXTCL, maintie_gold.YZ19VABZ], [maintie_gold.MBKLFF3Z, maintie_gold.C39RSI3A], [maintie_gold.MBKLFF3Z, maintie_gold.2RV1PMK8], [maintie_gold.ZRQYPO11, maintie_gold.GOMMXE91], [maintie_gold.6L1NXTWC, maintie_gold.E4CE2WHM], [maintie_gold.GMNOCLIJ, maintie_gold.1TDXCKIS], [maintie_gold.S74S76RG, maintie_gold.7WIZNS7E], [maintie_gold.328ZFAJL, maintie_gold.HBOQ7NKK], [maintie_gold.6EOH79QD, maintie_gold.JYHGPDIY], [maintie_gold.6EOH79QD, maintie_gold.T0VGTMN9], [maintie_gold.TAEIC7B5, maintie_gold.FES7FE2K], [maintie_gold.MDFVJV9H, maintie_gold.PRYSV84H], [maintie_gold.DAXFYOID, maintie_gold.DND2B96T], [maintie_gold.VK8PR0DQ, maintie_gold.O5KD7LF5], [maintie_gold.8KQ6FBQG, maintie_gold.MIE27C4Z], [maintie_gold.YSE27OPZ, maintie_gold.M9JKFBBL], [maintie_gold.LK972D39, maintie_gold.IA90QAMC], [maintie_gold.PEH40HKJ, maintie_gold.A4DH0DGO], [maintie_gold.43Y1YZ13, maintie_gold.RQZL8BHW], [maintie_gold.S95QPNQX, maintie_gold.VHUPJXSZ], [maintie_gold.DKZB3XUV, maintie_gold.GTBLRGBP], [maintie_gold.XQO0AVDL, maintie_gold.4VYJ2Z2I], [maintie_gold.AVCSJ4HD, maintie_gold.29VU5MJW], [maintie_gold.AVCSJ4HD, maintie_gold.E61HNNF5], [maintie_gold.F9IJG52T, maintie_gold.9OA1PUIU], [maintie_gold.W ...
#
# Result 1:
# Type: [maintie_gold.NotWorking], Label: ['0_not_working'], Comment: ['<id> air conditioner thermostat not working']
# Type: [maintie_gold.Thermostat], Label: ['0_thermostat'], Comment: ['<id> air conditioner thermostat not working']
#
# Result 2:
# Type: [maintie_gold.NotWorking], Label: ['11_not_working'], Comment: ['<id> air horn not working']
# Type: [maintie_gold.AirHorn], Label: ['11_air_horn'], Comment: ['<id> air horn not working']
#
# Result 3:
# Type: [maintie_gold.NotWorking], Label: ['12_not_working'], Comment: ['<id> air horn not working compressor awaiting']
# Type: [maintie_gold.AirHorn], Label: ['12_air_horn'], Comment: ['<id> air horn not working compressor awaiting']
#
# Result 4:
# Type: [maintie_gold.NotWorking], Label: ['20_not_working'], Comment: ['<id> airhorn not working']
# Type: [maintie_gold.Airhorn], Label: ['20_airhorn'], Comment: ['<id> airhorn not working']
#
# Result 5:
# Type: [maintie_gold.NotWorking], Label: ['36_not_working'], Comment: ['<id> auto-spray feature not working']
# Type: [maintie_gold.Autospray], Label: ['36_autospray'], Comment: ['<id> auto-spray feature not working']
#
# Result 6:
# Type: [maintie_gold.NotWorking], Label: ['44_not_working'], Comment: ['<id> backup alarm not working']
# Type: [maintie_gold.BackupAlarm], Label: ['44_backup_alarm'], Comment: ['<id> backup alarm not working']
#
# Result 7:
# Type: [maintie_gold.NotWorking], Label: ['50_not_working'], Comment: ['<id> beacon not working']
# Type: [maintie_gold.Beacon], Label: ['50_beacon'], Comment: ['<id> beacon not working']
#
# Result 8:
# Type: [maintie_gold.NotWorking], Label: ['82_not_working'], Comment: ['<id> boarding gate latch not working']
# Type: [maintie_gold.Latch], Label: ['82_latch'], Comment: ['<id> boarding gate latch not working']
#
# Result 9:
# Type: [maintie_gold.NotWorking], Label: ['83_not_working'], Comment: ['<id> boarding ladder not working']
# Type: [maintie_gold.BoardingLadder], Label: ['83_boarding_ladder'], Comment: ['<id> boarding ladder not working']
#
# Result 10:
# Type: [maintie_gold.NotWorking], Label: ['281_not_working'], Comment: ['speedometer not working']
# Type: [maintie_gold.Speedometer], Label: ['281_speedometer'], Comment: ['speedometer not working']
#
# Result 11:
# Type: [maintie_gold.NotWorking], Label: ['289_not_working'], Comment: ['front revolving light not working']
# Type: [maintie_gold.RevolvingLight], Label: ['289_revolving_light'], Comment: ['front revolving light not working']
#
# Result 12:
# Type: [maintie_gold.NotWorking], Label: ['314_not_working'], Comment: ['crane not working']
# Type: [maintie_gold.Crane], Label: ['314_crane'], Comment: ['crane not working']
#
# Result 13:
# Type: [maintie_gold.NotWorking], Label: ['350_not_working'], Comment: ['system <id> pump pressure gauge not working']
# Type: [maintie_gold.PressureGauge], Label: ['350_pressure_gauge'], Comment: ['system <id> pump pressure gauge not working']
#
# Result 14:
# Type: [maintie_gold.NotWorking], Label: ['524_not_working'], Comment: ['<id> - air horn not working']
# Type: [maintie_gold.AirHorn], Label: ['524_air_horn'], Comment: ['<id> - air horn not working']
#
# Result 15:
# Type: [maintie_gold.NotWorking], Label: ['792_not_working'], Comment: ['<id> air conditioner compressor not working']
# Type: [maintie_gold.Compressor], Label: ['792_compressor'], Comment: ['<id> air conditioner compressor not working']
#
# Result 16:
# Type: [maintie_gold.NotWorking], Label: ['806_not_working'], Comment: ['air conditioner fan speed resistor not working <num> and <num>']
# Type: [maintie_gold.SpeedResistor], Label: ['806_speed_resistor'], Comment: ['air conditioner fan speed resistor not working <num> and <num>']
#
# Result 17:
# Type: [maintie_gold.NotWorking], Label: ['829_not_working'], Comment: ['cabin side weightometer not working']
# Type: [maintie_gold.Weightometer], Label: ['829_weightometer'], Comment: ['cabin side weightometer not working']
#
# Result 18:
# Type: [maintie_gold.NotWorking], Label: ['864_not_working'], Comment: ['dry cell not working properly <id>']
# Type: [maintie_gold.DryCell], Label: ['864_dry_cell'], Comment: ['dry cell not working properly <id>']
#
# Result 19:
# Type: [maintie_gold.NotWorking], Label: ['867_not_working'], Comment: ['diagnose / repair right hand scoreboard not working']
# Type: [maintie_gold.Scoreboard], Label: ['867_scoreboard'], Comment: ['diagnose / repair right hand scoreboard not working']
#
# Result 20:
# Type: [maintie_gold.NotWorking], Label: ['878_not_working'], Comment: ['<sensitive> depth counter not working']
# Type: [maintie_gold.DepthCounter], Label: ['878_depth_counter'], Comment: ['<sensitive> depth counter not working']
#
# Result 21:
# Type: [maintie_gold.NotWorking], Label: ['880_not_working'], Comment: ['electric propel siren not working']
# Type: [maintie_gold.Siren], Label: ['880_siren'], Comment: ['electric propel siren not working']
#
# Result 22:
# Type: [maintie_gold.Unserviceable], Label: ['1_unserviceable'], Comment: ['<id> air conditioner thermostat unserviceable']
# Type: [maintie_gold.Thermostat], Label: ['1_thermostat'], Comment: ['<id> air conditioner thermostat unserviceable']
#
# Result 23:
# Type: [maintie_gold.Unserviceable], Label: ['2_unserviceable'], Comment: ['<id> air conditioner unserviceable']
# Type: [maintie_gold.AirConditioner], Label: ['2_air_conditioner'], Comment: ['<id> air conditioner unserviceable']
#
# Result 24:
# Type: [maintie_gold.Unserviceable], Label: ['3_unserviceable'], Comment: ['<id> air conditioner unserviceable when stationary']
# Type: [maintie_gold.AirConditioner], Label: ['3_air_conditioner'], Comment: ['<id> air conditioner unserviceable when stationary']
#
# Result 25:
# Type: [maintie_gold.Unserviceable], Label: ['14_unserviceable'], Comment: ['<id> air horn unserviceable']
# Type: [maintie_gold.AirHorn], Label: ['14_air_horn'], Comment: ['<id> air horn unserviceable']
#
# Result 26:
# Type: [maintie_gold.Unserviceable], Label: ['30_unserviceable'], Comment: ['<id> armrest unserviceable']
# Type: [maintie_gold.Armrest], Label: ['30_armrest'], Comment: ['<id> armrest unserviceable']
#
# Result 27:
# Type: [maintie_gold.Unserviceable], Label: ['33_unserviceable'], Comment: ['<id> auto-greaser unserviceable']
# Type: [maintie_gold.Autogreaser], Label: ['33_autogreaser'], Comment: ['<id> auto-greaser unserviceable']
#
# Result 28:
# Type: [maintie_gold.Unserviceable], Label: ['40_unserviceable'], Comment: ['<id> back rest unserviceable handle broken']
# Type: [maintie_gold.BackRest], Label: ['40_back_rest'], Comment: ['<id> back rest unserviceable handle broken']
#
# Result 29:
# Type: [maintie_gold.Unserviceable], Label: ['42_unserviceable'], Comment: ['<id> backlight on dash unserviceable']
# Type: [maintie_gold.Backlight], Label: ['42_backlight'], Comment: ['<id> backlight on dash unserviceable']
#
# Result 30:
# Type: [maintie_gold.Unserviceable], Label: ['47_unserviceable'], Comment: ['<id> batteries unserviceable']
# Type: [maintie_gold.Batteries], Label: ['47_batteries'], Comment: ['<id> batteries unserviceable']
#
# Result 31:
# Type: [maintie_gold.Unserviceable], Label: ['51_unserviceable'], Comment: ['<id> beacon unserviceable']
# Type: [maintie_gold.Beacon], Label: ['51_beacon'], Comment: ['<id> beacon unserviceable']
#
# Result 32:
# Type: [maintie_gold.Unserviceable], Label: ['52_unserviceable'], Comment: ['<id> bearing on air conditioner compressor unserviceable']
# Type: [maintie_gold.Bearing], Label: ['52_bearing'], Comment: ['<id> bearing on air conditioner compressor unserviceable']
#
# Result 33:
# Type: [maintie_gold.Unserviceable], Label: ['176_unserviceable'], Comment: ['<id> change out unserviceable jacket water pump']
# Type: [maintie_gold.JacketWaterPump], Label: ['176_jacket_water_pump'], Comment: ['<id> change out unserviceable jacket water pump']
#
# Result 34:
# Type: [maintie_gold.Unserviceable], Label: ['177_unserviceable'], Comment: ['<id> change out unserviceable left hand bucket cylinder hose']
# Type: [maintie_gold.Hose], Label: ['177_hose'], Comment: ['<id> change out unserviceable left hand bucket cylinder hose']
#
# Result 35:
# Type: [maintie_gold.Unserviceable], Label: ['178_unserviceable'], Comment: ['<id> change out unserviceable position <num> tyre']
# Type: [maintie_gold.Tyre], Label: ['178_tyre'], Comment: ['<id> change out unserviceable position <num> tyre']
#
# Result 36:
# Type: [maintie_gold.Unserviceable], Label: ['179_unserviceable'], Comment: ['<id> change out unserviceable right hand clam cylinder hose']
# Type: [maintie_gold.Hose], Label: ['179_hose'], Comment: ['<id> change out unserviceable right hand clam cylinder hose']
#
# Result 37:
# Type: [maintie_gold.Unserviceable], Label: ['180_unserviceable'], Comment: ['<id> change out unserviceable right hand tilt cylinder']
# Type: [maintie_gold.TiltCylinder], Label: ['180_tilt_cylinder'], Comment: ['<id> change out unserviceable right hand tilt cylinder']
#
# Result 38:
# Type: [maintie_gold.Unserviceable], Label: ['181_unserviceable'], Comment: ['<id> change out unserviceable swing brake cylinder']
# Type: [maintie_gold.SwingBrakeCylinder], Label: ['181_swing_brake_cylinder'], Comment: ['<id> change out unserviceable swing brake cylinder']
#
# Result 39:
# Type: [maintie_gold.Unserviceable], Label: ['204_unserviceable'], Comment: ['<id> compressor oil pressure switch unserviceable']
# Type: [maintie_gold.OilPressureSwitch], Label: ['204_oil_pressure_switch'], Comment: ['<id> compressor oil pressure switch unserviceable']
#
# Result 40:
# Type: [maintie_gold.Unserviceable], Label: ['206_unserviceable'], Comment: ['<id> control valve unserviceable see long text']
# Type: [maintie_gold.ControlValve], Label: ['206_control_valve'], Comment: ['<id> control valve unserviceable see long text']
#
# Result 41:
# Type: [maintie_gold.Unserviceable], Label: ['316_unserviceable'], Comment: ['grease pump unserviceable']
# Type: [maintie_gold.GreasePump], Label: ['316_grease_pump'], Comment: ['grease pump unserviceable']
#
# Result 42:
# Type: [maintie_gold.Unserviceable], Label: ['327_unserviceable'], Comment: ['rear through shaft universal joint unserviceable']
# Type: [maintie_gold.UniversalJoint], Label: ['327_universal_joint'], Comment: ['rear through shaft universal joint unserviceable']
#
# Result 43:
# Type: [maintie_gold.Unserviceable], Label: ['342_unserviceable'], Comment: ['<id> rear wiper motor unserviceable']
# Type: [maintie_gold.WiperMotor], Label: ['342_wiper_motor'], Comment: ['<id> rear wiper motor unserviceable']
#
# Result 44:
# Type: [maintie_gold.Unserviceable], Label: ['351_unserviceable'], Comment: ['<id> replace unserviceable differential drain plugs']
# Type: [maintie_gold.DrainPlugs], Label: ['351_drain_plugs'], Comment: ['<id> replace unserviceable differential drain plugs']
#
# Result 45:
# Type: [maintie_gold.Unserviceable], Label: ['425_unserviceable'], Comment: ['right hand bobbin roller unserviceable']
# Type: [maintie_gold.BobbinRoller], Label: ['425_bobbin_roller'], Comment: ['right hand bobbin roller unserviceable']
#
# Result 46:
# Type: [maintie_gold.Unserviceable], Label: ['467_unserviceable'], Comment: ['cabin jacking cylinder ends unserviceable']
# Type: [maintie_gold.Ends], Label: ['467_ends'], Comment: ['cabin jacking cylinder ends unserviceable']
#
# Result 47:
# Type: [maintie_gold.Unserviceable], Label: ['484_unserviceable'], Comment: ['cabin seat unserviceable needs replacing']
# Type: [maintie_gold.Seat], Label: ['484_seat'], Comment: ['cabin seat unserviceable needs replacing']
#
# Result 48:
# Type: [maintie_gold.Unserviceable], Label: ['520_unserviceable'], Comment: ['<id> - air conditioner compressor unserviceable']
# Type: [maintie_gold.Compressor], Label: ['520_compressor'], Comment: ['<id> - air conditioner compressor unserviceable']
#
# Result 49:
# Type: [maintie_gold.Unserviceable], Label: ['796_unserviceable'], Comment: ['<id> air conditioner fan unserviceable - fit new']
# Type: [maintie_gold.Fan], Label: ['796_fan'], Comment: ['<id> air conditioner fan unserviceable - fit new']
#
# Result 50:
# Type: [maintie_gold.Unserviceable], Label: ['801_unserviceable'], Comment: ['<id> air conditioner pressure switch unserviceable']
# Type: [maintie_gold.PressureSwitch], Label: ['801_pressure_switch'], Comment: ['<id> air conditioner pressure switch unserviceable']
#
# Result 51:
# Type: [maintie_gold.Unserviceable], Label: ['805_unserviceable'], Comment: ['[ shutdown ] vinyl flooring unserviceable']
# Type: [maintie_gold.VinylFlooring], Label: ['805_vinyl_flooring'], Comment: ['[ shutdown ] vinyl flooring unserviceable']
#
# Result 52:
# Type: [maintie_gold.Unserviceable], Label: ['818_unserviceable'], Comment: ['battery unserviceable dropped cell replace']
# Type: [maintie_gold.Battery], Label: ['818_battery'], Comment: ['battery unserviceable dropped cell replace']
#
# Result 53:
# Type: [maintie_gold.Unserviceable], Label: ['866_unserviceable'], Comment: ['depth counter unserviceable']
# Type: [maintie_gold.DepthCounter], Label: ['866_depth_counter'], Comment: ['depth counter unserviceable']
#
# Result 54:
# Type: [maintie_gold.Unserviceable], Label: ['901_unserviceable'], Comment: ['generator flow regulator unserviceable']
# Type: [maintie_gold.FlowRegulator], Label: ['901_flow_regulator'], Comment: ['generator flow regulator unserviceable']
#
# Result 55:
# Type: [maintie_gold.Unserviceable], Label: ['905_unserviceable'], Comment: ['heater hose in cab roof unserviceable']
# Type: [maintie_gold.Hose], Label: ['905_hose'], Comment: ['heater hose in cab roof unserviceable']
#
# Result 56:
# Type: [maintie_gold.Unserviceable], Label: ['920_unserviceable'], Comment: ['left hand chain guide unserviceable']
# Type: [maintie_gold.Guide], Label: ['920_guide'], Comment: ['left hand chain guide unserviceable']
#
# Result 57:
# Type: [maintie_gold.Unserviceable], Label: ['924_unserviceable'], Comment: ['left hand PTO pump chip sensor harness unserviceable']
# Type: [maintie_gold.Harness], Label: ['924_harness'], Comment: ['left hand PTO pump chip sensor harness unserviceable']
#
# Result 58:
# Type: [maintie_gold.Unserviceable], Label: ['928_unserviceable'], Comment: ['microwave oven unserviceable']
# Type: [maintie_gold.MicrowaveOven], Label: ['928_microwave_oven'], Comment: ['microwave oven unserviceable']
#
# Result 59:
# Type: [maintie_gold.Unserviceable], Label: ['932_unserviceable'], Comment: ['number <num> slew pump contamination switch unserviceable']
# Type: [maintie_gold.ContaminationSwitch], Label: ['932_contamination_switch'], Comment: ['number <num> slew pump contamination switch unserviceable']
#
# Result 60:
# Type: [maintie_gold.Unserviceable], Label: ['954_unserviceable'], Comment: ['pump drive box coupling and shaft unserviceable']
# Type: [maintie_gold.BoxCoupling], Label: ['954_box_coupling'], Comment: ['pump drive box coupling and shaft unserviceable']
#
# Result 61:
# Type: [maintie_gold.Unserviceable], Label: ['954_unserviceable'], Comment: ['pump drive box coupling and shaft unserviceable']
# Type: [maintie_gold.Shaft], Label: ['954_shaft'], Comment: ['pump drive box coupling and shaft unserviceable']
#
# Result 62:
# Type: [maintie_gold.Unserviceable], Label: ['960_unserviceable'], Comment: ['radiator sight glasses unserviceable']
# Type: [maintie_gold.SightGlasses], Label: ['960_sight_glasses'], Comment: ['radiator sight glasses unserviceable']
#
# Result 63:
# Type: [maintie_gold.Unserviceable], Label: ['970_unserviceable'], Comment: ['remove unserviceable air separator']
# Type: [maintie_gold.AirSeparator], Label: ['970_air_separator'], Comment: ['remove unserviceable air separator']
#
# Result 64:
# Type: [maintie_gold.Unserviceable], Label: ['1032_unserviceable'], Comment: ['replace unserviceable grease distributor']
# Type: [maintie_gold.GreaseDistributor], Label: ['1032_grease_distributor'], Comment: ['replace unserviceable grease distributor']
#
# Result 65:
# Type: [maintie_gold.Unserviceable], Label: ['1033_unserviceable'], Comment: ['replace unserviceable chip indicators']
# Type: [maintie_gold.ChipIndicators], Label: ['1033_chip_indicators'], Comment: ['replace unserviceable chip indicators']
#
# Result 66:
# Type: [maintie_gold.Unserviceable], Label: ['1034_unserviceable'], Comment: ['replace unserviceable ignition switch']
# Type: [maintie_gold.IgnitionSwitch], Label: ['1034_ignition_switch'], Comment: ['replace unserviceable ignition switch']
#
# Result 67:
# Type: [maintie_gold.Unserviceable], Label: ['1035_unserviceable'], Comment: ['replace unserviceable transmission screen and magnet']
# Type: [maintie_gold.Screen], Label: ['1035_screen'], Comment: ['replace unserviceable transmission screen and magnet']
#
# Result 68:
# Type: [maintie_gold.Unserviceable], Label: ['1035_unserviceable'], Comment: ['replace unserviceable transmission screen and magnet']
# Type: [maintie_gold.Magnet], Label: ['1035_magnet'], Comment: ['replace unserviceable transmission screen and magnet']
#
# Result 69:
# Type: [maintie_gold.Unserviceable], Label: ['1056_unserviceable'], Comment: ['siren unserviceable']
# Type: [maintie_gold.Siren], Label: ['1056_siren'], Comment: ['siren unserviceable']
#
# Result 70:
# Type: [maintie_gold.Unserviceable], Label: ['1071_unserviceable'], Comment: ['weightometer display on trailer unserviceable']
# Type: [maintie_gold.Display], Label: ['1071_display'], Comment: ['weightometer display on trailer unserviceable']
#
# Result 71:
# Type: [maintie_gold.Unserviceable], Label: ['1073_unserviceable'], Comment: ['will not start - batteries unserviceable']
# Type: [maintie_gold.Batteries], Label: ['1073_batteries'], Comment: ['will not start - batteries unserviceable']
#
# Result 72:
# Type: [maintie_gold.Unserviceable], Label: ['1075_unserviceable'], Comment: ['wiper fuse unserviceable']
# Type: [maintie_gold.Fuse], Label: ['1075_fuse'], Comment: ['wiper fuse unserviceable']
#
# Result 73:
# Type: [maintie_gold.Plugged], Label: ['5_plugged'], Comment: ['<id> air filters plugged']
# Type: [maintie_gold.AirFilters], Label: ['5_air_filters'], Comment: ['<id> air filters plugged']
#
# Result 74:
# Type: [maintie_gold.Plugged], Label: ['572_plugged'], Comment: ['<id> - change out plugged fuel filters']
# Type: [maintie_gold.FuelFilters], Label: ['572_fuel_filters'], Comment: ['<id> - change out plugged fuel filters']
#
# Result 75:
# Type: [maintie_gold.Plugged], Label: ['786_plugged'], Comment: ['<id> VIMS fuel filter plugged']
# Type: [maintie_gold.FuelFilter], Label: ['786_fuel_filter'], Comment: ['<id> VIMS fuel filter plugged']
#
# Result 76:
# Type: [maintie_gold.Disconnected], Label: ['8_disconnected'], Comment: ['<id> air horn disconnected']
# Type: [maintie_gold.AirHorn], Label: ['8_air_horn'], Comment: ['<id> air horn disconnected']
#
# Result 77:
# Type: [maintie_gold.StuckOn], Label: ['13_stuck_on'], Comment: ['<id> air horn stuck on']
# Type: [maintie_gold.AirHorn], Label: ['13_air_horn'], Comment: ['<id> air horn stuck on']
#
# Result 78:
# Type: [maintie_gold.WorkingIntermittently], Label: ['15_working_intermittently'], Comment: ['<id> air horn working intermittently']
# Type: [maintie_gold.AirHorn], Label: ['15_air_horn'], Comment: ['<id> air horn working intermittently']
#
# Result 79:
# Type: [maintie_gold.Failed], Label: ['24_failed'], Comment: ['<id> alternator failed']
# Type: [maintie_gold.Alternator], Label: ['24_alternator'], Comment: ['<id> alternator failed']
#
# Result 80:
# Type: [maintie_gold.Failed], Label: ['28_failed'], Comment: ['<id> analyse failed driveline component']
# Type: [maintie_gold.Driveline], Label: ['28_driveline'], Comment: ['<id> analyse failed driveline component']
#
# Result 81:
# Type: [maintie_gold.Failed], Label: ['283_failed'], Comment: ['<id> failed PTO and auxiliary drive PO']
# Type: [maintie_gold.Pto], Label: ['283_PTO'], Comment: ['<id> failed PTO and auxiliary drive PO']
#
# Result 82:
# Type: [maintie_gold.Failed], Label: ['283_failed'], Comment: ['<id> failed PTO and auxiliary drive PO']
# Type: [maintie_gold.AuxiliaryDrive], Label: ['283_auxiliary_drive'], Comment: ['<id> failed PTO and auxiliary drive PO']
#
# Result 83:
# Type: [maintie_gold.Failed], Label: ['707_failed'], Comment: ['<id> - replace failed air conditioner compressor']
# Type: [maintie_gold.Compressor], Label: ['707_compressor'], Comment: ['<id> - replace failed air conditioner compressor']
#
# Result 84:
# Type: [maintie_gold.Failed], Label: ['769_failed'], Comment: ['<id> CW PTO universal joint failed']
# Type: [maintie_gold.UniversalJoint], Label: ['769_universal_joint'], Comment: ['<id> CW PTO universal joint failed']
#
# Result 85:
# Type: [maintie_gold.Failed], Label: ['774_failed'], Comment: ['<id> CW transmission failed']
# Type: [maintie_gold.Transmission], Label: ['774_transmission'], Comment: ['<id> CW transmission failed']
#
# Result 86:
# Type: [maintie_gold.NotCharging], Label: ['25_not_charging'], Comment: ['<id> alternator not charging']
# Type: [maintie_gold.Alternator], Label: ['25_alternator'], Comment: ['<id> alternator not charging']
#
# Result 87:
# Type: [maintie_gold.Overcharged], Label: ['27_overcharged'], Comment: ['<id> alternator overcharged']
# Type: [maintie_gold.Alternator], Label: ['27_alternator'], Comment: ['<id> alternator overcharged']
#
# Result 88:
# Type: [maintie_gold.Broken], Label: ['40_broken'], Comment: ['<id> back rest unserviceable handle broken']
# Type: [maintie_gold.Handle], Label: ['40_handle'], Comment: ['<id> back rest unserviceable handle broken']
#
# Result 89:
# Type: [maintie_gold.Broken], Label: ['49_broken'], Comment: ['<id> beacon mount is broken']
# Type: [maintie_gold.Mount], Label: ['49_mount'], Comment: ['<id> beacon mount is broken']
#
# Result 90:
# Type: [maintie_gold.Broken], Label: ['81_broken'], Comment: ['<id> boarding gate hinge broken']
# Type: [maintie_gold.Hinge], Label: ['81_hinge'], Comment: ['<id> boarding gate hinge broken']
#
# Result 91:
# Type: [maintie_gold.Broken], Label: ['97_broken'], Comment: ['<id> broken air conditioner guard']
# Type: [maintie_gold.Guard], Label: ['97_guard'], Comment: ['<id> broken air conditioner guard']
#
# Result 92:
# Type: [maintie_gold.Broken], Label: ['98_broken'], Comment: ['<id> broken clamp on crowd cylinder hose TBC']
# Type: [maintie_gold.Clamp], Label: ['98_clamp'], Comment: ['<id> broken clamp on crowd cylinder hose TBC']
#
# Result 93:
# Type: [maintie_gold.Broken], Label: ['99_broken'], Comment: ['<id> broken fuel cooler mounts']
# Type: [maintie_gold.Mounts], Label: ['99_mounts'], Comment: ['<id> broken fuel cooler mounts']
#
# Result 94:
# Type: [maintie_gold.Broken], Label: ['100_broken'], Comment: ['<id> broken grease plug']
# Type: [maintie_gold.GreasePlug], Label: ['100_grease_plug'], Comment: ['<id> broken grease plug']
#
# Result 95:
# Type: [maintie_gold.Broken], Label: ['101_broken'], Comment: ['<id> broken hinge']
# Type: [maintie_gold.Hinge], Label: ['101_hinge'], Comment: ['<id> broken hinge']
#
# Result 96:
# Type: [maintie_gold.Broken], Label: ['102_broken'], Comment: ['<id> broken joystick PO']
# Type: [maintie_gold.Joystick], Label: ['102_joystick'], Comment: ['<id> broken joystick PO']
#
# Result 97:
# Type: [maintie_gold.Broken], Label: ['103_broken'], Comment: ['<id> broken left hand side mirror']
# Type: [maintie_gold.Mirror], Label: ['103_mirror'], Comment: ['<id> broken left hand side mirror']
#
# Result 98:
# Type: [maintie_gold.Broken], Label: ['104_broken'], Comment: ['<id> broken mirror']
# Type: [maintie_gold.Mirror], Label: ['104_mirror'], Comment: ['<id> broken mirror']
#
# Result 99:
# Type: [maintie_gold.Broken], Label: ['105_broken'], Comment: ['<id> broken right hand side door window']
# Type: [maintie_gold.Window], Label: ['105_window'], Comment: ['<id> broken right hand side door window']
#
# Result 100:
# Type: [maintie_gold.Broken], Label: ['106_broken'], Comment: ['<id> broken ripper tooth']
# Type: [maintie_gold.RipperTooth], Label: ['106_ripper_tooth'], Comment: ['<id> broken ripper tooth']
#
# Result 101:
# Type: [maintie_gold.Broken], Label: ['107_broken'], Comment: ['<id> broken weld on handrail']
# Type: [maintie_gold.Weld], Label: ['107_weld'], Comment: ['<id> broken weld on handrail']
#
# Result 102:
# Type: [maintie_gold.Broken], Label: ['134_broken'], Comment: ['<id> change out broken bolt on brake pump']
# Type: [maintie_gold.Bolt], Label: ['134_bolt'], Comment: ['<id> change out broken bolt on brake pump']
#
# Result 103:
# Type: [maintie_gold.Broken], Label: ['135_broken'], Comment: ['<id> change out broken prelube bracket']
# Type: [maintie_gold.Bracket], Label: ['135_bracket'], Comment: ['<id> change out broken prelube bracket']
#
# Result 104:
# Type: [maintie_gold.Broken], Label: ['136_broken'], Comment: ['<id> change out broken stabilizer bar']
# Type: [maintie_gold.StabilizerBar], Label: ['136_stabilizer_bar'], Comment: ['<id> change out broken stabilizer bar']
#
# Result 105:
# Type: [maintie_gold.Broken], Label: ['144_broken'], Comment: ['<id> change out exhaust clamp broken on left hand side [t |]']
# Type: [maintie_gold.Clamp], Label: ['144_clamp'], Comment: ['<id> change out exhaust clamp broken on left hand side [t |]']
#
# Result 106:
# Type: [maintie_gold.Broken], Label: ['242_broken'], Comment: ['<id> dash broken']
# Type: [maintie_gold.Dash], Label: ['242_dash'], Comment: ['<id> dash broken']
#
# Result 107:
# Type: [maintie_gold.Broken], Label: ['254_broken'], Comment: ['<id> differential lock broken']
# Type: [maintie_gold.Lock], Label: ['254_lock'], Comment: ['<id> differential lock broken']
#
# Result 108:
# Type: [maintie_gold.Broken], Label: ['265_broken'], Comment: ['<id> drill out broken bolt see text']
# Type: [maintie_gold.Bolt], Label: ['265_bolt'], Comment: ['<id> drill out broken bolt see text']
#
# Result 109:
# Type: [maintie_gold.Broken], Label: ['266_broken'], Comment: ["<id> driver's door top hinge broken"]
# Type: [maintie_gold.Hinge], Label: ['266_hinge'], Comment: ["<id> driver's door top hinge broken"]
#
# Result 110:
# Type: [maintie_gold.Broken], Label: ['407_broken'], Comment: ['parts washer pump broken']
# Type: [maintie_gold.Pump], Label: ['407_pump'], Comment: ['parts washer pump broken']
#
# Result 111:
# Type: [maintie_gold.Broken], Label: ['458_broken'], Comment: ['<id> headboard welds broken / cracked']
# Type: [maintie_gold.Welds], Label: ['458_welds'], Comment: ['<id> headboard welds broken / cracked']
#
# Result 112:
# Type: [maintie_gold.Broken], Label: ['481_broken'], Comment: ['front window roller blind broken']
# Type: [maintie_gold.RollerBlind], Label: ['481_roller_blind'], Comment: ['front window roller blind broken']
#
# Result 113:
# Type: [maintie_gold.Broken], Label: ['546_broken'], Comment: ['<id> - change out broken grease lines']
# Type: [maintie_gold.GreaseLines], Label: ['546_grease_lines'], Comment: ['<id> - change out broken grease lines']
#
# Result 114:
# Type: [maintie_gold.Broken], Label: ['606_broken'], Comment: ['<id> - emergency gate latch broken']
# Type: [maintie_gold.Latch], Label: ['606_latch'], Comment: ['<id> - emergency gate latch broken']
#
# Result 115:
# Type: [maintie_gold.Broken], Label: ['689_broken'], Comment: ['<id> - repaired <num> x broken lines']
# Type: [maintie_gold.Lines], Label: ['689_lines'], Comment: ['<id> - repaired <num> x broken lines']
#
# Result 116:
# Type: [maintie_gold.Broken], Label: ['700_broken'], Comment: ['<id> - replace broken onside mirror']
# Type: [maintie_gold.Mirror], Label: ['700_mirror'], Comment: ['<id> - replace broken onside mirror']
#
# Result 117:
# Type: [maintie_gold.Broken], Label: ['725_broken'], Comment: ['<id> - ripper shank broken']
# Type: [maintie_gold.RipperShank], Label: ['725_ripper_shank'], Comment: ['<id> - ripper shank broken']
#
# Result 118:
# Type: [maintie_gold.Broken], Label: ['768_broken'], Comment: ['<id> Bradken to repair broken clam']
# Type: [maintie_gold.Clam], Label: ['768_clam'], Comment: ['<id> Bradken to repair broken clam']
#
# Result 119:
# Type: [maintie_gold.Broken], Label: ['788_broken'], Comment: ['<id> aftercooler tank gauge broken']
# Type: [maintie_gold.Gauge], Label: ['788_gauge'], Comment: ['<id> aftercooler tank gauge broken']
#
# Result 120:
# Type: [maintie_gold.Broken], Label: ['791_broken'], Comment: ['<id> air conditioner belt broken']
# Type: [maintie_gold.Belt], Label: ['791_belt'], Comment: ['<id> air conditioner belt broken']
#
# Result 121:
# Type: [maintie_gold.Broken], Label: ['825_broken'], Comment: ['broken proximity sensor tag - carosell']
# Type: [maintie_gold.Tag], Label: ['825_tag'], Comment: ['broken proximity sensor tag - carosell']
#
# Result 122:
# Type: [maintie_gold.Broken], Label: ['826_broken'], Comment: ['broken wire on speaker']
# Type: [maintie_gold.Wire], Label: ['826_wire'], Comment: ['broken wire on speaker']
#
# Result 123:
# Type: [maintie_gold.Broken], Label: ['850_broken'], Comment: ['collect broken tooth']
# Type: [maintie_gold.Tooth], Label: ['850_tooth'], Comment: ['collect broken tooth']
#
# Result 124:
# Type: [maintie_gold.Broken], Label: ['881_broken'], Comment: ['earth wire broken on bottom of radiator']
# Type: [maintie_gold.EarthWire], Label: ['881_earth_wire'], Comment: ['earth wire broken on bottom of radiator']
#
# Result 125:
# Type: [maintie_gold.Broken], Label: ['900_broken'], Comment: ['fuel filter water separator housing broken']
# Type: [maintie_gold.Housing], Label: ['900_housing'], Comment: ['fuel filter water separator housing broken']
#
# Result 126:
# Type: [maintie_gold.Broken], Label: ['908_broken'], Comment: ['ignition switch broken replace']
# Type: [maintie_gold.IgnitionSwitch], Label: ['908_ignition_switch'], Comment: ['ignition switch broken replace']
#
# Result 127:
# Type: [maintie_gold.Broken], Label: ['919_broken'], Comment: ['key broken in ignition switch']
# Type: [maintie_gold.Key], Label: ['919_key'], Comment: ['key broken in ignition switch']
#
# Result 128:
# Type: [maintie_gold.Broken], Label: ['946_broken'], Comment: ['power step control cable broken']
# Type: [maintie_gold.ControlCable], Label: ['946_control_cable'], Comment: ['power step control cable broken']
#
# Result 129:
# Type: [maintie_gold.Broken], Label: ['1007_broken'], Comment: ['replace broken earth terminal']
# Type: [maintie_gold.EarthTerminal], Label: ['1007_earth_terminal'], Comment: ['replace broken earth terminal']
#
# Result 130:
# Type: [maintie_gold.Blown], Label: ['43_blown'], Comment: ['<id> backlights on dash blown']
# Type: [maintie_gold.Backlights], Label: ['43_backlights'], Comment: ['<id> backlights on dash blown']
#
# Result 131:
# Type: [maintie_gold.Blown], Label: ['58_blown'], Comment: ['<id> blade light blown needs replacing']
# Type: [maintie_gold.Light], Label: ['58_light'], Comment: ['<id> blade light blown needs replacing']
#
# Result 132:
# Type: [maintie_gold.Blown], Label: ['64_blown'], Comment: ['<id> blown air conditioner hose']
# Type: [maintie_gold.Hose], Label: ['64_hose'], Comment: ['<id> blown air conditioner hose']
#
# Result 133:
# Type: [maintie_gold.Blown], Label: ['65_blown'], Comment: ['<id> blown air conditioner hose to radiator']
# Type: [maintie_gold.Hose], Label: ['65_hose'], Comment: ['<id> blown air conditioner hose to radiator']
#
# Result 134:
# Type: [maintie_gold.Blown], Label: ['66_blown'], Comment: ['<id> blown brake hose']
# Type: [maintie_gold.Hose], Label: ['66_hose'], Comment: ['<id> blown brake hose']
#
# Result 135:
# Type: [maintie_gold.Blown], Label: ['67_blown'], Comment: ['<id> blown crowd cylinder hose']
# Type: [maintie_gold.Hose], Label: ['67_hose'], Comment: ['<id> blown crowd cylinder hose']
#
# Result 136:
# Type: [maintie_gold.Blown], Label: ['68_blown'], Comment: ['<id> blown extension line from position <num>']
# Type: [maintie_gold.ExtensionLine], Label: ['68_extension_line'], Comment: ['<id> blown extension line from position <num>']
#
# Result 137:
# Type: [maintie_gold.Blown], Label: ['69_blown'], Comment: ['<id> blown hose in hitch']
# Type: [maintie_gold.Hose], Label: ['69_hose'], Comment: ['<id> blown hose in hitch']
#
# Result 138:
# Type: [maintie_gold.Blown], Label: ['70_blown'], Comment: ['<id> blown hose on boom']
# Type: [maintie_gold.Hose], Label: ['70_hose'], Comment: ['<id> blown hose on boom']
#
# Result 139:
# Type: [maintie_gold.Blown], Label: ['71_blown'], Comment: ['<id> blown lift cylinder o-ring']
# Type: [maintie_gold.Oring], Label: ['71_oring'], Comment: ['<id> blown lift cylinder o-ring']
#
# Result 140:
# Type: [maintie_gold.Blown], Label: ['72_blown'], Comment: ['<id> blown light on boom']
# Type: [maintie_gold.Light], Label: ['72_light'], Comment: ['<id> blown light on boom']
#
# Result 141:
# Type: [maintie_gold.Blown], Label: ['73_blown'], Comment: ['<id> blown o-ring off steering hose']
# Type: [maintie_gold.Oring], Label: ['73_oring'], Comment: ['<id> blown o-ring off steering hose']
#
# Result 142:
# Type: [maintie_gold.Blown], Label: ['74_blown'], Comment: ['<id> blown o-ring on left hand lift cylinder']
# Type: [maintie_gold.Oring], Label: ['74_oring'], Comment: ['<id> blown o-ring on left hand lift cylinder']
#
# Result 143:
# Type: [maintie_gold.Blown], Label: ['75_blown'], Comment: ['<id> blown o-ring on steering hose']
# Type: [maintie_gold.Oring], Label: ['75_oring'], Comment: ['<id> blown o-ring on steering hose']
#
# Result 144:
# Type: [maintie_gold.Blown], Label: ['76_blown'], Comment: ['<id> blown oil cooler hose - <num> x <num> <num> metre']
# Type: [maintie_gold.Hose], Label: ['76_hose'], Comment: ['<id> blown oil cooler hose - <num> x <num> <num> metre']
#
# Result 145:
# Type: [maintie_gold.Blown], Label: ['77_blown'], Comment: ['<id> blown position <num> tyre']
# Type: [maintie_gold.Tyre], Label: ['77_tyre'], Comment: ['<id> blown position <num> tyre']
#
# Result 146:
# Type: [maintie_gold.Blown], Label: ['78_blown'], Comment: ['<id> blown right hand bucket cylinder hose']
# Type: [maintie_gold.Hose], Label: ['78_hose'], Comment: ['<id> blown right hand bucket cylinder hose']
#
# Result 147:
# Type: [maintie_gold.Blown], Label: ['79_blown'], Comment: ['<id> blown steering hose']
# Type: [maintie_gold.Hose], Label: ['79_hose'], Comment: ['<id> blown steering hose']
#
# Result 148:
# Type: [maintie_gold.Blown], Label: ['80_blown'], Comment: ['<id> blown steering pump hose']
# Type: [maintie_gold.Hose], Label: ['80_hose'], Comment: ['<id> blown steering pump hose']
#
# Result 149:
# Type: [maintie_gold.Blown], Label: ['131_blown'], Comment: ['<id> change out blown o-ring on steering pump']
# Type: [maintie_gold.Oring], Label: ['131_oring'], Comment: ['<id> change out blown o-ring on steering pump']
#
# Result 150:
# Type: [maintie_gold.Blown], Label: ['132_blown'], Comment: ['<id> change out blown position <num> tyre']
# Type: [maintie_gold.Tyre], Label: ['132_tyre'], Comment: ['<id> change out blown position <num> tyre']
#
# Result 151:
# Type: [maintie_gold.Blown], Label: ['133_blown'], Comment: ['<id> change out blown steering hose']
# Type: [maintie_gold.Hose], Label: ['133_hose'], Comment: ['<id> change out blown steering hose']
#
# Result 152:
# Type: [maintie_gold.Blown], Label: ['305_blown'], Comment: ['<id> replace blown implement hose']
# Type: [maintie_gold.ImplementHose], Label: ['305_implement_hose'], Comment: ['<id> replace blown implement hose']
#
# Result 153:
# Type: [maintie_gold.Blown], Label: ['313_blown'], Comment: ['<id> replace blown right hand steering hose']
# Type: [maintie_gold.Hose], Label: ['313_hose'], Comment: ['<id> replace blown right hand steering hose']
#
# Result 154:
# Type: [maintie_gold.Blown], Label: ['413_blown'], Comment: ['position <num> tyre blown']
# Type: [maintie_gold.Tyre], Label: ['413_tyre'], Comment: ['position <num> tyre blown']
#
# Result 155:
# Type: [maintie_gold.Blown], Label: ['473_blown'], Comment: ['<id> replace blown main pump hose']
# Type: [maintie_gold.Hose], Label: ['473_hose'], Comment: ['<id> replace blown main pump hose']
#
# Result 156:
# Type: [maintie_gold.Blown], Label: ['541_blown'], Comment: ['<id> - change out blown hose']
# Type: [maintie_gold.Hose], Label: ['541_hose'], Comment: ['<id> - change out blown hose']
#
# Result 157:
# Type: [maintie_gold.Blown], Label: ['607_blown'], Comment: ['<id> - engine bay light blown']
# Type: [maintie_gold.Light], Label: ['607_light'], Comment: ['<id> - engine bay light blown']
#
# Result 158:
# Type: [maintie_gold.Blown], Label: ['621_blown'], Comment: ['<id> - front headlight blown']
# Type: [maintie_gold.Headlight], Label: ['621_headlight'], Comment: ['<id> - front headlight blown']
#
# Result 159:
# Type: [maintie_gold.Blown], Label: ['657_blown'], Comment: ['<id> - lower left hand headlight blown']
# Type: [maintie_gold.Headlight], Label: ['657_headlight'], Comment: ['<id> - lower left hand headlight blown']
#
# Result 160:
# Type: [maintie_gold.Blown], Label: ['677_blown'], Comment: ['<id> - repair blown air conditioner hose']
# Type: [maintie_gold.Hose], Label: ['677_hose'], Comment: ['<id> - repair blown air conditioner hose']
#
# Result 161:
# Type: [maintie_gold.Blown], Label: ['695_blown'], Comment: ['<id> - replace blown hose']
# Type: [maintie_gold.Hose], Label: ['695_hose'], Comment: ['<id> - replace blown hose']
#
# Result 162:
# Type: [maintie_gold.Blown], Label: ['696_blown'], Comment: ['<id> - replace blown work lights']
# Type: [maintie_gold.WorkLights], Label: ['696_work_lights'], Comment: ['<id> - replace blown work lights']
#
# Result 163:
# Type: [maintie_gold.Blown], Label: ['811_blown'], Comment: ['air brake line blown - requires replacing']
# Type: [maintie_gold.Line], Label: ['811_line'], Comment: ['air brake line blown - requires replacing']
#
# Result 164:
# Type: [maintie_gold.Blown], Label: ['821_blown'], Comment: ['blown air conditioner fuse']
# Type: [maintie_gold.Fuse], Label: ['821_fuse'], Comment: ['blown air conditioner fuse']
#
# Result 165:
# Type: [maintie_gold.OutOfService], Label: ['46_out_of_service'], Comment: ['<id> batteries out of service']
# Type: [maintie_gold.Batteries], Label: ['46_batteries'], Comment: ['<id> batteries out of service']
#
# Result 166:
# Type: [maintie_gold.Seized], Label: ['48_seized'], Comment: ['<id> battery cover hinges seized']
# Type: [maintie_gold.Hinges], Label: ['48_hinges'], Comment: ['<id> battery cover hinges seized']
#
# Result 167:
# Type: [maintie_gold.Seized], Label: ['1028_seized'], Comment: ['replace seized air conditioner control cable']
# Type: [maintie_gold.ControlCable], Label: ['1028_control_cable'], Comment: ['replace seized air conditioner control cable']
#
# Result 168:
# Type: [maintie_gold.Shot], Label: ['53_shot'], Comment: ['<id> bearings are shot']
# Type: [maintie_gold.Bearings], Label: ['53_bearings'], Comment: ['<id> bearings are shot']
#
# Result 169:
# Type: [maintie_gold.Cracked], Label: ['60_cracked'], Comment: ['<id> blade skin cracked']
# Type: [maintie_gold.Skin], Label: ['60_skin'], Comment: ['<id> blade skin cracked']
#
# Result 170:
# Type: [maintie_gold.Cracked], Label: ['61_cracked'], Comment: ['<id> blade wear plates cracked and worn']
# Type: [maintie_gold.WearPlates], Label: ['61_wear_plates'], Comment: ['<id> blade wear plates cracked and worn']
#
# Result 171:
# Type: [maintie_gold.Cracked], Label: ['108_cracked'], Comment: ['<id> bucket cracked in arch near cancelled']
# Type: [maintie_gold.Arch], Label: ['108_arch'], Comment: ['<id> bucket cracked in arch near cancelled']
#
# Result 172:
# Type: [maintie_gold.Cracked], Label: ['109_cracked'], Comment: ['<id> cabin door window cracked']
# Type: [maintie_gold.Window], Label: ['109_window'], Comment: ['<id> cabin door window cracked']
#
# Result 173:
# Type: [maintie_gold.Cracked], Label: ['137_cracked'], Comment: ['<id> change out cracked pipe on valve bank']
# Type: [maintie_gold.Pipe], Label: ['137_pipe'], Comment: ['<id> change out cracked pipe on valve bank']
#
# Result 174:
# Type: [maintie_gold.Cracked], Label: ['138_cracked'], Comment: ['<id> change out cracked position <num> adaptor and tooth']
# Type: [maintie_gold.Adaptor], Label: ['138_adaptor'], Comment: ['<id> change out cracked position <num> adaptor and tooth']
#
# Result 175:
# Type: [maintie_gold.Cracked], Label: ['138_cracked'], Comment: ['<id> change out cracked position <num> adaptor and tooth']
# Type: [maintie_gold.Tooth], Label: ['138_tooth'], Comment: ['<id> change out cracked position <num> adaptor and tooth']
#
# Result 176:
# Type: [maintie_gold.Cracked], Label: ['146_cracked'], Comment: ['<id> change out front upper window cracked']
# Type: [maintie_gold.Window], Label: ['146_window'], Comment: ['<id> change out front upper window cracked']
#
# Result 177:
# Type: [maintie_gold.Cracked], Label: ['214_cracked'], Comment: ['<id> cords cracked at <id> and <id>']
# Type: [maintie_gold.Cords], Label: ['214_cords'], Comment: ['<id> cords cracked at <id> and <id>']
#
# Result 178:
# Type: [maintie_gold.Cracked], Label: ['222_cracked'], Comment: ['<id> cracked front window']
# Type: [maintie_gold.Window], Label: ['222_window'], Comment: ['<id> cracked front window']
#
# Result 179:
# Type: [maintie_gold.Cracked], Label: ['223_cracked'], Comment: ['<id> cracked fuel tank']
# Type: [maintie_gold.FuelTank], Label: ['223_fuel_tank'], Comment: ['<id> cracked fuel tank']
#
# Result 180:
# Type: [maintie_gold.Cracked], Label: ['224_cracked'], Comment: ['<id> cracked hydraulic pipe']
# Type: [maintie_gold.HydraulicPipe], Label: ['224_hydraulic_pipe'], Comment: ['<id> cracked hydraulic pipe']
#
# Result 181:
# Type: [maintie_gold.Cracked], Label: ['225_cracked'], Comment: ['<id> cracked steering tank suction tube']
# Type: [maintie_gold.SuctionTube], Label: ['225_suction_tube'], Comment: ['<id> cracked steering tank suction tube']
#
# Result 182:
# Type: [maintie_gold.Cracked], Label: ['226_cracked'], Comment: ['<id> cracked suction tube']
# Type: [maintie_gold.SuctionTube], Label: ['226_suction_tube'], Comment: ['<id> cracked suction tube']
#
# Result 183:
# Type: [maintie_gold.Cracked], Label: ['227_cracked'], Comment: ['<id> cracked walkway and handrails']
# Type: [maintie_gold.Walkway], Label: ['227_walkway'], Comment: ['<id> cracked walkway and handrails']
#
# Result 184:
# Type: [maintie_gold.Cracked], Label: ['227_cracked'], Comment: ['<id> cracked walkway and handrails']
# Type: [maintie_gold.Handrails], Label: ['227_handrails'], Comment: ['<id> cracked walkway and handrails']
#
# Result 185:
# Type: [maintie_gold.Cracked], Label: ['347_cracked'], Comment: ['<id> replace transmission - cracked']
# Type: [maintie_gold.Transmission], Label: ['347_transmission'], Comment: ['<id> replace transmission - cracked']
#
# Result 186:
# Type: [maintie_gold.Cracked], Label: ['365_cracked'], Comment: ['handrail above battery box cracked']
# Type: [maintie_gold.Handrail], Label: ['365_handrail'], Comment: ['handrail above battery box cracked']
#
# Result 187:
# Type: [maintie_gold.Cracked], Label: ['366_cracked'], Comment: ['<id> front window cracked replace']
# Type: [maintie_gold.Window], Label: ['366_window'], Comment: ['<id> front window cracked replace']
#
# Result 188:
# Type: [maintie_gold.Cracked], Label: ['400_cracked'], Comment: ['<id> replace <num> x cracked windows']
# Type: [maintie_gold.Windows], Label: ['400_windows'], Comment: ['<id> replace <num> x cracked windows']
#
# Result 189:
# Type: [maintie_gold.Cracked], Label: ['446_cracked'], Comment: ['bulk fuel tank cracked and leaking']
# Type: [maintie_gold.BulkFuelTank], Label: ['446_bulk_fuel_tank'], Comment: ['bulk fuel tank cracked and leaking']
#
# Result 190:
# Type: [maintie_gold.Cracked], Label: ['458_cracked'], Comment: ['<id> headboard welds broken / cracked']
# Type: [maintie_gold.Welds], Label: ['458_welds'], Comment: ['<id> headboard welds broken / cracked']
#
# Result 191:
# Type: [maintie_gold.Cracked], Label: ['479_cracked'], Comment: ['<id> replace cracked transmission dropbox']
# Type: [maintie_gold.Dropbox], Label: ['479_dropbox'], Comment: ['<id> replace cracked transmission dropbox']
#
# Result 192:
# Type: [maintie_gold.Cracked], Label: ['654_cracked'], Comment: ['<id> - left hand corner bonnet cracked']
# Type: [maintie_gold.Bonnet], Label: ['654_bonnet'], Comment: ['<id> - left hand corner bonnet cracked']
#
# Result 193:
# Type: [maintie_gold.Cracked], Label: ['678_cracked'], Comment: ['<id> - repair cracked steering tank mo']
# Type: [maintie_gold.Tank], Label: ['678_tank'], Comment: ['<id> - repair cracked steering tank mo']
#
# Result 194:
# Type: [maintie_gold.Cracked], Label: ['703_cracked'], Comment: ['<id> - replace cracked exhaust shield']
# Type: [maintie_gold.ExhaustShield], Label: ['703_exhaust_shield'], Comment: ['<id> - replace cracked exhaust shield']
#
# Result 195:
# Type: [maintie_gold.Cracked], Label: ['863_cracked'], Comment: ['cracked power point in cabin']
# Type: [maintie_gold.PowerPoint], Label: ['863_power_point'], Comment: ['cracked power point in cabin']
#
# Result 196:
# Type: [maintie_gold.Cracked], Label: ['980_cracked'], Comment: ['repair cracked baffle in hydraulic tank']
# Type: [maintie_gold.Baffle], Label: ['980_baffle'], Comment: ['repair cracked baffle in hydraulic tank']
#
# Result 197:
# Type: [maintie_gold.Cracked], Label: ['981_cracked'], Comment: ['repair cracked roof skin left hand side exhaust']
# Type: [maintie_gold.RoofSkin], Label: ['981_roof_skin'], Comment: ['repair cracked roof skin left hand side exhaust']
#
# Result 198:
# Type: [maintie_gold.Cracked], Label: ['988_cracked'], Comment: ['repair left hand scoreboard base cracked']
# Type: [maintie_gold.Base], Label: ['988_base'], Comment: ['repair left hand scoreboard base cracked']
#
# Result 199:
# Type: [maintie_gold.Cracked], Label: ['1012_cracked'], Comment: ['replace cracked glass in entry door']
# Type: [maintie_gold.Glass], Label: ['1012_glass'], Comment: ['replace cracked glass in entry door']
#
# Result 200:
# Type: [maintie_gold.Cracked], Label: ['1013_cracked'], Comment: ['replace cracked water separator']
# Type: [maintie_gold.WaterSeparator], Label: ['1013_water_separator'], Comment: ['replace cracked water separator']
#
# Result 201:
# Type: [maintie_gold.Cracked], Label: ['1044_cracked'], Comment: ['rock breaker cracked']
# Type: [maintie_gold.RockBreaker], Label: ['1044_rock_breaker'], Comment: ['rock breaker cracked']
#
# Result 202:
# Type: [maintie_gold.Cracked], Label: ['1045_cracked'], Comment: ['rock breaker in bucket cracked at base']
# Type: [maintie_gold.Base], Label: ['1045_base'], Comment: ['rock breaker in bucket cracked at base']
#
# Result 203:
# Type: [maintie_gold.Popped], Label: ['116_popped'], Comment: ['<id> carousel popped bolt needs Loctite']
# Type: [maintie_gold.Bolt], Label: ['116_bolt'], Comment: ['<id> carousel popped bolt needs Loctite']
#
# Result 204:
# Type: [maintie_gold.NotReading], Label: ['169_not_reading'], Comment: ['<id> change out position <num> tyre - sensor not reading']
# Type: [maintie_gold.Sensor], Label: ['169_sensor'], Comment: ['<id> change out position <num> tyre - sensor not reading']
#
# Result 205:
# Type: [maintie_gold.Flat], Label: ['189_flat'], Comment: ['<id> change position <num> flat tyre']
# Type: [maintie_gold.Tyre], Label: ['189_tyre'], Comment: ['<id> change position <num> flat tyre']
#
# Result 206:
# Type: [maintie_gold.Out], Label: ['259_out'], Comment: ['<id> dogbone pin out']
# Type: [maintie_gold.Pin], Label: ['259_pin'], Comment: ['<id> dogbone pin out']
#
# Result 207:
# Type: [maintie_gold.Out], Label: ['368_out'], Comment: ['VIMS keypad light out']
# Type: [maintie_gold.Light], Label: ['368_light'], Comment: ['VIMS keypad light out']
#
# Result 208:
# Type: [maintie_gold.Tripped], Label: ['286_tripped'], Comment: ['drag tripped on electrical']
# Type: [maintie_gold.Drag], Label: ['286_drag'], Comment: ['drag tripped on electrical']
#
# Result 209:
# Type: [maintie_gold.WiredIncorrectly], Label: ['301_wired_incorrectly'], Comment: ['hoist motor <num> RTD wired incorrectly']
# Type: [maintie_gold.Rtd], Label: ['301_RTD'], Comment: ['hoist motor <num> RTD wired incorrectly']
#
# Result 210:
# Type: [maintie_gold.SoundsContinuously], Label: ['349_sounds_continuously'], Comment: ['<id> park brake alarm sounds continuously']
# Type: [maintie_gold.Alarm], Label: ['349_alarm'], Comment: ['<id> park brake alarm sounds continuously']
#
# Result 211:
# Type: [maintie_gold.Require], Label: ['381_require'], Comment: ['rear door struts require replacing']
# Type: [maintie_gold.Replacing], Label: ['381_replacing'], Comment: ['rear door struts require replacing']
#
# Result 212:
# Type: [maintie_gold.Require], Label: ['444_require'], Comment: ['steering hub caps require replacing']
# Type: [maintie_gold.Replacing], Label: ['444_replacing'], Comment: ['steering hub caps require replacing']
#
# Result 213:
# Type: [maintie_gold.NotMeshing], Label: ['382_not_meshing'], Comment: ['mechanical - PTO not meshing']
# Type: [maintie_gold.Pto], Label: ['382_PTO'], Comment: ['mechanical - PTO not meshing']
#
# Result 214:
# Type: [maintie_gold.No], Label: ['391_no'], Comment: ['<id> tail pulley has no grease lines']
# Type: [maintie_gold.GreaseLines], Label: ['391_grease_lines'], Comment: ['<id> tail pulley has no grease lines']
#
# Result 215:
# Type: [maintie_gold.No], Label: ['755_no'], Comment: ['<id> <id> steering pin no grease text']
# Type: [maintie_gold.Grease], Label: ['755_grease'], Comment: ['<id> <id> steering pin no grease text']
#
# Result 216:
# Type: [maintie_gold.No], Label: ['817_no'], Comment: ['batteries have no charge']
# Type: [maintie_gold.Charge], Label: ['817_charge'], Comment: ['batteries have no charge']
#
# Result 217:
# Type: [maintie_gold.Trip], Label: ['431_trip'], Comment: ['synchronous motor <num> trip']
# Type: [maintie_gold.SynchronousMotor], Label: ['431_synchronous_motor'], Comment: ['synchronous motor <num> trip']
#
# Result 218:
# Type: [maintie_gold.Trip], Label: ['1061_trip'], Comment: ['transformer trip']
# Type: [maintie_gold.Transformer], Label: ['1061_transformer'], Comment: ['transformer trip']
#
# Result 219:
# Type: [maintie_gold.NotCounting], Label: ['449_not_counting'], Comment: ['swing resolver not counting']
# Type: [maintie_gold.Resolver], Label: ['449_resolver'], Comment: ['swing resolver not counting']
#
# Result 220:
# Type: [maintie_gold.Fail], Label: ['625_fail'], Comment: ['<id> - grease system fail']
# Type: [maintie_gold.GreaseSystem], Label: ['625_grease_system'], Comment: ['<id> - grease system fail']
#
# Result 221:
# Type: [maintie_gold.Blocked], Label: ['694_blocked'], Comment: ['<id> - replace blocked dryer']
# Type: [maintie_gold.Dryer], Label: ['694_dryer'], Comment: ['<id> - replace blocked dryer']
#
# Result 222:
# Type: [maintie_gold.Blocked], Label: ['959_blocked'], Comment: ['radiator blocked with grass']
# Type: [maintie_gold.Grass], Label: ['959_grass'], Comment: ['radiator blocked with grass']
#
# Result 223:
# Type: [maintie_gold.Snapped], Label: ['771_snapped'], Comment: ['<id> CW engine water pump snapped shaft']
# Type: [maintie_gold.Shaft], Label: ['771_shaft'], Comment: ['<id> CW engine water pump snapped shaft']
#
# Result 224:
# Type: [maintie_gold.Melted], Label: ['859_melted'], Comment: ['constant voltage transformer melted']
# Type: [maintie_gold.ConstantVoltageTransformer], Label: ['859_constant_voltage_transformer'], Comment: ['constant voltage transformer melted']
#
# Result 225:
# Type: [maintie_gold.Shorted], Label: ['1029_shorted'], Comment: ['replace shorted diode RPC <num>']
# Type: [maintie_gold.Diode], Label: ['1029_diode'], Comment: ['replace shorted diode RPC <num>']
#
# Result 226:
# Type: [maintie_gold.NotCommunicating], Label: ['1060_not_communicating'], Comment: ['troubleshoot smart meter not communicating']
# Type: [maintie_gold.SmartMeter], Label: ['1060_smart_meter'], Comment: ['troubleshoot smart meter not communicating']

# %% [markdown]
# **Find all the `FailedStates` of a specific object based on its descendants**

# %%
# %%sparql_query
# """
# PREFIX rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#>
# PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
# PREFIX owl: <http://www.w3.org/2002/07/owl#>
#
# SELECT ?acInstance ?failedStateInstance
# WHERE {
#   # Find subclasses of AirConditioner
#   ?subclass rdfs:subClassOf* <file://ONTOLOGY_NAME#AirConditioner> .
#
#   # Find instances of these subclasses
#   ?acInstance rdf:type ?subclass .
#
#   # Find subclasses of FailedState
#   ?subclassFailedState rdfs:subClassOf* <file://ONTOLOGY_NAME#FailedState> .
#
#   # Find instances of FailedState
#   ?failedStateInstance rdf:type ?subclassFailedState .
#
#   # Assuming there is a property that associates AirConditioner with State
#   ?failedStateInstance <file://ONTOLOGY_NAME#has_patient> ?acInstance .
# }
# """
# Out:
# Results found: 2
#
# [[maintie_gold.0LODB56W, maintie_gold.F62DSA72], [maintie_gold.U48IZ5BD, maintie_gold.058FJELD]]
#
# Result 1:
# Type: [maintie_gold.AirConditioner], Label: ['2_air_conditioner'], Comment: ['<id> air conditioner unserviceable']
# Type: [maintie_gold.Unserviceable], Label: ['2_unserviceable'], Comment: ['<id> air conditioner unserviceable']
#
# Result 2:
# Type: [maintie_gold.AirConditioner], Label: ['3_air_conditioner'], Comment: ['<id> air conditioner unserviceable when stationary']
# Type: [maintie_gold.Unserviceable], Label: ['3_unserviceable'], Comment: ['<id> air conditioner unserviceable when stationary']

# %% [markdown]
# **Find all the `UndesirableStates` of a specific object based on its descendants**
# - WIP: Need to figure out `FILTER` clause

# %%
# %%sparql_query
# """
# PREFIX rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#>
# PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
# PREFIX owl: <http://www.w3.org/2002/07/owl#>
#
# SELECT ?acInstance ?undesirableStateInstance
# WHERE {
#   # Find subclasses of AirConditioner
#   ?subclass rdfs:subClassOf* <file://ONTOLOGY_NAME#AirConditioner> .
#   ?acInstance rdf:type ?subclass .
#
#   # Find subclasses of UndesirableState
#   ?subclassUndesirableState rdfs:subClassOf* <file://ONTOLOGY_NAME#UndesirableState> .
#
#   # Exclude FailedState explicitly
#   FILTER (?subclassUndesirableState != <file://ONTOLOGY_NAME#FailedState>)
#
#   # Find instances of UndesirableState
#   ?undesirableStateInstance rdf:type ?subclassUndesirableState .
#
#   # Assuming there is a property that associates AirConditioner with State
#   ?undesirableStateInstance <file://ONTOLOGY_NAME#has_patient> ?acInstance .
# }
# """
# Out:
# Results found: 10
#
# [[maintie_gold.0LODB56W, maintie_gold.F62DSA72], [maintie_gold.U48IZ5BD, maintie_gold.058FJELD], [maintie_gold.3DD9W9A5, maintie_gold.B9DNGOIZ], [maintie_gold.ZZ9F7FA6, maintie_gold.LEIC7ZK5], [maintie_gold.5X79W8W7, maintie_gold.CFI3W9LD], [maintie_gold.HF45P16A, maintie_gold.JH6IK2J1], [maintie_gold.2PX672L9, maintie_gold.HDK8VK8O], [maintie_gold.B4LUUU0I, maintie_gold.V4LS7DFJ], [maintie_gold.4EGCZY9B, maintie_gold.DOE2I1F5], [maintie_gold.4EGCZY9B, maintie_gold.RHQR5Y99]]
#
# Result 1:
# Type: [maintie_gold.AirConditioner], Label: ['2_air_conditioner'], Comment: ['<id> air conditioner unserviceable']
# Type: [maintie_gold.Unserviceable], Label: ['2_unserviceable'], Comment: ['<id> air conditioner unserviceable']
#
# Result 2:
# Type: [maintie_gold.AirConditioner], Label: ['3_air_conditioner'], Comment: ['<id> air conditioner unserviceable when stationary']
# Type: [maintie_gold.Unserviceable], Label: ['3_unserviceable'], Comment: ['<id> air conditioner unserviceable when stationary']
#
# Result 3:
# Type: [maintie_gold.AirConditioner], Label: ['4_air_conditioner'], Comment: ['<id> air conditioner warm']
# Type: [maintie_gold.Warm], Label: ['4_warm'], Comment: ['<id> air conditioner warm']
#
# Result 4:
# Type: [maintie_gold.AirConditioner], Label: ['521_air_conditioner'], Comment: ['<id> - air conditioner fault']
# Type: [maintie_gold.Fault], Label: ['521_fault'], Comment: ['<id> - air conditioner fault']
#
# Result 5:
# Type: [maintie_gold.AirConditioner], Label: ['522_air_conditioner'], Comment: ['<id> - air conditioner no good']
# Type: [maintie_gold.NoGood], Label: ['522_no_good'], Comment: ['<id> - air conditioner no good']
#
# Result 6:
# Type: [maintie_gold.AirConditioner], Label: ['797_air_conditioner'], Comment: ['<id> air conditioner fault']
# Type: [maintie_gold.Fault], Label: ['797_fault'], Comment: ['<id> air conditioner fault']
#
# Result 7:
# Type: [maintie_gold.AirConditioner], Label: ['798_air_conditioner'], Comment: ['<id> air conditioner needs a boost not cold']
# Type: [maintie_gold.NotCold], Label: ['798_not_cold'], Comment: ['<id> air conditioner needs a boost not cold']
#
# Result 8:
# Type: [maintie_gold.AirConditioner], Label: ['799_air_conditioner'], Comment: ['<id> air conditioner not cold PO']
# Type: [maintie_gold.NotCold], Label: ['799_not_cold'], Comment: ['<id> air conditioner not cold PO']
#
# Result 9:
# Type: [maintie_gold.AirConditioner], Label: ['800_air_conditioner'], Comment: ['<id> air conditioner not cold electrical faults']
# Type: [maintie_gold.ElectricalFaults], Label: ['800_electrical_faults'], Comment: ['<id> air conditioner not cold electrical faults']
#
# Result 10:
# Type: [maintie_gold.AirConditioner], Label: ['800_air_conditioner'], Comment: ['<id> air conditioner not cold electrical faults']
# Type: [maintie_gold.NotCold], Label: ['800_not_cold'], Comment: ['<id> air conditioner not cold electrical faults']

# %% [markdown]
# **Find all the fault types on AirConditioners**

# %%
# %%sparql_query
# """
# PREFIX rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#>
# PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
# PREFIX owl: <http://www.w3.org/2002/07/owl#>
#
# SELECT ?acInstance ?faultInstance
# WHERE {
#   # Find subclasses of AirConditioner
#   ?subclass rdfs:subClassOf* <file://ONTOLOGY_NAME#AirConditioner> .
#   ?acInstance rdf:type ?subclass .
#
#   # Find subclasses of Fault
#   ?subclassFaultState rdfs:subClassOf* <file://ONTOLOGY_NAME#Fault> .
#
#   # Find instances of subclassFaultState
#   ?faultInstance rdf:type ?subclassFaultState .
#
#   # Assuming there is a property that associates AirConditioner with State
#   ?faultInstance <file://ONTOLOGY_NAME#has_patient> ?acInstance .
# }
# """
# Out:
# Results found: 2
#
# [[maintie_gold.ZZ9F7FA6, maintie_gold.LEIC7ZK5], [maintie_gold.HF45P16A, maintie_gold.JH6IK2J1]]
#
# Result 1:
# Type: [maintie_gold.AirConditioner], Label: ['521_air_conditioner'], Comment: ['<id> - air conditioner fault']
# Type: [maintie_gold.Fault], Label: ['521_fault'], Comment: ['<id> - air conditioner fault']
#
# Result 2:
# Type: [maintie_gold.AirConditioner], Label: ['797_air_conditioner'], Comment: ['<id> air conditioner fault']
# Type: [maintie_gold.Fault], Label: ['797_fault'], Comment: ['<id> air conditioner fault']

# %% [markdown]
# **Find types of faults**

# %%
# %%sparql_query
# """
# PREFIX rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#>
# PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
# PREFIX owl: <http://www.w3.org/2002/07/owl#>
#
# SELECT ?faultInstance # ?objectInstance # (COUNT(*) AS ?count)
# WHERE {
#   # Find subclasses of Fault
#   ?subclassFaultState rdfs:subClassOf* <file://ONTOLOGY_NAME#Fault> .
#
#   # Find instances of subclassFaultState
#   ?faultInstance rdf:type ?subclassFaultState .
#
#   # Assuming there is a property that associates fault with object instances
#   ?faultInstance <file://ONTOLOGY_NAME#has_patient> ?objectInstance .
# }
# """
# Out:
# Results found: 48
#
# [[maintie_gold.XXW0T72N], [maintie_gold.U5OGJSNX], [maintie_gold.GYU88S1D], [maintie_gold.PDV971K0], [maintie_gold.3OL7S8KN], [maintie_gold.JS74DUQB], [maintie_gold.8BAKKJMA], [maintie_gold.U0GURZXF], [maintie_gold.1ME5TEWB], [maintie_gold.LWSUREM8], [maintie_gold.MZRN7A2E], [maintie_gold.61C4WGFF], [maintie_gold.9KT3WH0R], [maintie_gold.5UO12G3E], [maintie_gold.LXND413V], [maintie_gold.U8LRHR7N], [maintie_gold.1IEI4TAH], [maintie_gold.ZHXPPXL7], [maintie_gold.B3FGZRC0], [maintie_gold.R9QP8GN9], [maintie_gold.8458LZGM], [maintie_gold.W1GWKDJ8], [maintie_gold.QGN36E9A], [maintie_gold.VLZ6MY6G], [maintie_gold.LEIC7ZK5], [maintie_gold.XUCIRZTX], [maintie_gold.FWOQPPWO], [maintie_gold.KH99RZ7K], [maintie_gold.K5SHO7MD], [maintie_gold.5JXPQGA3], [maintie_gold.NH4LL9BF], [maintie_gold.JH6IK2J1], [maintie_gold.YUM7MEOE], [maintie_gold.WCJPPY6S], [maintie_gold.YVSIQJ15], [maintie_gold.GGKU7YPF], [maintie_gold.ZZ2DYHCW], [maintie_gold.CPMATP35], [maintie_gold.0SESQJPW], [maintie_gold.QUELMUHI], [maintie_gold.AGASTI9O], [maintie_gold.58XLJUG6], [maintie_gold.4XCECL6U], [maintie_gold.9J1RYO53], [maintie_gold.V3NMFNZU], [maintie_gold.QCQEYCIO], [maintie_gold.IE9LASXI], [maintie_gold.0QGJIL1D]]
#
# Result 1:
# Type: [maintie_gold.Fault], Label: ['10_fault'], Comment: ['<id> air horn fault']
#
# Result 2:
# Type: [maintie_gold.Fault], Label: ['39_fault'], Comment: ['<id> axle temperature sensor fault']
#
# Result 3:
# Type: [maintie_gold.Fault], Label: ['115_fault'], Comment: ['<id> camera fault']
#
# Result 4:
# Type: [maintie_gold.Fault], Label: ['117_fault'], Comment: ['<id> centrifugal oil filter fault']
#
# Result 5:
# Type: [maintie_gold.Fault], Label: ['205_fault'], Comment: ['<id> contactor fault']
#
# Result 6:
# Type: [maintie_gold.Fault], Label: ['247_fault'], Comment: ['<id> diagnose engine fault']
#
# Result 7:
# Type: [maintie_gold.Fault], Label: ['267_fault'], Comment: ['<id> drivers window fault']
#
# Result 8:
# Type: [maintie_gold.Fault], Label: ['273_fault'], Comment: ['<id> electrical harness fault']
#
# Result 9:
# Type: [maintie_gold.Fault], Label: ['325_fault'], Comment: ['IOV fault on drag package']
#
# Result 10:
# Type: [maintie_gold.Fault], Label: ['364_fault'], Comment: ['<id> investigate / repair no gear fault']
#
# Result 11:
# Type: [maintie_gold.Fault], Label: ['375_fault'], Comment: ['diagnose and repair ladder fault']
#
# Result 12:
# Type: [maintie_gold.Fault], Label: ['404_fault'], Comment: ['drag generator fault']
#
# Result 13:
# Type: [maintie_gold.Fault], Label: ['415_fault'], Comment: ['<id> grease system fault']
#
# Result 14:
# Type: [maintie_gold.Fault], Label: ['417_fault'], Comment: ['<id> investigate auto-lube fault']
#
# Result 15:
# Type: [maintie_gold.Fault], Label: ['430_fault'], Comment: ['<id> repair brake fault']
#
# Result 16:
# Type: [maintie_gold.Fault], Label: ['434_fault'], Comment: ['walk motor <num> brake fault']
#
# Result 17:
# Type: [maintie_gold.Fault], Label: ['436_fault'], Comment: ['<id> tray fault']
#
# Result 18:
# Type: [maintie_gold.Fault], Label: ['450_fault'], Comment: ['<id> repair gear fault']
#
# Result 19:
# Type: [maintie_gold.Fault], Label: ['451_fault'], Comment: ['<id> repair air conditioner and wiring fault']
#
# Result 20:
# Type: [maintie_gold.Fault], Label: ['453_fault'], Comment: ['swing resolver fault']
#
# Result 21:
# Type: [maintie_gold.Fault], Label: ['455_fault'], Comment: ['drag chain fault']
#
# Result 22:
# Type: [maintie_gold.Fault], Label: ['507_fault'], Comment: ['<id> - Tele-Remote camera fault']
#
# Result 23:
# Type: [maintie_gold.Fault], Label: ['508_fault'], Comment: ['<id> - Tele-Remote cameras fault - text -']
#
# Result 24:
# Type: [maintie_gold.Fault], Label: ['509_fault'], Comment: ['<id> - Tele-Remote fault']
#
# Result 25:
# Type: [maintie_gold.Fault], Label: ['521_fault'], Comment: ['<id> - air conditioner fault']
#
# Result 26:
# Type: [maintie_gold.Fault], Label: ['626_fault'], Comment: ['<id> - grease system fault']
#
# Result 27:
# Type: [maintie_gold.Fault], Label: ['652_fault'], Comment: ['<id> - ladder fault']
#
# Result 28:
# Type: [maintie_gold.Fault], Label: ['658_fault'], Comment: ['<id> - lube fault']
#
# Result 29:
# Type: [maintie_gold.Fault], Label: ['666_fault'], Comment: ['<id> - park brake fault']
#
# Result 30:
# Type: [maintie_gold.Fault], Label: ['687_fault'], Comment: ['<id> - repair transmission fault']
#
# Result 31:
# Type: [maintie_gold.Fault], Label: ['784_fault'], Comment: ['<id> Tele-Remote fault']
#
# Result 32:
# Type: [maintie_gold.Fault], Label: ['797_fault'], Comment: ['<id> air conditioner fault']
#
# Result 33:
# Type: [maintie_gold.Fault], Label: ['1067_fault'], Comment: ['voltage regulator fuse fault']
#
# Result 34:
# Type: [maintie_gold.SlippingFault], Label: ['249_slipping_fault'], Comment: ['<id> diagnose transmission slipping fault']
#
# Result 35:
# Type: [maintie_gold.GroundFault], Label: ['377_ground_fault'], Comment: ['ground fault welding board']
#
# Result 36:
# Type: [maintie_gold.GroundFault], Label: ['403_ground_fault'], Comment: ['ground fault in propel']
#
# Result 37:
# Type: [maintie_gold.OverchargeFault], Label: ['26_overcharge_fault'], Comment: ['<id> alternator overcharge fault']
#
# Result 38:
# Type: [maintie_gold.OverloadFault], Label: ['914_overload_fault'], Comment: ['investigate main transformer overload fault']
#
# Result 39:
# Type: [maintie_gold.ShutdownFault], Label: ['613_shutdown_fault'], Comment: ['<id> - engine shutdown fault']
#
# Result 40:
# Type: [maintie_gold.ShutdownFault], Label: ['743_shutdown_fault'], Comment: ['<id> <id> engine shutdown fault']
#
# Result 41:
# Type: [maintie_gold.TemperatureFault], Label: ['38_temperature_fault'], Comment: ['<id> axle temperature fault']
#
# Result 42:
# Type: [maintie_gold.TemperatureFault], Label: ['756_temperature_fault'], Comment: ['<id> <id> transmission temperature fault']
#
# Result 43:
# Type: [maintie_gold.PressureFault], Label: ['203_pressure_fault'], Comment: ['<id> chord pressure fault']
#
# Result 44:
# Type: [maintie_gold.PressureFault], Label: ['384_pressure_fault'], Comment: ['swing brake pressure fault']
#
# Result 45:
# Type: [maintie_gold.AlarmFault], Label: ['356_alarm_fault'], Comment: ['<id> park brake alarm fault']
#
# Result 46:
# Type: [maintie_gold.OverheatFault], Label: ['248_overheat_fault'], Comment: ['<id> diagnose transmission overheat fault']
#
# Result 47:
# Type: [maintie_gold.ReleaseFault], Label: ['95_release_fault'], Comment: ['<id> brake release fault']
#
# Result 48:
# Type: [maintie_gold.IntermittentFault], Label: ['747_intermittent_fault'], Comment: ['<id> <id> grease system has intermittent fault']

# %% [markdown]
# **Find all of the parts of pumps that are in FailedStates**

# %%
# %%sparql_query
# """
# PREFIX rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#>
# PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
# PREFIX owl: <http://www.w3.org/2002/07/owl#>
#
# SELECT ?pumpInstance ?part ?failedStateInstance
# WHERE {
#   # Find subclasses of Pump
#   ?subclass rdfs:subClassOf* <file://ONTOLOGY_NAME#Pump> .
#
#   # Find instances of these subclasses
#   ?pumpInstance rdf:type ?subclass .
#
#   # Find instances of
#   ?pumpInstance <file://ONTOLOGY_NAME#has_part> ?part .
#
#   # Find subclasses of FailedState
#   ?subclassFailedState rdfs:subClassOf* <file://ONTOLOGY_NAME#FailedState> .
#
#   # Find instances of FailedState
#   ?failedStateInstance rdf:type ?subclassFailedState .
#
#   # Assuming there is a property that associates Pump with State
#   ?failedStateInstance <file://ONTOLOGY_NAME#has_patient> ?part .
# }
# """
# Out:
# Results found: 7
#
# [[maintie_gold.L3LL22IE, maintie_gold.ZQ6U8D4C, maintie_gold.PV8XM1UP], [maintie_gold.M3LX09M4, maintie_gold.GX39BIIL, maintie_gold.XB1T4W82], [maintie_gold.AYXX9F3U, maintie_gold.98T97J9A, maintie_gold.GCBQMFO5], [maintie_gold.A99BPUV6, maintie_gold.DOJ0E238, maintie_gold.AYD16229], [maintie_gold.NU6IFPB8, maintie_gold.QOORX1A3, maintie_gold.X03YG27Z], [maintie_gold.HO242CHB, maintie_gold.YZ19VABZ, maintie_gold.WTYZXTCL], [maintie_gold.5ZDL63W9, maintie_gold.VOSOEDZA, maintie_gold.X2RMX5QO]]
#
# Result 1:
# Type: [maintie_gold.Pump], Label: ['80_pump'], Comment: ['<id> blown steering pump hose']
# Type: [maintie_gold.Hose], Label: ['80_hose'], Comment: ['<id> blown steering pump hose']
# Type: [maintie_gold.Blown], Label: ['80_blown'], Comment: ['<id> blown steering pump hose']
#
# Result 2:
# Type: [maintie_gold.Pump], Label: ['131_pump'], Comment: ['<id> change out blown o-ring on steering pump']
# Type: [maintie_gold.Oring], Label: ['131_oring'], Comment: ['<id> change out blown o-ring on steering pump']
# Type: [maintie_gold.Blown], Label: ['131_blown'], Comment: ['<id> change out blown o-ring on steering pump']
#
# Result 3:
# Type: [maintie_gold.Pump], Label: ['134_pump'], Comment: ['<id> change out broken bolt on brake pump']
# Type: [maintie_gold.Bolt], Label: ['134_bolt'], Comment: ['<id> change out broken bolt on brake pump']
# Type: [maintie_gold.Broken], Label: ['134_broken'], Comment: ['<id> change out broken bolt on brake pump']
#
# Result 4:
# Type: [maintie_gold.Pump], Label: ['350_pump'], Comment: ['system <id> pump pressure gauge not working']
# Type: [maintie_gold.PressureGauge], Label: ['350_pressure_gauge'], Comment: ['system <id> pump pressure gauge not working']
# Type: [maintie_gold.NotWorking], Label: ['350_not_working'], Comment: ['system <id> pump pressure gauge not working']
#
# Result 5:
# Type: [maintie_gold.Pump], Label: ['473_pump'], Comment: ['<id> replace blown main pump hose']
# Type: [maintie_gold.Hose], Label: ['473_hose'], Comment: ['<id> replace blown main pump hose']
# Type: [maintie_gold.Blown], Label: ['473_blown'], Comment: ['<id> replace blown main pump hose']
#
# Result 6:
# Type: [maintie_gold.Pump], Label: ['932_pump'], Comment: ['number <num> slew pump contamination switch unserviceable']
# Type: [maintie_gold.ContaminationSwitch], Label: ['932_contamination_switch'], Comment: ['number <num> slew pump contamination switch unserviceable']
# Type: [maintie_gold.Unserviceable], Label: ['932_unserviceable'], Comment: ['number <num> slew pump contamination switch unserviceable']
#
# Result 7:
# Type: [maintie_gold.WaterPump], Label: ['771_water_pump'], Comment: ['<id> CW engine water pump snapped shaft']
# Type: [maintie_gold.Shaft], Label: ['771_shaft'], Comment: ['<id> CW engine water pump snapped shaft']
# Type: [maintie_gold.Snapped], Label: ['771_snapped'], Comment: ['<id> CW engine water pump snapped shaft']

# %% [markdown]
# **Find all the parts of an object (Pump)**

# %%
# %%sparql_query
# """
# PREFIX rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#>
# PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
# PREFIX owl: <http://www.w3.org/2002/07/owl#>
#
# SELECT ?part  # ?pumpInstance
# WHERE {
#   # Find subclasses of Pump
#   ?subclass rdfs:subClassOf* <file://ONTOLOGY_NAME#Pump> .
#
#   # Find instances of these subclasses
#   ?pumpInstance rdf:type ?subclass .
#
#   # Find instances of parts
#   ?pumpInstance <file://ONTOLOGY_NAME#has_part> ?part .
# }
# """
# Out:
# Results found: 20
#
# [[maintie_gold.ZQ6U8D4C], [maintie_gold.GX39BIIL], [maintie_gold.98T97J9A], [maintie_gold.OLD3BUHK], [maintie_gold.DOJ0E238], [maintie_gold.FU2LB3L1], [maintie_gold.QOORX1A3], [maintie_gold.NHGPUYGR], [maintie_gold.S1RYQV6J], [maintie_gold.EV8RHTDV], [maintie_gold.QG8DCNYQ], [maintie_gold.I6638LRB], [maintie_gold.YZ19VABZ], [maintie_gold.IYRO9C2H], [maintie_gold.492U03ZQ], [maintie_gold.YI3M3N22], [maintie_gold.EF0QEHUY], [maintie_gold.V8XIHJRX], [maintie_gold.B056L76L], [maintie_gold.VOSOEDZA]]
#
# Result 1:
# Type: [maintie_gold.Hose], Label: ['80_hose'], Comment: ['<id> blown steering pump hose']
#
# Result 2:
# Type: [maintie_gold.Oring], Label: ['131_oring'], Comment: ['<id> change out blown o-ring on steering pump']
#
# Result 3:
# Type: [maintie_gold.Bolt], Label: ['134_bolt'], Comment: ['<id> change out broken bolt on brake pump']
#
# Result 4:
# Type: [maintie_gold.Motor], Label: ['258_motor'], Comment: ['<id> differential pump motor hose leaking']
#
# Result 5:
# Type: [maintie_gold.PressureGauge], Label: ['350_pressure_gauge'], Comment: ['system <id> pump pressure gauge not working']
#
# Result 6:
# Type: [maintie_gold.LubeSystem], Label: ['401_lube_system'], Comment: ['replace lube system <id> drag rope pump']
#
# Result 7:
# Type: [maintie_gold.Hose], Label: ['473_hose'], Comment: ['<id> replace blown main pump hose']
#
# Result 8:
# Type: [maintie_gold.CoolingFan], Label: ['574_cooling_fan'], Comment: ['<id> - change out pump cooling fan engine']
#
# Result 9:
# Type: [maintie_gold.UniversalJoints], Label: ['594_universal_joints'], Comment: ['<id> - change out universal joints engine - pump drag']
#
# Result 10:
# Type: [maintie_gold.DriveShaft], Label: ['596_drive_shaft'], Comment: ['<id> - change out universal joints engine - pump drive shaft']
#
# Result 11:
# Type: [maintie_gold.ChipSensor], Label: ['924_chip_sensor'], Comment: ['left hand PTO pump chip sensor harness unserviceable']
#
# Result 12:
# Type: [maintie_gold.ContaminationSwitch], Label: ['930_contamination_switch'], Comment: ['number <num> pump contamination switch on']
#
# Result 13:
# Type: [maintie_gold.ContaminationSwitch], Label: ['932_contamination_switch'], Comment: ['number <num> slew pump contamination switch unserviceable']
#
# Result 14:
# Type: [maintie_gold.Cavity], Label: ['945_cavity'], Comment: ['position <num> pump cavity low']
#
# Result 15:
# Type: [maintie_gold.Drive], Label: ['954_drive'], Comment: ['pump drive box coupling and shaft unserviceable']
#
# Result 16:
# Type: [maintie_gold.ChipIndicator], Label: ['1003_chip_indicator'], Comment: ['replace all pump chip indicator cables']
#
# Result 17:
# Type: [maintie_gold.ContaminationSwitch], Label: ['1024_contamination_switch'], Comment: ['replace left hand slew pump contamination switch']
#
# Result 18:
# Type: [maintie_gold.ChipSensor], Label: ['1027_chip_sensor'], Comment: ['replace right hand swing pump chip sensor']
#
# Result 19:
# Type: [maintie_gold.Coupling], Label: ['429_coupling'], Comment: ['replace hydraulic pump coupling']
#
# Result 20:
# Type: [maintie_gold.Shaft], Label: ['771_shaft'], Comment: ['<id> CW engine water pump snapped shaft']

# %% [markdown]
# **Who is performing what activities?**

# %%
# %%sparql_query
# """
# PREFIX rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#>
# PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
# PREFIX owl: <http://www.w3.org/2002/07/owl#>
#
# SELECT ?agentInstance ?activityInstance ?objectInstance
# WHERE {
#     # Find subclasses of Person
#     ?subclass rdfs:subClassOf* <file://ONTOLOGY_NAME#Person> .
#
#     ?agentInstance rdf:type ?subclass .
#
#     # Find instances of activities
#     ?activityInstance <file://ONTOLOGY_NAME#has_agent> ?agentInstance .
#
#     # Find instances of objects
#     ?activityInstance <file://ONTOLOGY_NAME#has_patient> ?objectInstance .
# }
# """
# Out:
# Results found: 11
#
# [[maintie_gold.B2SQL2WH, maintie_gold.OLKXOPGN, maintie_gold.A3RO36SG], [maintie_gold.XUKVHPH4, maintie_gold.ZBS5JJP2, maintie_gold.X2CE4SP8], [maintie_gold.GVWSFIYQ, maintie_gold.K8KXCTN1, maintie_gold.DLJ9M32W], [maintie_gold.RHUOQE1Z, maintie_gold.8GE4GQ2E, maintie_gold.TXVQX4EN], [maintie_gold.691JAWC0, maintie_gold.EOW375FV, maintie_gold.2INKJTOJ], [maintie_gold.KBY9IECW, maintie_gold.H7Z29KBI, maintie_gold.OFYRXCSF], [maintie_gold.9B735MHQ, maintie_gold.Z4EJNZY7, maintie_gold.7OSPP2HM], [maintie_gold.CD0G4WUB, maintie_gold.TTS0BAVY, maintie_gold.7JTA292Q], [maintie_gold.SZC93AXY, maintie_gold.SYJAP6YW, maintie_gold.PUY0YT0I], [maintie_gold.SZC93AXY, maintie_gold.TCJI8JBX, maintie_gold.PUY0YT0I], [maintie_gold.SN2NFC4J, maintie_gold.XP9I0R8D, maintie_gold.Z1V8IB2J]]
#
# Result 1:
# Type: [maintie_gold.Boilermaker], Label: ['84_boilermaker'], Comment: ['<id> boilermaker repairs to bucket assembly']
# Type: [maintie_gold.Repairs], Label: ['84_repairs'], Comment: ['<id> boilermaker repairs to bucket assembly']
# Type: [maintie_gold.Bucket], Label: ['84_bucket'], Comment: ['<id> boilermaker repairs to bucket assembly']
#
# Result 2:
# Type: [maintie_gold.Boilermaker], Label: ['85_boilermaker'], Comment: ['<id> boilermaker repairs to engine cover']
# Type: [maintie_gold.Repairs], Label: ['85_repairs'], Comment: ['<id> boilermaker repairs to engine cover']
# Type: [maintie_gold.Cover], Label: ['85_cover'], Comment: ['<id> boilermaker repairs to engine cover']
#
# Result 3:
# Type: [maintie_gold.Boilermaker], Label: ['86_boilermaker'], Comment: ['<id> boilermaker repairs to exhaust area']
# Type: [maintie_gold.Repairs], Label: ['86_repairs'], Comment: ['<id> boilermaker repairs to exhaust area']
# Type: [maintie_gold.Exhaust], Label: ['86_exhaust'], Comment: ['<id> boilermaker repairs to exhaust area']
#
# Result 4:
# Type: [maintie_gold.Boilermakers], Label: ['87_boilermakers'], Comment: ['<id> boilermakers to repair bucket']
# Type: [maintie_gold.Repair], Label: ['87_repair'], Comment: ['<id> boilermakers to repair bucket']
# Type: [maintie_gold.Bucket], Label: ['87_bucket'], Comment: ['<id> boilermakers to repair bucket']
#
# Result 5:
# Type: [maintie_gold.Boilermakers], Label: ['88_boilermakers'], Comment: ['<id> boilermakers to repair cooler frame']
# Type: [maintie_gold.Repair], Label: ['88_repair'], Comment: ['<id> boilermakers to repair cooler frame']
# Type: [maintie_gold.Frame], Label: ['88_frame'], Comment: ['<id> boilermakers to repair cooler frame']
#
# Result 6:
# Type: [maintie_gold.Boilermakers], Label: ['89_boilermakers'], Comment: ['<id> boilermakers to repair plate over proximity switch']
# Type: [maintie_gold.Repair], Label: ['89_repair'], Comment: ['<id> boilermakers to repair plate over proximity switch']
# Type: [maintie_gold.Plate], Label: ['89_plate'], Comment: ['<id> boilermakers to repair plate over proximity switch']
#
# Result 7:
# Type: [maintie_gold.Ezihose], Label: ['502_Ezihose'], Comment: ['<id> - Ezi-hose modifications to module']
# Type: [maintie_gold.Modifications], Label: ['502_modifications'], Comment: ['<id> - Ezi-hose modifications to module']
# Type: [maintie_gold.Module], Label: ['502_module'], Comment: ['<id> - Ezi-hose modifications to module']
#
# Result 8:
# Type: [maintie_gold.Ezihose], Label: ['775_Ezihose'], Comment: ['<id> Ezi-hose to fit coolant meters']
# Type: [maintie_gold.Fit], Label: ['775_fit'], Comment: ['<id> Ezi-hose to fit coolant meters']
# Type: [maintie_gold.CoolantMeters], Label: ['775_coolant_meters'], Comment: ['<id> Ezi-hose to fit coolant meters']
#
# Result 9:
# Type: [maintie_gold.Liebherr], Label: ['778_Liebherr'], Comment: ['<id> Liebherr to supply and fit cabin mounts']
# Type: [maintie_gold.Fit], Label: ['778_fit'], Comment: ['<id> Liebherr to supply and fit cabin mounts']
# Type: [maintie_gold.Mounts], Label: ['778_mounts'], Comment: ['<id> Liebherr to supply and fit cabin mounts']
#
# Result 10:
# Type: [maintie_gold.Liebherr], Label: ['778_Liebherr'], Comment: ['<id> Liebherr to supply and fit cabin mounts']
# Type: [maintie_gold.Supply], Label: ['778_supply'], Comment: ['<id> Liebherr to supply and fit cabin mounts']
# Type: [maintie_gold.Mounts], Label: ['778_mounts'], Comment: ['<id> Liebherr to supply and fit cabin mounts']
#
# Result 11:
# Type: [maintie_gold.Fitters], Label: ['876_fitters'], Comment: ['disconnect motor for fitters to remove']
# Type: [maintie_gold.Remove], Label: ['876_remove'], Comment: ['disconnect motor for fitters to remove']
# Type: [maintie_gold.Motor], Label: ['876_motor'], Comment: ['disconnect motor for fitters to remove']

# %% [markdown]
# **Who performs the adjust activity on pumps?**

# %%
# %%sparql_query
# """
# PREFIX rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#>
# PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
# PREFIX owl: <http://www.w3.org/2002/07/owl#>
#
# SELECT ?pumpInstance ?agent
# WHERE {
#   # Find subclasses of Pump
#   ?subclass rdfs:subClassOf* <file://ONTOLOGY_NAME#Pump> .
#   ?pumpInstance rdf:type ?subclass .
#
#   # Find subclasses of Adjust
#   ?subclassAdjust rdfs:subClassOf* <file://ONTOLOGY_NAME#Adjust> .
#   ?adjustInstances rdf:type ?subclassAdjust .
#
#   # Assuming there is a property that associates Pump with Agent
#   ?adjustInstances <file://ONTOLOGY_NAME#has_agent> ?agent .
#
#   # Check if the adjustInstances has_patient pumpInstance
#   ?adjustInstances <file://ONTOLOGY_NAME#has_patient> ?pumpInstance .
# }
# """
# Out:
# No results found.

# %% [markdown]
# **What can be adjusted**

# %%
# %%sparql_query
# """
# PREFIX rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#>
# PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
# PREFIX owl: <http://www.w3.org/2002/07/owl#>
#
# SELECT ?adjustInstance ?physicalObject
# WHERE {
#   # Find subclasses of Adjust
#   ?subclassAdjust rdfs:subClassOf* <file://ONTOLOGY_NAME#Adjust> .
#
#   # Find instances of these subclasses
#   ?adjustInstance rdf:type ?subclassAdjust .
#
#   # Assuming there is a property that associates Adjust instances with a physical object
#   ?adjustInstance <file://ONTOLOGY_NAME#has_patient> ?physicalObject .
# }
# """
# Out:
# Results found: 8
#
# [[maintie_gold.1ULE68XJ, maintie_gold.6SFUVQ28], [maintie_gold.2X5FRT2V, maintie_gold.0BLKEDY0], [maintie_gold.KYA01O5F, maintie_gold.E2TU7Z8I], [maintie_gold.S57OO2IM, maintie_gold.7Z3SHUK7], [maintie_gold.LXYBQAT8, maintie_gold.VJS1S3DI], [maintie_gold.0NKN8VUJ, maintie_gold.7LQEMPSG], [maintie_gold.L8CCA8ZD, maintie_gold.Y0VSEZEH], [maintie_gold.09HRH3R0, maintie_gold.1YV6KG0G]]
#
# Result 1:
# Type: [maintie_gold.Adjust], Label: ['296_adjust'], Comment: ['adjust drag number <num> brakes to standard']
# Type: [maintie_gold.Brakes], Label: ['296_brakes'], Comment: ['adjust drag number <num> brakes to standard']
#
# Result 2:
# Type: [maintie_gold.Adjust], Label: ['326_adjust'], Comment: ['adjust brake pads']
# Type: [maintie_gold.Pads], Label: ['326_pads'], Comment: ['adjust brake pads']
#
# Result 3:
# Type: [maintie_gold.Adjust], Label: ['810_adjust'], Comment: ['adjust curtains <id>']
# Type: [maintie_gold.Curtains], Label: ['810_curtains'], Comment: ['adjust curtains <id>']
#
# Result 4:
# Type: [maintie_gold.Tighten], Label: ['733_tighten'], Comment: ['<id> - tighten bolts to transmission']
# Type: [maintie_gold.Bolts], Label: ['733_bolts'], Comment: ['<id> - tighten bolts to transmission']
#
# Result 5:
# Type: [maintie_gold.Retension], Label: ['779_retension'], Comment: ['<id> Loctite retension transmission mount']
# Type: [maintie_gold.Mount], Label: ['779_mount'], Comment: ['<id> Loctite retension transmission mount']
#
# Result 6:
# Type: [maintie_gold.Retension], Label: ['853_retension'], Comment: ['complete wheel retension']
# Type: [maintie_gold.Wheel], Label: ['853_wheel'], Comment: ['complete wheel retension']
#
# Result 7:
# Type: [maintie_gold.Alignment], Label: ['943_alignment'], Comment: ['perform wheel alignment']
# Type: [maintie_gold.Wheel], Label: ['943_wheel'], Comment: ['perform wheel alignment']
#
# Result 8:
# Type: [maintie_gold.Set], Label: ['1059_set'], Comment: ['start motorvator and set limits']
# Type: [maintie_gold.Limits], Label: ['1059_limits'], Comment: ['start motorvator and set limits']

# %% [markdown]
# **What activities do technicans perform?**

# %% [raw]
# %%sparql_query
# """
# PREFIX rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#>
# PREFIX owl: <http://www.w3.org/2002/07/owl#>
#
# SELECT ?technician ?associatedInstance
# WHERE {
#   # Find instances of the Technician class
#   ?technician rdf:type <file://ONTOLOGY_NAME#Technician> .
#
#   # Find instances where Technician is the object of the has_agent property
#   ?associatedInstance <file://ONTOLOGY_NAME#has_agent> ?technician .
# }
# """

# %% [markdown]
# **What activities do boilermakers perform?**

# %%
# %%sparql_query
# """
# PREFIX rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#>
#
# SELECT ?boilermaker ?activityInstance ?otherInstance
# WHERE {
#   # Find instances of the Boilermaker class
#   ?boilermaker rdf:type <file://ONTOLOGY_NAME#Boilermaker> .
#
#   # Find subclasses of Activity
#   ?subclassActivity rdfs:subClassOf* <file://ONTOLOGY_NAME#Activity> .
#
#   # Find instances of these subclasses that have Boilermaker as the object of the has_agent property
#   ?activityInstance rdf:type ?subclassActivity .
#   ?activityInstance <file://ONTOLOGY_NAME#has_agent> ?boilermaker .
#
#   # Find other instances where Boilermaker is the object of the has_patient property
#   ?activityInstance <file://ONTOLOGY_NAME#has_patient> ?otherInstance .
# }
# """
# Out:
# Results found: 3
#
# [[maintie_gold.B2SQL2WH, maintie_gold.OLKXOPGN, maintie_gold.A3RO36SG], [maintie_gold.XUKVHPH4, maintie_gold.ZBS5JJP2, maintie_gold.X2CE4SP8], [maintie_gold.GVWSFIYQ, maintie_gold.K8KXCTN1, maintie_gold.DLJ9M32W]]
#
# Result 1:
# Type: [maintie_gold.Boilermaker], Label: ['84_boilermaker'], Comment: ['<id> boilermaker repairs to bucket assembly']
# Type: [maintie_gold.Repairs], Label: ['84_repairs'], Comment: ['<id> boilermaker repairs to bucket assembly']
# Type: [maintie_gold.Bucket], Label: ['84_bucket'], Comment: ['<id> boilermaker repairs to bucket assembly']
#
# Result 2:
# Type: [maintie_gold.Boilermaker], Label: ['85_boilermaker'], Comment: ['<id> boilermaker repairs to engine cover']
# Type: [maintie_gold.Repairs], Label: ['85_repairs'], Comment: ['<id> boilermaker repairs to engine cover']
# Type: [maintie_gold.Cover], Label: ['85_cover'], Comment: ['<id> boilermaker repairs to engine cover']
#
# Result 3:
# Type: [maintie_gold.Boilermaker], Label: ['86_boilermaker'], Comment: ['<id> boilermaker repairs to exhaust area']
# Type: [maintie_gold.Repairs], Label: ['86_repairs'], Comment: ['<id> boilermaker repairs to exhaust area']
# Type: [maintie_gold.Exhaust], Label: ['86_exhaust'], Comment: ['<id> boilermaker repairs to exhaust area']

# %% [markdown]
# **Objects Contained in Another Object**

# %%
# %%sparql_query
# """
# SELECT ?container ?containedObject
# WHERE {
#   ?container <file://ONTOLOGY_NAME#contains> ?containedObject .
# }
# """
# Out:
# Results found: 38
#
# [[maintie_gold.2N40HDUM, maintie_gold.Z54DNHRH], [maintie_gold.HTH5TH22, maintie_gold.Z54DNHRH], [maintie_gold.QHATO22V, maintie_gold.IHMTZJ9V], [maintie_gold.9W5ZQO6C, maintie_gold.IHMTZJ9V], [maintie_gold.X7Q02ZKN, maintie_gold.T4HNB7P1], [maintie_gold.9PNVW5XG, maintie_gold.XG4KI424], [maintie_gold.55T566BF, maintie_gold.THXK9UFZ], [maintie_gold.DOP9G5ZL, maintie_gold.45I3QL0X], [maintie_gold.B8OTGY2P, maintie_gold.3SQMM2ZB], [maintie_gold.MPVY36Y2, maintie_gold.D2Z3V5GR], [maintie_gold.LIQT8KBS, maintie_gold.D2Z3V5GR], [maintie_gold.G72S2LGG, maintie_gold.RAQ9KYVJ], [maintie_gold.T2X82236, maintie_gold.RAQ9KYVJ], [maintie_gold.QY6SM03M, maintie_gold.2NK9CGD6], [maintie_gold.ED5AYXEZ, maintie_gold.0FHWSPQO], [maintie_gold.EH4M6997, maintie_gold.MYR4DVZH], [maintie_gold.IS6UJINM, maintie_gold.2NUQMDBY], [maintie_gold.MLE91ZI5, maintie_gold.HDI3192N], [maintie_gold.183PORKW, maintie_gold.IQJSLPUO], [maintie_gold.4YWT7ORE, maintie_gold.A7249PAR], [maintie_gold.34AEWAZC, maintie_gold.DQ2FPIZD], [maintie_gold.KN3U03AO, maintie_gold.6EV7IMIX], [maintie_gold.C3GERDAF, maintie_gold.44ELBN85], [maintie_gold.ZOMPY8HH, maintie_gold.4II8ZUMN], [maintie_gold.70Y5U1GH, maintie_gold.D9ZT1W2O], [maintie_gold.RWC6ASRE, maintie_gold.NREU8S5O], [maintie_gold.MT9N9WDZ, maintie_gold.4L95QAGB], [maintie_gold.4O00V48L, maintie_gold.BPSIHNEB], [maintie_gold.NZ1YPIWS, maintie_gold.L5WF7WDA], [maintie_gold.47PVZULN, maintie_gold.Q0A2F1R2], [maintie_gold.3SA0PKMB, maintie_gold.PYQ0LVOL], [maintie_gold.J6P9U4I9, maintie_gold.RJOULSEW], [maintie_gold.XD3GVIOE, maintie_gold.636JON2H], [maintie_gold.3149D54U, maintie_gold.W2UO74TB], [maintie_gold.RHREQXON, maintie_gold.ILFS9LOY], [maintie_gold.IZSARL2Y, maintie_gold.O12WZQBU], [maintie_gold.14SDI8DA, maintie_gold.F3RR65I3], [maintie_gold.DHW7N6G9, maintie_gold.S20WIW3W]]
#
# Result 1:
# Type: [maintie_gold.FinalDrive], Label: ['120_final_drive'], Comment: ['<id> change differential and final drive oils']
# Type: [maintie_gold.Oils], Label: ['120_oils'], Comment: ['<id> change differential and final drive oils']
#
# Result 2:
# Type: [maintie_gold.Differential], Label: ['120_differential'], Comment: ['<id> change differential and final drive oils']
# Type: [maintie_gold.Oils], Label: ['120_oils'], Comment: ['<id> change differential and final drive oils']
#
# Result 3:
# Type: [maintie_gold.Differential], Label: ['121_differential'], Comment: ['<id> change differential and hub oils']
# Type: [maintie_gold.Oils], Label: ['121_oils'], Comment: ['<id> change differential and hub oils']
#
# Result 4:
# Type: [maintie_gold.Hub], Label: ['121_hub'], Comment: ['<id> change differential and hub oils']
# Type: [maintie_gold.Oils], Label: ['121_oils'], Comment: ['<id> change differential and hub oils']
#
# Result 5:
# Type: [maintie_gold.Engine], Label: ['122_engine'], Comment: ['<id> change engine oil and inspect cooling system']
# Type: [maintie_gold.Oil], Label: ['122_oil'], Comment: ['<id> change engine oil and inspect cooling system']
#
# Result 6:
# Type: [maintie_gold.ThrustBearing], Label: ['126_thrust_bearing'], Comment: ['<id> change out <id> thrust bearing oil']
# Type: [maintie_gold.Oil], Label: ['126_oil'], Comment: ['<id> change out <id> thrust bearing oil']
#
# Result 7:
# Type: [maintie_gold.Engine], Label: ['196_engine'], Comment: ['<id> check / repair engine oil leak']
# Type: [maintie_gold.Oil], Label: ['196_oil'], Comment: ['<id> check / repair engine oil leak']
#
# Result 8:
# Type: [maintie_gold.Differential], Label: ['257_differential'], Comment: ['<id> differential oil leak']
# Type: [maintie_gold.Oil], Label: ['257_oil'], Comment: ['<id> differential oil leak']
#
# Result 9:
# Type: [maintie_gold.Engine], Label: ['264_engine'], Comment: ['<id> drain and sample engine oil']
# Type: [maintie_gold.Oil], Label: ['264_oil'], Comment: ['<id> drain and sample engine oil']
#
# Result 10:
# Type: [maintie_gold.Blower], Label: ['306_blower'], Comment: ['<id> swing motor blower lube inspect']
# Type: [maintie_gold.Lube], Label: ['306_lube'], Comment: ['<id> swing motor blower lube inspect']
#
# Result 11:
# Type: [maintie_gold.Motor], Label: ['306_motor'], Comment: ['<id> swing motor blower lube inspect']
# Type: [maintie_gold.Lube], Label: ['306_lube'], Comment: ['<id> swing motor blower lube inspect']
#
# Result 12:
# Type: [maintie_gold.Blower], Label: ['307_blower'], Comment: ['<id> swing motor / blower lube inspection']
# Type: [maintie_gold.Lube], Label: ['307_lube'], Comment: ['<id> swing motor / blower lube inspection']
#
# Result 13:
# Type: [maintie_gold.Motor], Label: ['307_motor'], Comment: ['<id> swing motor / blower lube inspection']
# Type: [maintie_gold.Lube], Label: ['307_lube'], Comment: ['<id> swing motor / blower lube inspection']
#
# Result 14:
# Type: [maintie_gold.Engine], Label: ['372_engine'], Comment: ['<id> investigate engine oil leak']
# Type: [maintie_gold.Oil], Label: ['372_oil'], Comment: ['<id> investigate engine oil leak']
#
# Result 15:
# Type: [maintie_gold.AirCompressor], Label: ['385_air_compressor'], Comment: ['<id> oil leak at air compressor']
# Type: [maintie_gold.Oil], Label: ['385_oil'], Comment: ['<id> oil leak at air compressor']
#
# Result 16:
# Type: [maintie_gold.Swingbox], Label: ['398_swingbox'], Comment: ['oil leak swingbox <num>']
# Type: [maintie_gold.Oil], Label: ['398_oil'], Comment: ['oil leak swingbox <num>']
#
# Result 17:
# Type: [maintie_gold.Engine], Label: ['411_engine'], Comment: ['<id> engine oil leaks right hand side']
# Type: [maintie_gold.Oil], Label: ['411_oil'], Comment: ['<id> engine oil leaks right hand side']
#
# Result 18:
# Type: [maintie_gold.CentreHitch], Label: ['441_centre_hitch'], Comment: ['<id> repair centre hitch oil leaks']
# Type: [maintie_gold.Oil], Label: ['441_oil'], Comment: ['<id> repair centre hitch oil leaks']
#
# Result 19:
# Type: [maintie_gold.Engine], Label: ['459_engine'], Comment: ['inspect bad engine oil leak']
# Type: [maintie_gold.Oil], Label: ['459_oil'], Comment: ['inspect bad engine oil leak']
#
# Result 20:
# Type: [maintie_gold.Differential], Label: ['531_differential'], Comment: ['<id> - change differential oil']
# Type: [maintie_gold.Oil], Label: ['531_oil'], Comment: ['<id> - change differential oil']
#
# Result 21:
# Type: [maintie_gold.Differential], Label: ['602_differential'], Comment: ['<id> - differential oil leak']
# Type: [maintie_gold.Oil], Label: ['602_oil'], Comment: ['<id> - differential oil leak']
#
# Result 22:
# Type: [maintie_gold.Engine], Label: ['609_engine'], Comment: ['<id> - engine oil leak']
# Type: [maintie_gold.Oil], Label: ['609_oil'], Comment: ['<id> - engine oil leak']
#
# Result 23:
# Type: [maintie_gold.Engine], Label: ['610_engine'], Comment: ['<id> - engine oil leak - inspection plate']
# Type: [maintie_gold.Oil], Label: ['610_oil'], Comment: ['<id> - engine oil leak - inspection plate']
#
# Result 24:
# Type: [maintie_gold.Pump], Label: ['651_pump'], Comment: ['<id> - investigate torque converter fan pump oil leak']
# Type: [maintie_gold.Oil], Label: ['651_oil'], Comment: ['<id> - investigate torque converter fan pump oil leak']
#
# Result 25:
# Type: [maintie_gold.Transmission], Label: ['661_transmission'], Comment: ['<id> - minor transmission oil leak']
# Type: [maintie_gold.Oil], Label: ['661_oil'], Comment: ['<id> - minor transmission oil leak']
#
# Result 26:
# Type: [maintie_gold.Engine], Label: ['680_engine'], Comment: ['<id> - repair engine oil leak and']
# Type: [maintie_gold.Oil], Label: ['680_oil'], Comment: ['<id> - repair engine oil leak and']
#
# Result 27:
# Type: [maintie_gold.Engine], Label: ['681_engine'], Comment: ['<id> - repair engine oil leaking']
# Type: [maintie_gold.Oil], Label: ['681_oil'], Comment: ['<id> - repair engine oil leaking']
#
# Result 28:
# Type: [maintie_gold.Engine], Label: ['749_engine'], Comment: ['<id> <id> repair engine oil leak text']
# Type: [maintie_gold.Oil], Label: ['749_oil'], Comment: ['<id> <id> repair engine oil leak text']
#
# Result 29:
# Type: [maintie_gold.Transmission], Label: ['750_transmission'], Comment: ['<id> <id> repair transmission oil leak text']
# Type: [maintie_gold.Oil], Label: ['750_oil'], Comment: ['<id> <id> repair transmission oil leak text']
#
# Result 30:
# Type: [maintie_gold.Pin], Label: ['755_pin'], Comment: ['<id> <id> steering pin no grease text']
# Type: [maintie_gold.Grease], Label: ['755_grease'], Comment: ['<id> <id> steering pin no grease text']
#
# Result 31:
# Type: [maintie_gold.Engine], Label: ['770_engine'], Comment: ['<id> CW engine oil leaks x <num>']
# Type: [maintie_gold.Oil], Label: ['770_oil'], Comment: ['<id> CW engine oil leaks x <num>']
#
# Result 32:
# Type: [maintie_gold.Engine], Label: ['838_engine'], Comment: ['change engine oil / sample']
# Type: [maintie_gold.Oil], Label: ['838_oil'], Comment: ['change engine oil / sample']
#
# Result 33:
# Type: [maintie_gold.Engine], Label: ['882_engine'], Comment: ['eng oil sample']
# Type: [maintie_gold.Oil], Label: ['882_oil'], Comment: ['eng oil sample']
#
# Result 34:
# Type: [maintie_gold.Engine], Label: ['885_engine'], Comment: ['engine oil samples']
# Type: [maintie_gold.Oil], Label: ['885_oil'], Comment: ['engine oil samples']
#
# Result 35:
# Type: [maintie_gold.HighVoltageSlipRing], Label: ['907_high_voltage_slip_ring'], Comment: ['high voltage slip ring inspection - grease leak']
# Type: [maintie_gold.Grease], Label: ['907_grease'], Comment: ['high voltage slip ring inspection - grease leak']
#
# Result 36:
# Type: [maintie_gold.Engine], Label: ['1050_engine'], Comment: ['sample engine oil and inspect filters']
# Type: [maintie_gold.Oil], Label: ['1050_oil'], Comment: ['sample engine oil and inspect filters']
#
# Result 37:
# Type: [maintie_gold.Engine], Label: ['1051_engine'], Comment: ['sample engine oil and replace oil and filter']
# Type: [maintie_gold.Oil], Label: ['1051_oil'], Comment: ['sample engine oil and replace oil and filter']
#
# Result 38:
# Type: [maintie_gold.Transmission], Label: ['1052_transmission'], Comment: ['sample transmission oil']
# Type: [maintie_gold.Oil], Label: ['1052_oil'], Comment: ['sample transmission oil']

# %% [markdown]
# **Properties of Physical Objects**

# %%
# %%sparql_query
# """
# PREFIX rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#>
#
# SELECT ?object ?subclassProperty
# WHERE {
#   # Find subclasses of Property
#   # ?subclassProperty rdfs:subClassOf* <file://ONTOLOGY_NAME#Property> .
#
#   ?object <file://ONTOLOGY_NAME#has_property> ?subclassProperty .
#
#   # ?property rdf:type <file://ONTOLOGY_NAME#Property> .
# }"""
# Out:
# Results found: 34
#
# [[maintie_gold.UM569Z1M, maintie_gold.IEF50RTN], [maintie_gold.RSEEMPH2, maintie_gold.KRLAH3RS], [maintie_gold.GKC3ZPHH, maintie_gold.11130WHL], [maintie_gold.A4J8JNYB, maintie_gold.KCBNEZZ4], [maintie_gold.RHO4ZJZR, maintie_gold.KF1326LN], [maintie_gold.JE2FU53B, maintie_gold.58EYRWMU], [maintie_gold.R5Q3C7HR, maintie_gold.V2JK0ZEQ], [maintie_gold.0X9S0UOR, maintie_gold.56E4WN5J], [maintie_gold.89BY6JZO, maintie_gold.KB72CL1Q], [maintie_gold.ZSQFL3P1, maintie_gold.M4DJZ5JX], [maintie_gold.A3DOXAA9, maintie_gold.MYGNMLDF], [maintie_gold.7TUMEM7P, maintie_gold.GDPCMBOB], [maintie_gold.BQVG6IB8, maintie_gold.C3LIYGFJ], [maintie_gold.6SZOKJAV, maintie_gold.G37PE25F], [maintie_gold.T5GZHFS7, maintie_gold.B2K7LS0G], [maintie_gold.MOVNH3HN, maintie_gold.K8UNRGKT], [maintie_gold.F11K8UPE, maintie_gold.6FF82M1L], [maintie_gold.XMPGANVG, maintie_gold.YLQMH8YN], [maintie_gold.2SV74109, maintie_gold.540Q79BE], [maintie_gold.XLK4CN5E, maintie_gold.EHCQOV6N], [maintie_gold.KFNXQLPG, maintie_gold.2GQC1G8D], [maintie_gold.X5S5YS5Z, maintie_gold.6BX1KJFC], [maintie_gold.T31K7KBJ, maintie_gold.MVYGMVXP], [maintie_gold.SKVOKR8M, maintie_gold.LSKT96WM], [maintie_gold.ZP9KMF0P, maintie_gold.2J4WK8MF], [maintie_gold.K17JOFY6, maintie_gold.OCFETXU3], [maintie_gold.55B862VK, maintie_gold.JF6VHZTH], [maintie_gold.9W3E404H, maintie_gold.LKDFHWLV], [maintie_gold.STX5LBMC, maintie_gold.1LG39IT5], [maintie_gold.55WFIHZJ, maintie_gold.YZ1ARATD], [maintie_gold.68IN6GSM, maintie_gold.GOE4ENF7], [maintie_gold.RU3NG47K, maintie_gold.MC467XKD], [maintie_gold.TY74TENT, maintie_gold.SKPF3VGQ], [maintie_gold.1IQAZW5Y, maintie_gold.E3R7TEXO]]
#
# Result 1:
# Type: [maintie_gold.Liner], Label: ['215_liner'], Comment: ['<id> crack in blade liner left hand side']
# Type: [maintie_gold.Crack], Label: ['215_crack'], Comment: ['<id> crack in blade liner left hand side']
#
# Result 2:
# Type: [maintie_gold.Chord], Label: ['216_chord'], Comment: ['<id> crack in boom <id> chord']
# Type: [maintie_gold.Crack], Label: ['216_crack'], Comment: ['<id> crack in boom <id> chord']
#
# Result 3:
# Type: [maintie_gold.FuelTank], Label: ['217_fuel_tank'], Comment: ['<id> crack in fuel tank']
# Type: [maintie_gold.Crack], Label: ['217_crack'], Comment: ['<id> crack in fuel tank']
#
# Result 4:
# Type: [maintie_gold.Headboard], Label: ['218_headboard'], Comment: ['<id> crack in headboard']
# Type: [maintie_gold.Crack], Label: ['218_crack'], Comment: ['<id> crack in headboard']
#
# Result 5:
# Type: [maintie_gold.Windscreen], Label: ['219_windscreen'], Comment: ['<id> crack in lower centre of windscreen']
# Type: [maintie_gold.Crack], Label: ['219_crack'], Comment: ['<id> crack in lower centre of windscreen']
#
# Result 6:
# Type: [maintie_gold.Windscreen], Label: ['220_windscreen'], Comment: ['<id> crack in windscreen']
# Type: [maintie_gold.Crack], Label: ['220_crack'], Comment: ['<id> crack in windscreen']
#
# Result 7:
# Type: [maintie_gold.RockDeflector], Label: ['221_rock_deflector'], Comment: ['<id> crack onside rock deflector']
# Type: [maintie_gold.Crack], Label: ['221_crack'], Comment: ['<id> crack onside rock deflector']
#
# Result 8:
# Type: [maintie_gold.Handrail], Label: ['228_handrail'], Comment: ['<id> cracks in back right hand side handrail']
# Type: [maintie_gold.Cracks], Label: ['228_cracks'], Comment: ['<id> cracks in back right hand side handrail']
#
# Result 9:
# Type: [maintie_gold.Decking], Label: ['229_decking'], Comment: ['<id> cracks in decking']
# Type: [maintie_gold.Cracks], Label: ['229_cracks'], Comment: ['<id> cracks in decking']
#
# Result 10:
# Type: [maintie_gold.DiagonalBraces], Label: ['230_diagonal_braces'], Comment: ['<id> cracks in diagonal braces in front']
# Type: [maintie_gold.Cracks], Label: ['230_cracks'], Comment: ['<id> cracks in diagonal braces in front']
#
# Result 11:
# Type: [maintie_gold.Mounts], Label: ['231_mounts'], Comment: ['<id> cracks in fire suppression mounts']
# Type: [maintie_gold.Cracks], Label: ['231_cracks'], Comment: ['<id> cracks in fire suppression mounts']
#
# Result 12:
# Type: [maintie_gold.Headboard], Label: ['232_headboard'], Comment: ['<id> cracks in headboard']
# Type: [maintie_gold.Cracks], Label: ['232_cracks'], Comment: ['<id> cracks in headboard']
#
# Result 13:
# Type: [maintie_gold.DirtChute], Label: ['233_dirt_chute'], Comment: ['<id> cracks in the dirt chute']
# Type: [maintie_gold.Cracks], Label: ['233_cracks'], Comment: ['<id> cracks in the dirt chute']
#
# Result 14:
# Type: [maintie_gold.MudBucket], Label: ['279_mud_bucket'], Comment: ['repair cracks in mud bucket']
# Type: [maintie_gold.Cracks], Label: ['279_cracks'], Comment: ['repair cracks in mud bucket']
#
# Result 15:
# Type: [maintie_gold.CableGantry], Label: ['282_cable_gantry'], Comment: ['<num> - cable gantry crack repairs']
# Type: [maintie_gold.Crack], Label: ['282_crack'], Comment: ['<num> - cable gantry crack repairs']
#
# Result 16:
# Type: [maintie_gold.Bearing], Label: ['318_bearing'], Comment: ['bearing noisy']
# Type: [maintie_gold.Noisy], Label: ['318_noisy'], Comment: ['bearing noisy']
#
# Result 17:
# Type: [maintie_gold.FuelTank], Label: ['354_fuel_tank'], Comment: ['<id> repair right hand fuel tank crack']
# Type: [maintie_gold.Crack], Label: ['354_crack'], Comment: ['<id> repair right hand fuel tank crack']
#
# Result 18:
# Type: [maintie_gold.Stick], Label: ['357_stick'], Comment: ['<id> repair cracks on stick']
# Type: [maintie_gold.Cracks], Label: ['357_cracks'], Comment: ['<id> repair cracks on stick']
#
# Result 19:
# Type: [maintie_gold.Boom], Label: ['362_boom'], Comment: ['<id> repair boom cracks left hand side']
# Type: [maintie_gold.Cracks], Label: ['362_cracks'], Comment: ['<id> repair boom cracks left hand side']
#
# Result 20:
# Type: [maintie_gold.BoomFoot], Label: ['655_boom_foot'], Comment: ['<id> - left hand side boom foot crack repair']
# Type: [maintie_gold.Crack], Label: ['655_crack'], Comment: ['<id> - left hand side boom foot crack repair']
#
# Result 21:
# Type: [maintie_gold.HydraulicLiftCylinder], Label: ['664_hydraulic_lift_cylinder'], Comment: ['<id> - noisy hydraulic lift cylinder']
# Type: [maintie_gold.Noisy], Label: ['664_noisy'], Comment: ['<id> - noisy hydraulic lift cylinder']
#
# Result 22:
# Type: [maintie_gold.TrackFrame], Label: ['686_track_frame'], Comment: ['<id> - repair right hand track frame crack']
# Type: [maintie_gold.Crack], Label: ['686_crack'], Comment: ['<id> - repair right hand track frame crack']
#
# Result 23:
# Type: [maintie_gold.Stick], Label: ['729_stick'], Comment: ['<id> - stick cracks']
# Type: [maintie_gold.Cracks], Label: ['729_cracks'], Comment: ['<id> - stick cracks']
#
# Result 24:
# Type: [maintie_gold.Chord], Label: ['742_chord'], Comment: ['<id> <id> chord is leaking air from crack']
# Type: [maintie_gold.Crack], Label: ['742_crack'], Comment: ['<id> <id> chord is leaking air from crack']
#
# Result 25:
# Type: [maintie_gold.Batteries], Label: ['817_batteries'], Comment: ['batteries have no charge']
# Type: [maintie_gold.Charge], Label: ['817_charge'], Comment: ['batteries have no charge']
#
# Result 26:
# Type: [maintie_gold.WindowFrame], Label: ['862_window_frame'], Comment: ['crack repairs left hand window frame']
# Type: [maintie_gold.Crack], Label: ['862_crack'], Comment: ['crack repairs left hand window frame']
#
# Result 27:
# Type: [maintie_gold.FlowBattery], Label: ['898_flow_battery'], Comment: ['flow battery power']
# Type: [maintie_gold.Power], Label: ['898_power'], Comment: ['flow battery power']
#
# Result 28:
# Type: [maintie_gold.DoorFrame], Label: ['906_door_frame'], Comment: ['hole in door frame']
# Type: [maintie_gold.Hole], Label: ['906_hole'], Comment: ['hole in door frame']
#
# Result 29:
# Type: [maintie_gold.GlassWindow], Label: ['936_glass_window'], Comment: ['<num> glass window has large crack']
# Type: [maintie_gold.Crack], Label: ['936_crack'], Comment: ['<num> glass window has large crack']
#
# Result 30:
# Type: [maintie_gold.CrossMember], Label: ['972_cross_member'], Comment: ['repair crack in right hand side of rear cross member']
# Type: [maintie_gold.Crack], Label: ['972_crack'], Comment: ['repair crack in right hand side of rear cross member']
#
# Result 31:
# Type: [maintie_gold.CrossMember], Label: ['977_cross_member'], Comment: ['repair chassis crack at right hand rear cross member']
# Type: [maintie_gold.Crack], Label: ['977_crack'], Comment: ['repair chassis crack at right hand rear cross member']
#
# Result 32:
# Type: [maintie_gold.CrossMember], Label: ['978_cross_member'], Comment: ['repair crack in rear cross member']
# Type: [maintie_gold.Crack], Label: ['978_crack'], Comment: ['repair crack in rear cross member']
#
# Result 33:
# Type: [maintie_gold.HeatShield], Label: ['979_heat_shield'], Comment: ['repair crack on left hand front heat shield']
# Type: [maintie_gold.Crack], Label: ['979_crack'], Comment: ['repair crack on left hand front heat shield']
#
# Result 34:
# Type: [maintie_gold.CrossBraces], Label: ['982_cross_braces'], Comment: ['repair cracks in mast cross braces']
# Type: [maintie_gold.Cracks], Label: ['982_cracks'], Comment: ['repair cracks in mast cross braces']

# %% [markdown]
# **States of properties on objects**

# %%
# %%sparql_query
# """
# SELECT ?object ?property ?state
# WHERE {
#   ?object <file://ONTOLOGY_NAME#has_property> ?property .
#
#   ?state <file://ONTOLOGY_NAME#has_patient> ?property .
# }"""
# Out:
# Results found: 1
#
# [[maintie_gold.ZP9KMF0P, maintie_gold.2J4WK8MF, maintie_gold.NWS2QKJQ]]
#
# Result 1:
# Type: [maintie_gold.Batteries], Label: ['817_batteries'], Comment: ['batteries have no charge']
# Type: [maintie_gold.Charge], Label: ['817_charge'], Comment: ['batteries have no charge']
# Type: [maintie_gold.No], Label: ['817_no'], Comment: ['batteries have no charge']

# %% [markdown]
# **What is replaced on Pumps**

# %%
# %%sparql_query
# """
# PREFIX rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#>
# PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
# PREFIX owl: <http://www.w3.org/2002/07/owl#>
#
# SELECT ?pumpInstance ?part ?replaceInstance
# WHERE {
#   # Find subclasses of Pump
#   ?subclass rdfs:subClassOf* <file://ONTOLOGY_NAME#Pump> .
#
#   # Find instances of these subclasses
#   ?pumpInstance rdf:type ?subclass .
#
#   # Find instances of
#   ?pumpInstance <file://ONTOLOGY_NAME#has_part> ?part .
#
#   # Find instances of the parts that have been patients of replacements
#   # Find subclasses of Replace
#   ?subclassReplace rdfs:subClassOf* <file://ONTOLOGY_NAME#Replace> .
#
#   # Find instances of these subclasses
#   ?replaceInstance rdf:type ?subclassReplace .
#
#   # Assuming there is a property that associates Adjust instances with a physical object
#   ?replaceInstance <file://ONTOLOGY_NAME#has_patient> ?part .
# }
# """
# Out:
# Results found: 9
#
# [[maintie_gold.M3LX09M4, maintie_gold.GX39BIIL, maintie_gold.IDQGXRCA], [maintie_gold.AYXX9F3U, maintie_gold.98T97J9A, maintie_gold.EUVDYBTK], [maintie_gold.6OTWBYY8, maintie_gold.FU2LB3L1, maintie_gold.VX5RH09F], [maintie_gold.NU6IFPB8, maintie_gold.QOORX1A3, maintie_gold.1H9P7N6V], [maintie_gold.FFD37OZJ, maintie_gold.NHGPUYGR, maintie_gold.Z4JZL1XC], [maintie_gold.TR6QHPMQ, maintie_gold.S1RYQV6J, maintie_gold.PEFW4NO7], [maintie_gold.6F9FO8HB, maintie_gold.EF0QEHUY, maintie_gold.4RQO3LNU], [maintie_gold.2MFGYKX0, maintie_gold.V8XIHJRX, maintie_gold.SD6W17H2], [maintie_gold.2V50DBH5, maintie_gold.B056L76L, maintie_gold.QU1PVQEG]]
#
# Result 1:
# Type: [maintie_gold.Pump], Label: ['131_pump'], Comment: ['<id> change out blown o-ring on steering pump']
# Type: [maintie_gold.Oring], Label: ['131_oring'], Comment: ['<id> change out blown o-ring on steering pump']
# Type: [maintie_gold.ChangeOut], Label: ['131_change_out'], Comment: ['<id> change out blown o-ring on steering pump']
#
# Result 2:
# Type: [maintie_gold.Pump], Label: ['134_pump'], Comment: ['<id> change out broken bolt on brake pump']
# Type: [maintie_gold.Bolt], Label: ['134_bolt'], Comment: ['<id> change out broken bolt on brake pump']
# Type: [maintie_gold.ChangeOut], Label: ['134_change_out'], Comment: ['<id> change out broken bolt on brake pump']
#
# Result 3:
# Type: [maintie_gold.Pump], Label: ['401_pump'], Comment: ['replace lube system <id> drag rope pump']
# Type: [maintie_gold.LubeSystem], Label: ['401_lube_system'], Comment: ['replace lube system <id> drag rope pump']
# Type: [maintie_gold.Replace], Label: ['401_replace'], Comment: ['replace lube system <id> drag rope pump']
#
# Result 4:
# Type: [maintie_gold.Pump], Label: ['473_pump'], Comment: ['<id> replace blown main pump hose']
# Type: [maintie_gold.Hose], Label: ['473_hose'], Comment: ['<id> replace blown main pump hose']
# Type: [maintie_gold.Replace], Label: ['473_replace'], Comment: ['<id> replace blown main pump hose']
#
# Result 5:
# Type: [maintie_gold.Pump], Label: ['574_pump'], Comment: ['<id> - change out pump cooling fan engine']
# Type: [maintie_gold.CoolingFan], Label: ['574_cooling_fan'], Comment: ['<id> - change out pump cooling fan engine']
# Type: [maintie_gold.ChangeOut], Label: ['574_change_out'], Comment: ['<id> - change out pump cooling fan engine']
#
# Result 6:
# Type: [maintie_gold.Pump], Label: ['594_pump'], Comment: ['<id> - change out universal joints engine - pump drag']
# Type: [maintie_gold.UniversalJoints], Label: ['594_universal_joints'], Comment: ['<id> - change out universal joints engine - pump drag']
# Type: [maintie_gold.ChangeOut], Label: ['594_change_out'], Comment: ['<id> - change out universal joints engine - pump drag']
#
# Result 7:
# Type: [maintie_gold.Pump], Label: ['1024_pump'], Comment: ['replace left hand slew pump contamination switch']
# Type: [maintie_gold.ContaminationSwitch], Label: ['1024_contamination_switch'], Comment: ['replace left hand slew pump contamination switch']
# Type: [maintie_gold.Replace], Label: ['1024_replace'], Comment: ['replace left hand slew pump contamination switch']
#
# Result 8:
# Type: [maintie_gold.Pump], Label: ['1027_pump'], Comment: ['replace right hand swing pump chip sensor']
# Type: [maintie_gold.ChipSensor], Label: ['1027_chip_sensor'], Comment: ['replace right hand swing pump chip sensor']
# Type: [maintie_gold.Replace], Label: ['1027_replace'], Comment: ['replace right hand swing pump chip sensor']
#
# Result 9:
# Type: [maintie_gold.HydraulicPump], Label: ['429_hydraulic_pump'], Comment: ['replace hydraulic pump coupling']
# Type: [maintie_gold.Coupling], Label: ['429_coupling'], Comment: ['replace hydraulic pump coupling']
# Type: [maintie_gold.Replace], Label: ['429_replace'], Comment: ['replace hydraulic pump coupling']

# %% [markdown]
# **What maintenance activities are performed on Pumps?**

# %%
# %%sparql_query
# """
# PREFIX rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#>
# PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
# PREFIX owl: <http://www.w3.org/2002/07/owl#>
#
# SELECT DISTINCT ?pumpInstance ?maintenanceActivityInstance
# WHERE {
#   # Find subclasses of Pump
#   ?subclass rdfs:subClassOf* <file://ONTOLOGY_NAME#Pump> .
#
#   # Find instances of these subclasses
#   ?pumpInstance rdf:type ?subclass .
#
#   # Find subclasses of Adjust
#   ?subclassMaintenanceActivity rdfs:subClassOf* <file://ONTOLOGY_NAME#MaintenanceActivity> .
#
#   # Find instances of these subclasses
#   ?maintenanceActivityInstance rdf:type ?subclassMaintenanceActivity .
#
#   # Assuming there is a property that associates Adjust instances with a physical object
#   ?maintenanceActivityInstance <file://ONTOLOGY_NAME#has_patient> ?pumpInstance .
#
# }
# """
# Out:
# Results found: 10
#
# [[maintie_gold.QVJ9UX8H, maintie_gold.C64LA615], [maintie_gold.ZOMPY8HH, maintie_gold.PMN62647], [maintie_gold.EU8M0HK2, maintie_gold.KID7BRYU], [maintie_gold.SXPFLPFO, maintie_gold.1K8H7MVM], [maintie_gold.BVZBO72W, maintie_gold.EZ04QAH9], [maintie_gold.AEY6LR9K, maintie_gold.1LDM1S8J], [maintie_gold.40OT0GKD, maintie_gold.HU5N9RLE], [maintie_gold.8NZWQ7OG, maintie_gold.R6PG0C5I], [maintie_gold.G3R39IG0, maintie_gold.1S4Y1ELQ], [maintie_gold.MNAUISZU, maintie_gold.3RS1C9SX]]
#
# Result 1:
# Type: [maintie_gold.Pump], Label: ['460_pump'], Comment: ['<id> reseal steering pump']
# Type: [maintie_gold.Reseal], Label: ['460_reseal'], Comment: ['<id> reseal steering pump']
#
# Result 2:
# Type: [maintie_gold.Pump], Label: ['651_pump'], Comment: ['<id> - investigate torque converter fan pump oil leak']
# Type: [maintie_gold.Investigate], Label: ['651_investigate'], Comment: ['<id> - investigate torque converter fan pump oil leak']
#
# Result 3:
# Type: [maintie_gold.CoolantPump], Label: ['549_coolant_pump'], Comment: ['<id> - change out coolant pump']
# Type: [maintie_gold.ChangeOut], Label: ['549_change_out'], Comment: ['<id> - change out coolant pump']
#
# Result 4:
# Type: [maintie_gold.ScavengePump], Label: ['386_scavenge_pump'], Comment: ['<id> replace leaking scavenge pump']
# Type: [maintie_gold.Replace], Label: ['386_replace'], Comment: ['<id> replace leaking scavenge pump']
#
# Result 5:
# Type: [maintie_gold.WaterPump], Label: ['182_water_pump'], Comment: ['<id> change out water pump']
# Type: [maintie_gold.ChangeOut], Label: ['182_change_out'], Comment: ['<id> change out water pump']
#
# Result 6:
# Type: [maintie_gold.JacketWaterPump], Label: ['147_jacket_water_pump'], Comment: ['<id> change out jacket water pump']
# Type: [maintie_gold.ChangeOut], Label: ['147_change_out'], Comment: ['<id> change out jacket water pump']
#
# Result 7:
# Type: [maintie_gold.JacketWaterPump], Label: ['176_jacket_water_pump'], Comment: ['<id> change out unserviceable jacket water pump']
# Type: [maintie_gold.ChangeOut], Label: ['176_change_out'], Comment: ['<id> change out unserviceable jacket water pump']
#
# Result 8:
# Type: [maintie_gold.AuxiliaryWaterPump], Label: ['130_auxiliary_water_pump'], Comment: ['<id> change out auxiliary water pump']
# Type: [maintie_gold.ChangeOut], Label: ['130_change_out'], Comment: ['<id> change out auxiliary water pump']
#
# Result 9:
# Type: [maintie_gold.ImplementPump], Label: ['153_implement_pump'], Comment: ['<id> change out leaking implement pump']
# Type: [maintie_gold.ChangeOut], Label: ['153_change_out'], Comment: ['<id> change out leaking implement pump']
#
# Result 10:
# Type: [maintie_gold.OilPump], Label: ['556_oil_pump'], Comment: ['<id> - change out engine oil pump']
# Type: [maintie_gold.ChangeOut], Label: ['556_change_out'], Comment: ['<id> - change out engine oil pump']

# %% [markdown]
# **What Supporting Activities are performed on pumps?**

# %%
# %%sparql_query
# """
# PREFIX rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#>
# PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
# PREFIX owl: <http://www.w3.org/2002/07/owl#>
#
# SELECT DISTINCT ?pumpInstance ?supportingActivityInstance
# WHERE {
#   # Find subclasses of Pump
#   ?subclass rdfs:subClassOf* <file://ONTOLOGY_NAME#Pump> .
#
#   # Find instances of these subclasses
#   ?pumpInstance rdf:type ?subclass .
#
#   # Find subclasses of Supporting Activity
#   ?subclassSupportingActivity rdfs:subClassOf* <file://ONTOLOGY_NAME#SupportingActivity> .
#
#   # Find instances of these subclasses
#   ?supportingActivityInstance rdf:type ?subclassSupportingActivity .
#
#   # Assuming there is a property that associates Adjust instances with a physical object
#   ?supportingActivityInstance <file://ONTOLOGY_NAME#has_patient> ?pumpInstance .
# }
# """
# Out:
# Results found: 1
#
# [[maintie_gold.WSXB2MXM, maintie_gold.SG8U85FK]]
#
# Result 1:
# Type: [maintie_gold.Pump], Label: ['7_pump'], Comment: ['<id> air freight for pump TBC']
# Type: [maintie_gold.AirFreight], Label: ['7_air_freight'], Comment: ['<id> air freight for pump TBC']

# %% [markdown]
# **What Maintenance Activities are performed on parts of pumps?**

# %%
# %%sparql_query
# """
# PREFIX rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#>
# PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
# PREFIX owl: <http://www.w3.org/2002/07/owl#>
#
# SELECT DISTINCT ?pumpInstance ?part ?maintenanceActivityInstance
# WHERE {
#   # Find subclasses of Pump
#   ?subclass rdfs:subClassOf* <file://ONTOLOGY_NAME#Pump> .
#
#   # Find instances of these subclasses
#   ?pumpInstance rdf:type ?subclass .
#
#   # Find instances of pump parts
#   ?pumpInstance <file://ONTOLOGY_NAME#has_part> ?part .
#
#   # Find subclasses of SupportingActivity
#   ?subclassMaintenanceActivity rdfs:subClassOf* <file://ONTOLOGY_NAME#MaintenanceActivity> .
#
#   # Find instances of these subclasses
#   ?maintenanceActivityInstance rdf:type ?subclassMaintenanceActivity .
#
#   # Assuming there is a property that associates Adjust instances with a physical object
#   ?maintenanceActivityInstance <file://ONTOLOGY_NAME#has_patient> ?part .
# }
# """
# Out:
# Results found: 9
#
# [[maintie_gold.M3LX09M4, maintie_gold.GX39BIIL, maintie_gold.IDQGXRCA], [maintie_gold.AYXX9F3U, maintie_gold.98T97J9A, maintie_gold.EUVDYBTK], [maintie_gold.6OTWBYY8, maintie_gold.FU2LB3L1, maintie_gold.VX5RH09F], [maintie_gold.NU6IFPB8, maintie_gold.QOORX1A3, maintie_gold.1H9P7N6V], [maintie_gold.FFD37OZJ, maintie_gold.NHGPUYGR, maintie_gold.Z4JZL1XC], [maintie_gold.TR6QHPMQ, maintie_gold.S1RYQV6J, maintie_gold.PEFW4NO7], [maintie_gold.6F9FO8HB, maintie_gold.EF0QEHUY, maintie_gold.4RQO3LNU], [maintie_gold.2MFGYKX0, maintie_gold.V8XIHJRX, maintie_gold.SD6W17H2], [maintie_gold.2V50DBH5, maintie_gold.B056L76L, maintie_gold.QU1PVQEG]]
#
# Result 1:
# Type: [maintie_gold.Pump], Label: ['131_pump'], Comment: ['<id> change out blown o-ring on steering pump']
# Type: [maintie_gold.Oring], Label: ['131_oring'], Comment: ['<id> change out blown o-ring on steering pump']
# Type: [maintie_gold.ChangeOut], Label: ['131_change_out'], Comment: ['<id> change out blown o-ring on steering pump']
#
# Result 2:
# Type: [maintie_gold.Pump], Label: ['134_pump'], Comment: ['<id> change out broken bolt on brake pump']
# Type: [maintie_gold.Bolt], Label: ['134_bolt'], Comment: ['<id> change out broken bolt on brake pump']
# Type: [maintie_gold.ChangeOut], Label: ['134_change_out'], Comment: ['<id> change out broken bolt on brake pump']
#
# Result 3:
# Type: [maintie_gold.Pump], Label: ['401_pump'], Comment: ['replace lube system <id> drag rope pump']
# Type: [maintie_gold.LubeSystem], Label: ['401_lube_system'], Comment: ['replace lube system <id> drag rope pump']
# Type: [maintie_gold.Replace], Label: ['401_replace'], Comment: ['replace lube system <id> drag rope pump']
#
# Result 4:
# Type: [maintie_gold.Pump], Label: ['473_pump'], Comment: ['<id> replace blown main pump hose']
# Type: [maintie_gold.Hose], Label: ['473_hose'], Comment: ['<id> replace blown main pump hose']
# Type: [maintie_gold.Replace], Label: ['473_replace'], Comment: ['<id> replace blown main pump hose']
#
# Result 5:
# Type: [maintie_gold.Pump], Label: ['574_pump'], Comment: ['<id> - change out pump cooling fan engine']
# Type: [maintie_gold.CoolingFan], Label: ['574_cooling_fan'], Comment: ['<id> - change out pump cooling fan engine']
# Type: [maintie_gold.ChangeOut], Label: ['574_change_out'], Comment: ['<id> - change out pump cooling fan engine']
#
# Result 6:
# Type: [maintie_gold.Pump], Label: ['594_pump'], Comment: ['<id> - change out universal joints engine - pump drag']
# Type: [maintie_gold.UniversalJoints], Label: ['594_universal_joints'], Comment: ['<id> - change out universal joints engine - pump drag']
# Type: [maintie_gold.ChangeOut], Label: ['594_change_out'], Comment: ['<id> - change out universal joints engine - pump drag']
#
# Result 7:
# Type: [maintie_gold.Pump], Label: ['1024_pump'], Comment: ['replace left hand slew pump contamination switch']
# Type: [maintie_gold.ContaminationSwitch], Label: ['1024_contamination_switch'], Comment: ['replace left hand slew pump contamination switch']
# Type: [maintie_gold.Replace], Label: ['1024_replace'], Comment: ['replace left hand slew pump contamination switch']
#
# Result 8:
# Type: [maintie_gold.Pump], Label: ['1027_pump'], Comment: ['replace right hand swing pump chip sensor']
# Type: [maintie_gold.ChipSensor], Label: ['1027_chip_sensor'], Comment: ['replace right hand swing pump chip sensor']
# Type: [maintie_gold.Replace], Label: ['1027_replace'], Comment: ['replace right hand swing pump chip sensor']
#
# Result 9:
# Type: [maintie_gold.HydraulicPump], Label: ['429_hydraulic_pump'], Comment: ['replace hydraulic pump coupling']
# Type: [maintie_gold.Coupling], Label: ['429_coupling'], Comment: ['replace hydraulic pump coupling']
# Type: [maintie_gold.Replace], Label: ['429_replace'], Comment: ['replace hydraulic pump coupling']

# %% [markdown]
# **What SupportingActivities are performed on parts of Pumps?**

# %%
# %%sparql_query
# """
# PREFIX rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#>
# PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
# PREFIX owl: <http://www.w3.org/2002/07/owl#>
#
# SELECT DISTINCT ?pumpInstance ?part ?maintenanceActivityInstance
# WHERE {
#   # Find subclasses of Pump
#   ?subclass rdfs:subClassOf* <file://ONTOLOGY_NAME#Pump> .
#
#   # Find instances of these subclasses
#   ?pumpInstance rdf:type ?subclass .
#
#   # Find instances of pump parts
#   ?pumpInstance <file://ONTOLOGY_NAME#has_part> ?part .
#
#   # Find subclasses of SupportingActivity
#   ?subclassMaintenanceActivity rdfs:subClassOf* <file://ONTOLOGY_NAME#SupportingActivity> .
#
#   # Find instances of these subclasses
#   ?maintenanceActivityInstance rdf:type ?subclassMaintenanceActivity .
#
#   # Assuming there is a property that associates Adjust instances with a physical object
#   ?maintenanceActivityInstance <file://ONTOLOGY_NAME#has_patient> ?part .
# }
# """
# Out:
# No results found.

# %% [markdown]
# **What do pumps leak?**

# %%
# %%sparql_query
# """
# PREFIX rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#>
# PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
# PREFIX owl: <http://www.w3.org/2002/07/owl#>
#
# SELECT DISTINCT ?pumpInstance ?leakInstance ?patientInstance
# WHERE {
#   # Find subclasses of Pump
#   ?subclass rdfs:subClassOf* <file://ONTOLOGY_NAME#Pump> .
#
#   # Find instances of these subclasses
#   ?pumpInstance rdf:type ?subclass .
#
#   {
#     ?leakInstance rdf:type <file://ONTOLOGY_NAME#Leak> .
#   }
#   UNION
#   {
#     ?leakInstance rdf:type <file://ONTOLOGY_NAME#Leaking> .
#   }
#   UNION
#   {
#     ?leakInstance rdf:type <file://ONTOLOGY_NAME#Leaks> .
#   }
#
#   # Associate leak instances with pump instances
#   ?leakInstance <file://ONTOLOGY_NAME#has_agent> ?pumpInstance .
#
#   # Find individual objects that are patients of the leak instances
#   ?leakInstance <file://ONTOLOGY_NAME#has_patient> ?patientInstance .
# }
# """
# Out:
# Results found: 2
#
# [[maintie_gold.YWOAU95N, maintie_gold.CRL8ZTIV, maintie_gold.FC1Q8X5M], [maintie_gold.ZOMPY8HH, maintie_gold.E53T8PF9, maintie_gold.4II8ZUMN]]
#
# Result 1:
# Type: [maintie_gold.JacketWaterPump], Label: ['211_jacket_water_pump'], Comment: ['<id> coolant leak at jacket water pump']
# Type: [maintie_gold.Leak], Label: ['211_leak'], Comment: ['<id> coolant leak at jacket water pump']
# Type: [maintie_gold.Coolant], Label: ['211_coolant'], Comment: ['<id> coolant leak at jacket water pump']
#
# Result 2:
# Type: [maintie_gold.Pump], Label: ['651_pump'], Comment: ['<id> - investigate torque converter fan pump oil leak']
# Type: [maintie_gold.Leak], Label: ['651_leak'], Comment: ['<id> - investigate torque converter fan pump oil leak']
# Type: [maintie_gold.Oil], Label: ['651_oil'], Comment: ['<id> - investigate torque converter fan pump oil leak']

# %% [markdown]
# **What is leaking substance (oil, fuel, ...)?**

# %%
# %%sparql_query
# """
# PREFIX rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#>
# PREFIX owl: <http://www.w3.org/2002/07/owl#>
#
# SELECT DISTINCT ?agent ?leakInstance ?substanceInstance
# WHERE {
#   # Find instances of substances
#   ?subClass rdfs:subClassOf* <file://ONTOLOGY_NAME#Substance> .
#
#   ?substanceInstance rdf:type ?subClass .
#
#   # Find instances of Leak/Leaking/Leaks
#   {
#     ?leakInstance rdf:type <file://ONTOLOGY_NAME#Leak> .
#   }
#   UNION
#   {
#     ?leakInstance rdf:type <file://ONTOLOGY_NAME#Leaking> .
#   }
#   UNION
#   {
#     ?leakInstance rdf:type <file://ONTOLOGY_NAME#Leaks> .
#   }
#
#   # Associate leak instances with oil instances
#   ?leakInstance <file://ONTOLOGY_NAME#has_patient> ?substanceInstance .
#
#   # Find the agents of these leak instances
#   ?leakInstance <file://ONTOLOGY_NAME#has_agent> ?agent .
# }
# """
# Out:
# Results found: 9
#
# [[maintie_gold.BUTXTZFA, maintie_gold.NP6PRNZI, maintie_gold.FSUGU3HR], [maintie_gold.PDJK9VLW, maintie_gold.ABZGK931, maintie_gold.3979MWE0], [maintie_gold.Q8G1CU8U, maintie_gold.X163B4GG, maintie_gold.RDUDQ8NE], [maintie_gold.FH35E6TZ, maintie_gold.UKWM3UEM, maintie_gold.GO5XDD4Z], [maintie_gold.G2BYY1FR, maintie_gold.77IZO7IF, maintie_gold.JFP64MT0], [maintie_gold.KT5KDSXX, maintie_gold.1FK5LTA0, maintie_gold.S2ZZXNUL], [maintie_gold.JS18XM7N, maintie_gold.U816TCA7, maintie_gold.XJZUE7SR], [maintie_gold.SKVOKR8M, maintie_gold.590O85TC, maintie_gold.SVGHLVEB], [maintie_gold.L5WKHDX6, maintie_gold.29C55SQ0, maintie_gold.QU2FG99Y]]
#
# Result 1:
# Type: [maintie_gold.Door], Label: ['17_door'], Comment: ['<id> air leak near side of door']
# Type: [maintie_gold.Leak], Label: ['17_leak'], Comment: ['<id> air leak near side of door']
# Type: [maintie_gold.Air], Label: ['17_air'], Comment: ['<id> air leak near side of door']
#
# Result 2:
# Type: [maintie_gold.Window], Label: ['269_window'], Comment: ['<id> dust leak operators side window']
# Type: [maintie_gold.Leak], Label: ['269_leak'], Comment: ['<id> dust leak operators side window']
# Type: [maintie_gold.Dust], Label: ['269_dust'], Comment: ['<id> dust leak operators side window']
#
# Result 3:
# Type: [maintie_gold.SafetyValve], Label: ['974_safety_valve'], Comment: ['repair air leak at air tank safety valve']
# Type: [maintie_gold.Leak], Label: ['974_leak'], Comment: ['repair air leak at air tank safety valve']
# Type: [maintie_gold.Air], Label: ['974_air'], Comment: ['repair air leak at air tank safety valve']
#
# Result 4:
# Type: [maintie_gold.Line], Label: ['18_line'], Comment: ['<id> air leaking from line outside']
# Type: [maintie_gold.Leaking], Label: ['18_leaking'], Comment: ['<id> air leaking from line outside']
# Type: [maintie_gold.Air], Label: ['18_air'], Comment: ['<id> air leaking from line outside']
#
# Result 5:
# Type: [maintie_gold.Seals], Label: ['111_seals'], Comment: ['<id> cabin seals leaking dust PO']
# Type: [maintie_gold.Leaking], Label: ['111_leaking'], Comment: ['<id> cabin seals leaking dust PO']
# Type: [maintie_gold.Dust], Label: ['111_dust'], Comment: ['<id> cabin seals leaking dust PO']
#
# Result 6:
# Type: [maintie_gold.Seals], Label: ['112_seals'], Comment: ['<id> cabin seals leaking dust bad']
# Type: [maintie_gold.Leaking], Label: ['112_leaking'], Comment: ['<id> cabin seals leaking dust bad']
# Type: [maintie_gold.Dust], Label: ['112_dust'], Comment: ['<id> cabin seals leaking dust bad']
#
# Result 7:
# Type: [maintie_gold.Chord], Label: ['202_chord'], Comment: ['<id> chord leaking air found <id>']
# Type: [maintie_gold.Leaking], Label: ['202_leaking'], Comment: ['<id> chord leaking air found <id>']
# Type: [maintie_gold.Air], Label: ['202_air'], Comment: ['<id> chord leaking air found <id>']
#
# Result 8:
# Type: [maintie_gold.Chord], Label: ['742_chord'], Comment: ['<id> <id> chord is leaking air from crack']
# Type: [maintie_gold.Leaking], Label: ['742_leaking'], Comment: ['<id> <id> chord is leaking air from crack']
# Type: [maintie_gold.Air], Label: ['742_air'], Comment: ['<id> <id> chord is leaking air from crack']
#
# Result 9:
# Type: [maintie_gold.WaterSeparator], Label: ['1070_water_separator'], Comment: ['water separator leaking fuel']
# Type: [maintie_gold.Leaking], Label: ['1070_leaking'], Comment: ['water separator leaking fuel']
# Type: [maintie_gold.Fuel], Label: ['1070_fuel'], Comment: ['water separator leaking fuel']

# %% [markdown]
# **What leaks, what?**

# %%
# %%sparql_query
# """
# PREFIX rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#>
# PREFIX owl: <http://www.w3.org/2002/07/owl#>
#
# SELECT DISTINCT ?agent ?substanceInstance
# WHERE {
#   # Find instances of Leak/Leaking/Leaks
#   {
#     ?leakInstance rdf:type <file://ONTOLOGY_NAME#Leak> .
#   }
#   UNION
#   {
#     ?leakInstance rdf:type <file://ONTOLOGY_NAME#Leaking> .
#   }
#   UNION
#   {
#     ?leakInstance rdf:type <file://ONTOLOGY_NAME#Leaks> .
#   }
#
#   # Associate leak instances with oil instances
#   ?leakInstance <file://ONTOLOGY_NAME#has_patient> ?substanceInstance .
#
#   # Find the agents of these leak instances
#   ?leakInstance <file://ONTOLOGY_NAME#has_agent> ?agent .
#
# }
# """
# Out:
# Results found: 37
#
# [[maintie_gold.BUTXTZFA, maintie_gold.FSUGU3HR], [maintie_gold.55T566BF, maintie_gold.THXK9UFZ], [maintie_gold.4Y46SO44, maintie_gold.CBEN1CDR], [maintie_gold.YWOAU95N, maintie_gold.FC1Q8X5M], [maintie_gold.DOP9G5ZL, maintie_gold.45I3QL0X], [maintie_gold.PDJK9VLW, maintie_gold.3979MWE0], [maintie_gold.QY6SM03M, maintie_gold.2NK9CGD6], [maintie_gold.ED5AYXEZ, maintie_gold.0FHWSPQO], [maintie_gold.EH4M6997, maintie_gold.MYR4DVZH], [maintie_gold.183PORKW, maintie_gold.IQJSLPUO], [maintie_gold.34AEWAZC, maintie_gold.DQ2FPIZD], [maintie_gold.KN3U03AO, maintie_gold.6EV7IMIX], [maintie_gold.C3GERDAF, maintie_gold.44ELBN85], [maintie_gold.ZOMPY8HH, maintie_gold.4II8ZUMN], [maintie_gold.70Y5U1GH, maintie_gold.D9ZT1W2O], [maintie_gold.RWC6ASRE, maintie_gold.NREU8S5O], [maintie_gold.IESIGF4S, maintie_gold.G83NPKVP], [maintie_gold.4O00V48L, maintie_gold.BPSIHNEB], [maintie_gold.NZ1YPIWS, maintie_gold.L5WF7WDA], [maintie_gold.RHREQXON, maintie_gold.ILFS9LOY], [maintie_gold.25190PSL, maintie_gold.LXA0929D], [maintie_gold.TC3KJP0H, maintie_gold.NAO955J6], [maintie_gold.Q8G1CU8U, maintie_gold.RDUDQ8NE], [maintie_gold.FH35E6TZ, maintie_gold.GO5XDD4Z], [maintie_gold.LY1NM3GZ, maintie_gold.1AI6VW0G], [maintie_gold.G2BYY1FR, maintie_gold.JFP64MT0], [maintie_gold.KT5KDSXX, maintie_gold.S2ZZXNUL], [maintie_gold.JS18XM7N, maintie_gold.XJZUE7SR], [maintie_gold.MT9N9WDZ, maintie_gold.4L95QAGB], [maintie_gold.SKVOKR8M, maintie_gold.SVGHLVEB], [maintie_gold.T6BNGN5B, maintie_gold.5WPMVFIC], [maintie_gold.JSU0GAPG, maintie_gold.NB3ZBLTE], [maintie_gold.7QNN665I, maintie_gold.RTCGVH1E], [maintie_gold.L5WKHDX6, maintie_gold.QU2FG99Y], [maintie_gold.IS6UJINM, maintie_gold.2NUQMDBY], [maintie_gold.MLE91ZI5, maintie_gold.HDI3192N], [maintie_gold.3SA0PKMB, maintie_gold.PYQ0LVOL]]
#
# Result 1:
# Type: [maintie_gold.Door], Label: ['17_door'], Comment: ['<id> air leak near side of door']
# Type: [maintie_gold.Air], Label: ['17_air'], Comment: ['<id> air leak near side of door']
#
# Result 2:
# Type: [maintie_gold.Engine], Label: ['196_engine'], Comment: ['<id> check / repair engine oil leak']
# Type: [maintie_gold.Oil], Label: ['196_oil'], Comment: ['<id> check / repair engine oil leak']
#
# Result 3:
# Type: [maintie_gold.OilCooler], Label: ['210_oil_cooler'], Comment: ['<id> coolant leak at engine oil cooler']
# Type: [maintie_gold.Coolant], Label: ['210_coolant'], Comment: ['<id> coolant leak at engine oil cooler']
#
# Result 4:
# Type: [maintie_gold.JacketWaterPump], Label: ['211_jacket_water_pump'], Comment: ['<id> coolant leak at jacket water pump']
# Type: [maintie_gold.Coolant], Label: ['211_coolant'], Comment: ['<id> coolant leak at jacket water pump']
#
# Result 5:
# Type: [maintie_gold.Differential], Label: ['257_differential'], Comment: ['<id> differential oil leak']
# Type: [maintie_gold.Oil], Label: ['257_oil'], Comment: ['<id> differential oil leak']
#
# Result 6:
# Type: [maintie_gold.Window], Label: ['269_window'], Comment: ['<id> dust leak operators side window']
# Type: [maintie_gold.Dust], Label: ['269_dust'], Comment: ['<id> dust leak operators side window']
#
# Result 7:
# Type: [maintie_gold.Engine], Label: ['372_engine'], Comment: ['<id> investigate engine oil leak']
# Type: [maintie_gold.Oil], Label: ['372_oil'], Comment: ['<id> investigate engine oil leak']
#
# Result 8:
# Type: [maintie_gold.AirCompressor], Label: ['385_air_compressor'], Comment: ['<id> oil leak at air compressor']
# Type: [maintie_gold.Oil], Label: ['385_oil'], Comment: ['<id> oil leak at air compressor']
#
# Result 9:
# Type: [maintie_gold.Swingbox], Label: ['398_swingbox'], Comment: ['oil leak swingbox <num>']
# Type: [maintie_gold.Oil], Label: ['398_oil'], Comment: ['oil leak swingbox <num>']
#
# Result 10:
# Type: [maintie_gold.Engine], Label: ['459_engine'], Comment: ['inspect bad engine oil leak']
# Type: [maintie_gold.Oil], Label: ['459_oil'], Comment: ['inspect bad engine oil leak']
#
# Result 11:
# Type: [maintie_gold.Differential], Label: ['602_differential'], Comment: ['<id> - differential oil leak']
# Type: [maintie_gold.Oil], Label: ['602_oil'], Comment: ['<id> - differential oil leak']
#
# Result 12:
# Type: [maintie_gold.Engine], Label: ['609_engine'], Comment: ['<id> - engine oil leak']
# Type: [maintie_gold.Oil], Label: ['609_oil'], Comment: ['<id> - engine oil leak']
#
# Result 13:
# Type: [maintie_gold.Engine], Label: ['610_engine'], Comment: ['<id> - engine oil leak - inspection plate']
# Type: [maintie_gold.Oil], Label: ['610_oil'], Comment: ['<id> - engine oil leak - inspection plate']
#
# Result 14:
# Type: [maintie_gold.Pump], Label: ['651_pump'], Comment: ['<id> - investigate torque converter fan pump oil leak']
# Type: [maintie_gold.Oil], Label: ['651_oil'], Comment: ['<id> - investigate torque converter fan pump oil leak']
#
# Result 15:
# Type: [maintie_gold.Transmission], Label: ['661_transmission'], Comment: ['<id> - minor transmission oil leak']
# Type: [maintie_gold.Oil], Label: ['661_oil'], Comment: ['<id> - minor transmission oil leak']
#
# Result 16:
# Type: [maintie_gold.Engine], Label: ['680_engine'], Comment: ['<id> - repair engine oil leak and']
# Type: [maintie_gold.Oil], Label: ['680_oil'], Comment: ['<id> - repair engine oil leak and']
#
# Result 17:
# Type: [maintie_gold.PilotFilter], Label: ['748_pilot_filter'], Comment: ['<id> <id> oil leak pilot filter text']
# Type: [maintie_gold.Oil], Label: ['748_oil'], Comment: ['<id> <id> oil leak pilot filter text']
#
# Result 18:
# Type: [maintie_gold.Engine], Label: ['749_engine'], Comment: ['<id> <id> repair engine oil leak text']
# Type: [maintie_gold.Oil], Label: ['749_oil'], Comment: ['<id> <id> repair engine oil leak text']
#
# Result 19:
# Type: [maintie_gold.Transmission], Label: ['750_transmission'], Comment: ['<id> <id> repair transmission oil leak text']
# Type: [maintie_gold.Oil], Label: ['750_oil'], Comment: ['<id> <id> repair transmission oil leak text']
#
# Result 20:
# Type: [maintie_gold.HighVoltageSlipRing], Label: ['907_high_voltage_slip_ring'], Comment: ['high voltage slip ring inspection - grease leak']
# Type: [maintie_gold.Grease], Label: ['907_grease'], Comment: ['high voltage slip ring inspection - grease leak']
#
# Result 21:
# Type: [maintie_gold.DiverterValve], Label: ['934_diverter_valve'], Comment: ['oil leak at diverter valve']
# Type: [maintie_gold.Oil], Label: ['934_oil'], Comment: ['oil leak at diverter valve']
#
# Result 22:
# Type: [maintie_gold.CoverPlate], Label: ['935_cover_plate'], Comment: ['oil leak inlet to oil burner cover plate']
# Type: [maintie_gold.Oil], Label: ['935_oil'], Comment: ['oil leak inlet to oil burner cover plate']
#
# Result 23:
# Type: [maintie_gold.SafetyValve], Label: ['974_safety_valve'], Comment: ['repair air leak at air tank safety valve']
# Type: [maintie_gold.Air], Label: ['974_air'], Comment: ['repair air leak at air tank safety valve']
#
# Result 24:
# Type: [maintie_gold.Line], Label: ['18_line'], Comment: ['<id> air leaking from line outside']
# Type: [maintie_gold.Air], Label: ['18_air'], Comment: ['<id> air leaking from line outside']
#
# Result 25:
# Type: [maintie_gold.Autogreaser], Label: ['32_autogreaser'], Comment: ['<id> auto-greaser leaking oil']
# Type: [maintie_gold.Oil], Label: ['32_oil'], Comment: ['<id> auto-greaser leaking oil']
#
# Result 26:
# Type: [maintie_gold.Seals], Label: ['111_seals'], Comment: ['<id> cabin seals leaking dust PO']
# Type: [maintie_gold.Dust], Label: ['111_dust'], Comment: ['<id> cabin seals leaking dust PO']
#
# Result 27:
# Type: [maintie_gold.Seals], Label: ['112_seals'], Comment: ['<id> cabin seals leaking dust bad']
# Type: [maintie_gold.Dust], Label: ['112_dust'], Comment: ['<id> cabin seals leaking dust bad']
#
# Result 28:
# Type: [maintie_gold.Chord], Label: ['202_chord'], Comment: ['<id> chord leaking air found <id>']
# Type: [maintie_gold.Air], Label: ['202_air'], Comment: ['<id> chord leaking air found <id>']
#
# Result 29:
# Type: [maintie_gold.Engine], Label: ['681_engine'], Comment: ['<id> - repair engine oil leaking']
# Type: [maintie_gold.Oil], Label: ['681_oil'], Comment: ['<id> - repair engine oil leaking']
#
# Result 30:
# Type: [maintie_gold.Chord], Label: ['742_chord'], Comment: ['<id> <id> chord is leaking air from crack']
# Type: [maintie_gold.Air], Label: ['742_air'], Comment: ['<id> <id> chord is leaking air from crack']
#
# Result 31:
# Type: [maintie_gold.AccessoryDrive], Label: ['790_accessory_drive'], Comment: ['<id> air conditioner accessory drive leaking oil']
# Type: [maintie_gold.Oil], Label: ['790_oil'], Comment: ['<id> air conditioner accessory drive leaking oil']
#
# Result 32:
# Type: [maintie_gold.Drive], Label: ['795_drive'], Comment: ['<id> air conditioner drive leaking oil']
# Type: [maintie_gold.Oil], Label: ['795_oil'], Comment: ['<id> air conditioner drive leaking oil']
#
# Result 33:
# Type: [maintie_gold.PilotValve], Label: ['944_pilot_valve'], Comment: ['pilot valve leaking oil']
# Type: [maintie_gold.Oil], Label: ['944_oil'], Comment: ['pilot valve leaking oil']
#
# Result 34:
# Type: [maintie_gold.WaterSeparator], Label: ['1070_water_separator'], Comment: ['water separator leaking fuel']
# Type: [maintie_gold.Fuel], Label: ['1070_fuel'], Comment: ['water separator leaking fuel']
#
# Result 35:
# Type: [maintie_gold.Engine], Label: ['411_engine'], Comment: ['<id> engine oil leaks right hand side']
# Type: [maintie_gold.Oil], Label: ['411_oil'], Comment: ['<id> engine oil leaks right hand side']
#
# Result 36:
# Type: [maintie_gold.CentreHitch], Label: ['441_centre_hitch'], Comment: ['<id> repair centre hitch oil leaks']
# Type: [maintie_gold.Oil], Label: ['441_oil'], Comment: ['<id> repair centre hitch oil leaks']
#
# Result 37:
# Type: [maintie_gold.Engine], Label: ['770_engine'], Comment: ['<id> CW engine oil leaks x <num>']
# Type: [maintie_gold.Oil], Label: ['770_oil'], Comment: ['<id> CW engine oil leaks x <num>']

# %% [markdown]
# **What is leaking something that is not stated?**

# %%
# %%sparql_query
# """
# PREFIX rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#>
# PREFIX owl: <http://www.w3.org/2002/07/owl#>
#
# SELECT DISTINCT ?agent
# WHERE {
#   # Find instances of Leak/Leaking/Leaks
#   {
#     ?leakInstance rdf:type <file://ONTOLOGY_NAME#Leak> .
#   }
#   UNION
#   {
#     ?leakInstance rdf:type <file://ONTOLOGY_NAME#Leaking> .
#   }
#   UNION
#   {
#     ?leakInstance rdf:type <file://ONTOLOGY_NAME#Leaks> .
#   }
#
#   # Ensure no has_patient association exists
#   FILTER NOT EXISTS {
#     ?leakInstance <file://ONTOLOGY_NAME#has_patient> ?substanceInstance .
#   }
#
#   # Find the agents of these leak instances
#   ?leakInstance <file://ONTOLOGY_NAME#has_agent> ?agent .
# }
# """
# Out:
# Results found: 69
#
# [[maintie_gold.IGZOUJTU], [maintie_gold.RDPN0Y3V], [maintie_gold.WQ6Q9KGP], [maintie_gold.7LLDG4JS], [maintie_gold.BO4L1T3T], [maintie_gold.9SEY54Z2], [maintie_gold.LKGX1XWR], [maintie_gold.KU8TH2KD], [maintie_gold.14KSUV6W], [maintie_gold.38N3CR48], [maintie_gold.G3R39IG0], [maintie_gold.SETZMQPQ], [maintie_gold.JH62IZWZ], [maintie_gold.CZNE3QQ7], [maintie_gold.7PIX0PCX], [maintie_gold.TUNN18WT], [maintie_gold.KWMM5BFI], [maintie_gold.L9Q0VA1A], [maintie_gold.K2Q1124R], [maintie_gold.T0CVZ91S], [maintie_gold.LKKAPH0V], [maintie_gold.8IOUNBXM], [maintie_gold.K1BZLN49], [maintie_gold.WK1ZAZI3], [maintie_gold.YJ6J3EZE], [maintie_gold.CH8R2PEF], [maintie_gold.6CE0RXHJ], [maintie_gold.G6U9WMAX], [maintie_gold.IM7GMB8Z], [maintie_gold.SXPFLPFO], [maintie_gold.M1ZIFKHD], [maintie_gold.TQPV75FJ], [maintie_gold.HP3W88V9], [maintie_gold.VB3MJA3N], [maintie_gold.1OEZUAGF], [maintie_gold.JY0AK3DJ], [maintie_gold.8NBJAUVQ], [maintie_gold.YHDO8NDO], [maintie_gold.YUY2T6R5], [maintie_gold.EO768HIZ], [maintie_gold.KTFFEUAJ], [maintie_gold.XFM4E7A9], [maintie_gold.P2KURYJV], [maintie_gold.27HNVPOY], [maintie_gold.U9DXKLC4], [maintie_gold.8K02J6W3], [maintie_gold.0OQP0FPA], [maintie_gold.R1Y7GS6E], [maintie_gold.7AS9IWP7], [maintie_gold.964U72IS], [maintie_gold.KBT279CO], [maintie_gold.DGX6EPMS], [maintie_gold.8VPJPNH1], [maintie_gold.6I5Q4O0G], [maintie_gold.SQLNW0O5], [maintie_gold.C4LHWRWS], [maintie_gold.X0T0VXZ9], [maintie_gold.SMZNAWEB], [maintie_gold.ETT3J777], [maintie_gold.0RBMS2F4], [maintie_gold.2CX8HR8R], [maintie_gold.IIOZVX8S], [maintie_gold.LK4EJ5NE], [maintie_gold.34VMGICB], [maintie_gold.APOM105X], [maintie_gold.33LFUV4A], [maintie_gold.T1BQ8PG1], [maintie_gold.UNQ04WNK], [maintie_gold.FMXE8UTJ]]
#
# Result 1:
# Type: [maintie_gold.Drive], Label: ['23_drive'], Comment: ['<id> alternator drive leaking']
#
# Result 2:
# Type: [maintie_gold.StickCylinders], Label: ['91_stick_cylinders'], Comment: ['<id> both stick cylinders leaking']
#
# Result 3:
# Type: [maintie_gold.CoolingHose], Label: ['92_cooling_hose'], Comment: ['<id> brake cooling hose leaking']
#
# Result 4:
# Type: [maintie_gold.CoolingHose], Label: ['93_cooling_hose'], Comment: ['<id> brake cooling hose leaking rear']
#
# Result 5:
# Type: [maintie_gold.CoolingReturnHose], Label: ['94_cooling_return_hose'], Comment: ['<id> brake cooling return hose leaking']
#
# Result 6:
# Type: [maintie_gold.Hose], Label: ['148_hose'], Comment: ['<id> change out leak slew motor hose']
#
# Result 7:
# Type: [maintie_gold.Hmu], Label: ['149_HMU'], Comment: ['<id> change out leaking HMU on next']
#
# Result 8:
# Type: [maintie_gold.Hoses], Label: ['150_hoses'], Comment: ['<id> change out leaking fan hoses']
#
# Result 9:
# Type: [maintie_gold.Taps], Label: ['151_taps'], Comment: ['<id> change out leaking heater taps']
#
# Result 10:
# Type: [maintie_gold.HydraulicHose], Label: ['152_hydraulic_hose'], Comment: ['<id> change out leaking hydraulic hose']
#
# Result 11:
# Type: [maintie_gold.ImplementPump], Label: ['153_implement_pump'], Comment: ['<id> change out leaking implement pump']
#
# Result 12:
# Type: [maintie_gold.RelayValve], Label: ['154_relay_valve'], Comment: ['<id> change out leaking relay valve']
#
# Result 13:
# Type: [maintie_gold.Hose], Label: ['155_hose'], Comment: ['<id> change out leaking steering hose']
#
# Result 14:
# Type: [maintie_gold.SteeringCylinder], Label: ['160_steering_cylinder'], Comment: ['<id> change out left hand steering cylinder leaking']
#
# Result 15:
# Type: [maintie_gold.CoolantHose], Label: ['208_coolant_hose'], Comment: ['<id> coolant hose leaking at right hand bottom']
#
# Result 16:
# Type: [maintie_gold.Coupling], Label: ['213_coupling'], Comment: ['<id> cooler return pipe coupling leak']
#
# Result 17:
# Type: [maintie_gold.Hose], Label: ['250_hose'], Comment: ['<id> differential cooler fan hose leaking']
#
# Result 18:
# Type: [maintie_gold.Hose], Label: ['251_hose'], Comment: ['<id> differential cooler hose leaking']
#
# Result 19:
# Type: [maintie_gold.Pump], Label: ['252_pump'], Comment: ['<id> differential cooler pump leaking']
#
# Result 20:
# Type: [maintie_gold.Differential], Label: ['253_differential'], Comment: ['<id> differential leak']
#
# Result 21:
# Type: [maintie_gold.LubePump], Label: ['255_lube_pump'], Comment: ['<id> differential lube pump leaking']
#
# Result 22:
# Type: [maintie_gold.LubePump], Label: ['256_lube_pump'], Comment: ['<id> differential lube pump leaking PO']
#
# Result 23:
# Type: [maintie_gold.Hose], Label: ['258_hose'], Comment: ['<id> differential pump motor hose leaking']
#
# Result 24:
# Type: [maintie_gold.DuoconeSeals], Label: ['268_duocone_seals'], Comment: ['<id> duo-cone seals leaking number <num> swing']
#
# Result 25:
# Type: [maintie_gold.TransferPipe], Label: ['285_transfer_pipe'], Comment: ['<id> replace leaking transfer pipe']
#
# Result 26:
# Type: [maintie_gold.FuelTank], Label: ['304_fuel_tank'], Comment: ['<id> possible minor leak on fuel tank']
#
# Result 27:
# Type: [maintie_gold.Accumulator], Label: ['312_accumulator'], Comment: ['<id> rear steering accumulator leak']
#
# Result 28:
# Type: [maintie_gold.Seals], Label: ['328_seals'], Comment: ['repair leaking swing <num> pedestal seals']
#
# Result 29:
# Type: [maintie_gold.LiftCylinder], Label: ['373_lift_cylinder'], Comment: ['<id> replace right hand lift cylinder leaking']
#
# Result 30:
# Type: [maintie_gold.ScavengePump], Label: ['386_scavenge_pump'], Comment: ['<id> replace leaking scavenge pump']
#
# Result 31:
# Type: [maintie_gold.Hose], Label: ['389_hose'], Comment: ['change out leaking transmission hose']
#
# Result 32:
# Type: [maintie_gold.Tap], Label: ['409_tap'], Comment: ['middle air drain tap leaking']
#
# Result 33:
# Type: [maintie_gold.CoolingHose], Label: ['421_cooling_hose'], Comment: ['<id> leaking brake cooling hose']
#
# Result 34:
# Type: [maintie_gold.CoolingHose], Label: ['438_cooling_hose'], Comment: ['<id> left hand rear brake cooling hose leaking']
#
# Result 35:
# Type: [maintie_gold.Fitting], Label: ['440_fitting'], Comment: ['fitting leaking out of main air tanks']
#
# Result 36:
# Type: [maintie_gold.BulkFuelTank], Label: ['446_bulk_fuel_tank'], Comment: ['bulk fuel tank cracked and leaking']
#
# Result 37:
# Type: [maintie_gold.HydraulicHose], Label: ['447_hydraulic_hose'], Comment: ['hydraulic hose leaking in centre of machine']
#
# Result 38:
# Type: [maintie_gold.Exhaust], Label: ['490_exhaust'], Comment: ['<id> repair exhaust leaks']
#
# Result 39:
# Type: [maintie_gold.StickCylinder], Label: ['492_stick_cylinder'], Comment: ['stick cylinder leaking']
#
# Result 40:
# Type: [maintie_gold.Plug], Label: ['499_plug'], Comment: ['<id> - CW left hand hoist cylinder leaking plug']
#
# Result 41:
# Type: [maintie_gold.Radiator], Label: ['500_radiator'], Comment: ['<id> - CW radiator core leak']
#
# Result 42:
# Type: [maintie_gold.HoistCylinder], Label: ['501_hoist_cylinder'], Comment: ['<id> - CW right hand hoist cylinder leaking']
#
# Result 43:
# Type: [maintie_gold.InputSeal], Label: ['506_input_seal'], Comment: ['<id> - PTO shaft input seal leaking']
#
# Result 44:
# Type: [maintie_gold.AirConditioner], Label: ['523_air_conditioner'], Comment: ['<id> - air conditioner system leaking']
#
# Result 45:
# Type: [maintie_gold.Hose], Label: ['564_hose'], Comment: ['<id> - change out leaking transmission hose']
#
# Result 46:
# Type: [maintie_gold.LubeHose], Label: ['601_lube_hose'], Comment: ['<id> - differential lube hose leaking']
#
# Result 47:
# Type: [maintie_gold.Exhaust], Label: ['616_exhaust'], Comment: ['<id> - exhaust leak']
#
# Result 48:
# Type: [maintie_gold.Hose], Label: ['617_hose'], Comment: ['<id> - fan hose leaking']
#
# Result 49:
# Type: [maintie_gold.Hose], Label: ['630_hose'], Comment: ['<id> - hose leak developing']
#
# Result 50:
# Type: [maintie_gold.Hose], Label: ['653_hose'], Comment: ['<id> - left hand boom cylinder hose leaking PO']
#
# Result 51:
# Type: [maintie_gold.ReliefValves], Label: ['668_relief_valves'], Comment: ['<id> - radiator relief valves leaking']
#
# Result 52:
# Type: [maintie_gold.Accumulator], Label: ['669_accumulator'], Comment: ['<id> - rear steering accumulator leaking']
#
# Result 53:
# Type: [maintie_gold.CentrifugalFilter], Label: ['684_centrifugal_filter'], Comment: ['<id> - repair leaking centrifugal filter']
#
# Result 54:
# Type: [maintie_gold.SteeringCylinder], Label: ['709_steering_cylinder'], Comment: ['<id> - replace leaking steering cylinder']
#
# Result 55:
# Type: [maintie_gold.SteeringHose], Label: ['723_steering_hose'], Comment: ['<id> - replaced leaking steering hose']
#
# Result 56:
# Type: [maintie_gold.ChargeHose], Label: ['734_charge_hose'], Comment: ['<id> - transmission charge hose leaking']
#
# Result 57:
# Type: [maintie_gold.RadiatorTank], Label: ['773_radiator_tank'], Comment: ['<id> CW top radiator tank leak again']
#
# Result 58:
# Type: [maintie_gold.InputSeal], Label: ['782_input_seal'], Comment: ['<id> PTO input seal leaking']
#
# Result 59:
# Type: [maintie_gold.Adaptor], Label: ['787_adaptor'], Comment: ['<id> adaptor leaking at implement valve']
#
# Result 60:
# Type: [maintie_gold.Drive], Label: ['794_drive'], Comment: ['<id> air conditioner drive leaking']
#
# Result 61:
# Type: [maintie_gold.Hose], Label: ['836_hose'], Comment: ['centrifuge hose leaking - replace']
#
# Result 62:
# Type: [maintie_gold.SafetyValve], Label: ['854_safety_valve'], Comment: ['compressor safety valve leaking']
#
# Result 63:
# Type: [maintie_gold.GreaseDistributor], Label: ['902_grease_distributor'], Comment: ['grease distributor leaking']
#
# Result 64:
# Type: [maintie_gold.Gasket], Label: ['933_gasket'], Comment: ['oil centrifuge gasket leaking right hand engine']
#
# Result 65:
# Type: [maintie_gold.PressureCompensator], Label: ['949_pressure_compensator'], Comment: ['pressure compensator leaking']
#
# Result 66:
# Type: [maintie_gold.PressureControlValve], Label: ['950_pressure_control_valve'], Comment: ['pressure control valve in cabin leaking']
#
# Result 67:
# Type: [maintie_gold.Solenoid], Label: ['989_solenoid'], Comment: ['repair leak in pilot valve solenoid']
#
# Result 68:
# Type: [maintie_gold.ChipIndicators], Label: ['1011_chip_indicators'], Comment: ['replace chip indicators ( leaking )']
#
# Result 69:
# Type: [maintie_gold.Filter], Label: ['1069_filter'], Comment: ['water separator filter leaking see photo']

# %% [markdown]
# **What needs to be replaced because its seized?**

# %%
# %%sparql_query
# """
# PREFIX rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#>
# PREFIX owl: <http://www.w3.org/2002/07/owl#>
#
# SELECT DISTINCT ?physicalObject
# WHERE {
#   # Find instances of Seized
#   ?seizedInstance rdf:type <file://ONTOLOGY_NAME#Seized> .
#   ?seizedInstance <file://ONTOLOGY_NAME#has_patient> ?physicalObject .
#
#   # Find instances of Replace
#   ?replaceInstance rdf:type <file://ONTOLOGY_NAME#Replace> .
#   ?replaceInstance <file://ONTOLOGY_NAME#has_patient> ?physicalObject .
# }
# """
# Out:
# Results found: 1
#
# [[maintie_gold.OYW9QRAZ]]
#
# Result 1:
# Type: [maintie_gold.ControlCable], Label: ['1028_control_cable'], Comment: ['replace seized air conditioner control cable']

# %% [markdown]
# **What activities are performed in respond to X (blown, leak, etc.)?**

# %%
# %%sparql_query
# """
# PREFIX rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#>
# PREFIX owl: <http://www.w3.org/2002/07/owl#>
#
# SELECT DISTINCT ?stateInstance ?activityInstance ?physicalObject
# WHERE {
#   # Find instances of State
#   ?stateInstance <file://ONTOLOGY_NAME#has_patient> ?physicalObject .
#
#   # Find physical objects that are patients of the state instances
#   ?stateClass rdfs:subClassOf* <file://ONTOLOGY_NAME#State> .
#   ?stateInstance rdf:type ?stateClass .
#
#   # Find activities related to these physical objects
#   ?activityInstance <file://ONTOLOGY_NAME#has_patient> ?physicalObject .
#   ?activityClass rdfs:subClassOf* <file://ONTOLOGY_NAME#Activity> .
#   ?activityInstance rdf:type ?activityClass .
# }
# """
# Out:
# Results found: 100
#
# [[maintie_gold.VN92ZSW4, maintie_gold.3OZZ2DUC, maintie_gold.P7NBFI07], [maintie_gold.VN92ZSW4, maintie_gold.5MA86OW7, maintie_gold.P7NBFI07], [maintie_gold.JS74DUQB, maintie_gold.NJV0PUIW, maintie_gold.NKIWOBW1], [maintie_gold.LWSUREM8, maintie_gold.QYT7OJ17, maintie_gold.7B5WH7BJ], [maintie_gold.LWSUREM8, maintie_gold.DAZYDZCX, maintie_gold.7B5WH7BJ], [maintie_gold.MZRN7A2E, maintie_gold.WXZCBYHE, maintie_gold.SB085I7M], [maintie_gold.MZRN7A2E, maintie_gold.7TDAH58A, maintie_gold.SB085I7M], [maintie_gold.5UO12G3E, maintie_gold.X0R5WWHB, maintie_gold.8A2PY03C], [maintie_gold.LXND413V, maintie_gold.ZHA52UTE, maintie_gold.9F0DG036], [maintie_gold.ZHXPPXL7, maintie_gold.JFJ06S2T, maintie_gold.B30R9IQW], [maintie_gold.B3FGZRC0, maintie_gold.EVYY1DU7, maintie_gold.K6ZVXWY6], [maintie_gold.5JXPQGA3, maintie_gold.BZVKTA6V, maintie_gold.JU9O3J5R], [maintie_gold.WCJPPY6S, maintie_gold.WEL1FRET, maintie_gold.V9ZYIPNZ], [maintie_gold.CPMATP35, maintie_gold.CAXSJ3S8, maintie_gold.RT5IA0UY], [maintie_gold.QCQEYCIO, maintie_gold.VIHXSZV4, maintie_gold.HEY7O1MI], [maintie_gold.DVODYL1O, maintie_gold.BH1S7HMC, maintie_gold.SGT38663], [maintie_gold.MQ5CTOSI, maintie_gold.WQOC8LZ6, maintie_gold.EB66W6NT], [maintie_gold.MQ5CTOSI, maintie_gold.8CVPH52P, maintie_gold.EB66W6NT], [maintie_gold.7ZCZ6GM6, maintie_gold.UQHZ1KV8, maintie_gold.8MKXAVRC], [maintie_gold.7ZCZ6GM6, maintie_gold.5LEE26PP, maintie_gold.8MKXAVRC], [maintie_gold.ALBNOKFE, maintie_gold.HU5N9RLE, maintie_gold.40OT0GKD], [maintie_gold.LLJ070EG, maintie_gold.SKCHGP66, maintie_gold.F9PK7NJQ], [maintie_gold.SKCXWLST, maintie_gold.X699TD3C, maintie_gold.19KPS9ZB], [maintie_gold.3B1ES86A, maintie_gold.N8O0KXCW, maintie_gold.RAVZAQJE], [maintie_gold.HKBRSWO5, maintie_gold.2VODE1SL, maintie_gold.Q9ZOKMQF], [maintie_gold.1ZF7SPV3, maintie_gold.C43SS088, maintie_gold.O4NMXUL5], [maintie_gold.JTYL0KSN, maintie_gold.X301XNX8, maintie_gold.O7D1H40I], [maintie_gold.8ZAZX473, maintie_gold.HAITS9J9, maintie_gold.P6KZJ40E], [maintie_gold.6L1NXTWC, maintie_gold.V0GHPGTV, maintie_gold.E4CE2WHM], [maintie_gold.GMNOCLIJ, maintie_gold.NSOXBYWS, maintie_gold.1TDXCKIS], [maintie_gold.S74S76RG, maintie_gold.L1YYI8ZA, maintie_gold.7WIZNS7E], [maintie_gold.328ZFAJL, maintie_gold.EHHJ62MF, maintie_gold.HBOQ7NKK], [maintie_gold.6EOH79QD, maintie_gold.LQCXY8YH, maintie_gold.JYHGPDIY], [maintie_gold.6EOH79QD, maintie_gold.LQCXY8YH, maintie_gold.T0VGTMN9], [maintie_gold.YSE27OPZ, maintie_gold.6444K0C1, maintie_gold.M9JKFBBL], [maintie_gold.XQO0AVDL, maintie_gold.64V809MK, maintie_gold.4VYJ2Z2I], [maintie_gold.F9IJG52T, maintie_gold.GQAL0JAD, maintie_gold.9OA1PUIU], [maintie_gold.GCBQMFO5, maintie_gold.EUVDYBTK, maintie_gold.98T97J9A], [maintie_gold.9D82071M, maintie_gold.VT54B6D7, maintie_gold.CMK5JY8K], [maintie_gold.Q7M6GWXL, maintie_gold.HFHB4D6I, maintie_gold.I7DUKD0B], [maintie_gold.GPY18VEU, maintie_gold.8TALN6ZY, maintie_gold.8U2AATEN], [maintie_gold.A6FTB5G9, maintie_gold.AEU2ECCI, maintie_gold.MZ662EPJ], [maintie_gold.SGI8LRSU, maintie_gold.6AJZSVTX, maintie_gold.6SDB4E7B], [maintie_gold.TQGKPN79, maintie_gold.RMJCW1Y1, maintie_gold.CZGVQ3VL], [maintie_gold.3WM48YIL, maintie_gold.P9VWW2H6, maintie_gold.0IXGZZN3], [maintie_gold.4YIYFTS5, maintie_gold.1RRW330P, maintie_gold.YE3M2575], [maintie_gold.JPZR0LNH, maintie_gold.JB058GZ9, maintie_gold.B71CIV4D], [maintie_gold.NHQMTQNJ, maintie_gold.Z0A2KKTL, maintie_gold.2Y0YG870], [maintie_gold.IIUPT5PD, maintie_gold.LY6OY58H, maintie_gold.LNL044BU], [maintie_gold.XB1T4W82, maintie_gold.IDQGXRCA, maintie_gold.GX39BIIL], [maintie_gold.WCJYPS7Q, maintie_gold.P6M020U6, maintie_gold.HX4LQ5OH], [maintie_gold.M5A5U4WN, maintie_gold.1FACQTCK, maintie_gold.KG0N9LHI], [maintie_gold.9B8SQ0JL, maintie_gold.6KMS5Q58, maintie_gold.4K8YO8DF], [maintie_gold.GY46M7KS, maintie_gold.0VIVQ7N6, maintie_gold.K52OLNML], [maintie_gold.X03YG27Z, maintie_gold.1H9P7N6V, maintie_gold.QOORX1A3], [maintie_gold.6UEO8HCA, maintie_gold.JVQTOI4O, maintie_gold.RTVAGPJU], [maintie_gold.L9M5Q12A, ...
#
# Result 1:
# Type: [maintie_gold.Faults], Label: ['245_faults'], Comment: ['<id> diagnose and repair spray faults']
# Type: [maintie_gold.Repair], Label: ['245_repair'], Comment: ['<id> diagnose and repair spray faults']
# Type: [maintie_gold.Spray], Label: ['245_spray'], Comment: ['<id> diagnose and repair spray faults']
#
# Result 2:
# Type: [maintie_gold.Faults], Label: ['245_faults'], Comment: ['<id> diagnose and repair spray faults']
# Type: [maintie_gold.Diagnose], Label: ['245_diagnose'], Comment: ['<id> diagnose and repair spray faults']
# Type: [maintie_gold.Spray], Label: ['245_spray'], Comment: ['<id> diagnose and repair spray faults']
#
# Result 3:
# Type: [maintie_gold.Fault], Label: ['247_fault'], Comment: ['<id> diagnose engine fault']
# Type: [maintie_gold.Diagnose], Label: ['247_diagnose'], Comment: ['<id> diagnose engine fault']
# Type: [maintie_gold.Engine], Label: ['247_engine'], Comment: ['<id> diagnose engine fault']
#
# Result 4:
# Type: [maintie_gold.Fault], Label: ['364_fault'], Comment: ['<id> investigate / repair no gear fault']
# Type: [maintie_gold.Repair], Label: ['364_repair'], Comment: ['<id> investigate / repair no gear fault']
# Type: [maintie_gold.Gear], Label: ['364_gear'], Comment: ['<id> investigate / repair no gear fault']
#
# Result 5:
# Type: [maintie_gold.Fault], Label: ['364_fault'], Comment: ['<id> investigate / repair no gear fault']
# Type: [maintie_gold.Investigate], Label: ['364_investigate'], Comment: ['<id> investigate / repair no gear fault']
# Type: [maintie_gold.Gear], Label: ['364_gear'], Comment: ['<id> investigate / repair no gear fault']
#
# Result 6:
# Type: [maintie_gold.Fault], Label: ['375_fault'], Comment: ['diagnose and repair ladder fault']
# Type: [maintie_gold.Repair], Label: ['375_repair'], Comment: ['diagnose and repair ladder fault']
# Type: [maintie_gold.Ladder], Label: ['375_ladder'], Comment: ['diagnose and repair ladder fault']
#
# Result 7:
# Type: [maintie_gold.Fault], Label: ['375_fault'], Comment: ['diagnose and repair ladder fault']
# Type: [maintie_gold.Diagnose], Label: ['375_diagnose'], Comment: ['diagnose and repair ladder fault']
# Type: [maintie_gold.Ladder], Label: ['375_ladder'], Comment: ['diagnose and repair ladder fault']
#
# Result 8:
# Type: [maintie_gold.Fault], Label: ['417_fault'], Comment: ['<id> investigate auto-lube fault']
# Type: [maintie_gold.Investigate], Label: ['417_investigate'], Comment: ['<id> investigate auto-lube fault']
# Type: [maintie_gold.Autolube], Label: ['417_autolube'], Comment: ['<id> investigate auto-lube fault']
#
# Result 9:
# Type: [maintie_gold.Fault], Label: ['430_fault'], Comment: ['<id> repair brake fault']
# Type: [maintie_gold.Repair], Label: ['430_repair'], Comment: ['<id> repair brake fault']
# Type: [maintie_gold.Brake], Label: ['430_brake'], Comment: ['<id> repair brake fault']
#
# Result 10:
# Type: [maintie_gold.Fault], Label: ['450_fault'], Comment: ['<id> repair gear fault']
# Type: [maintie_gold.Repair], Label: ['450_repair'], Comment: ['<id> repair gear fault']
# Type: [maintie_gold.Gear], Label: ['450_gear'], Comment: ['<id> repair gear fault']
#
# Result 11:
# Type: [maintie_gold.Fault], Label: ['451_fault'], Comment: ['<id> repair air conditioner and wiring fault']
# Type: [maintie_gold.Repair], Label: ['451_repair'], Comment: ['<id> repair air conditioner and wiring fault']
# Type: [maintie_gold.Wiring], Label: ['451_wiring'], Comment: ['<id> repair air conditioner and wiring fault']
#
# Result 12:
# Type: [maintie_gold.Fault], Label: ['687_fault'], Comment: ['<id> - repair transmission fault']
# Type: [maintie_gold.Repair], Label: ['687_repair'], Comment: ['<id> - repair transmission fault']
# Type: [maintie_gold.Transmission], Label: ['687_transmission'], Comment: ['<id> - repair transmission fault']
#
# Result 13:
# Type: [maintie_gold.SlippingFault], Label: ['249_slipping_fault'], Comment: ['<id> diagnose transmission slipping fault']
# Type: [maintie_gold.Diagnose], Label: ['249_diagnose'], Comment: ['<id> diagnose transmission slipping fault']
# Type: [maintie_gold.Transmission], Label: ['249_transmission'], Comment: ['<id> diagnose transmission slipping fault']
#
# Result 14:
# Type: [maintie_gold.OverloadFault], Label: ['914_overload_fault'], Comment: ['investigate main transformer overload fault']
# Type: [maintie_gold.Investigate], Label: ['914_investigate'], Comment: ['investigate main transformer overload fault']
# Type: [maintie_gold.Transformer], Label: ['914_transformer'], Comment: ['investigate main transformer overload fault']
#
# Result 15:
# Type: [maintie_gold.OverheatFault], Label: ['248_overheat_fault'], Comment: ['<id> diagnose transmission overheat fault']
# Type: [maintie_gold.Diagnose], Label: ['248_diagnose'], Comment: ['<id> diagnose transmission overheat fault']
# Type: [maintie_gold.Transmission], Label: ['248_transmission'], Comment: ['<id> diagnose transmission overheat fault']
#
# Result 16:
# Type: [maintie_gold.Error], Label: ['486_error'], Comment: ['diagnose VIMS error']
# Type: [maintie_gold.Diagnose], Label: ['486_diagnose'], Comment: ['diagnose VIMS error']
# Type: [maintie_gold.Vims], Label: ['486_VIMS'], Comment: ['diagnose VIMS error']
#
# Result 17:
# Type: [maintie_gold.TemperatureError], Label: ['246_temperature_error'], Comment: ['<id> diagnose and repair torque converter temperature error']
# Type: [maintie_gold.Repair], Label: ['246_repair'], Comment: ['<id> diagnose and repair torque converter temperature error']
# Type: [maintie_gold.TorqueConverter], Label: ['246_torque_converter'], Comment: ['<id> diagnose and repair torque converter temperature error']
#
# Result 18:
# Type: [maintie_gold.TemperatureError], Label: ['246_temperature_error'], Comment: ['<id> diagnose and repair torque converter temperature error']
# Type: [maintie_gold.Diagnose], Label: ['246_diagnose'], Comment: ['<id> diagnose and repair torque converter temperature error']
# Type: [maintie_gold.TorqueConverter], Label: ['246_torque_converter'], Comment: ['<id> diagnose and repair torque converter temperature error']
#
# Result 19:
# Type: [maintie_gold.NotWorking], Label: ['867_not_working'], Comment: ['diagnose / repair right hand scoreboard not working']
# Type: [maintie_gold.Repair], Label: ['867_repair'], Comment: ['diagnose / repair right hand scoreboard not working']
# Type: [maintie_gold.Scoreboard], Label: ['867_scoreboard'], Comment: ['diagnose / repair right hand scoreboard not working']
#
# Result 20:
# Type: [maintie_gold.NotWorking], Label: ['867_not_working'], Comment: ['diagnose / repair right hand scoreboard not working']
# Type: [maintie_gold.Diagnose], Label: ['867_diagnose'], Comment: ['diagnose / repair right hand scoreboard not working']
# Type: [maintie_gold.Scoreboard], Label: ['867_scoreboard'], Comment: ['diagnose / repair right hand scoreboard not working']
#
# Result 21:
# Type: [maintie_gold.Unserviceable], Label: ['176_unserviceable'], Comment: ['<id> change out unserviceable jacket water pump']
# Type: [maintie_gold.ChangeOut], Label: ['176_change_out'], Comment: ['<id> change out unserviceable jacket water pump']
# Type: [maintie_gold.JacketWaterPump], Label: ['176_jacket_water_pump'], Comment: ['<id> change out unserviceable jacket water pump']
#
# Result 22:
# Type: [maintie_gold.Unserviceable], Label: ['177_unserviceable'], Comment: ['<id> change out unserviceable left hand bucket cylinder hose']
# Type: [maintie_gold.ChangeOut], Label: ['177_change_out'], Comment: ['<id> change out unserviceable left hand bucket cylinder hose']
# Type: [maintie_gold.Hose], Label: ['177_hose'], Comment: ['<id> change out unserviceable left hand bucket cylinder hose']
#
# Result 23:
# Type: [maintie_gold.Unserviceable], Label: ['178_unserviceable'], Comment: ['<id> change out unserviceable position <num> tyre']
# Type: [maintie_gold.ChangeOut], Label: ['178_change_out'], Comment: ['<id> change out unserviceable position <num> tyre']
# Type: [maintie_gold.Tyre], Label: ['178_tyre'], Comment: ['<id> change out unserviceable position <num> tyre']
#
# Result 24:
# Type: [maintie_gold.Unserviceable], Label: ['179_unserviceable'], Comment: ['<id> change out unserviceable right hand clam cylinder hose']
# Type: [maintie_gold.ChangeOut], Label: ['179_change_out'], Comment: ['<id> change out unserviceable right hand clam cylinder hose']
# Type: [maintie_gold.Hose], Label: ['179_hose'], Comment: ['<id> change out unserviceable right hand clam cylinder hose']
#
# Result 25:
# Type: [maintie_gold.Unserviceable], Label: ['180_unserviceable'], Comment: ['<id> change out unserviceable right hand tilt cylinder']
# Type: [maintie_gold.ChangeOut], Label: ['180_change_out'], Comment: ['<id> change out unserviceable right hand tilt cylinder']
# Type: [maintie_gold.TiltCylinder], Label: ['180_tilt_cylinder'], Comment: ['<id> change out unserviceable right hand tilt cylinder']
#
# Result 26:
# Type: [maintie_gold.Unserviceable], Label: ['181_unserviceable'], Comment: ['<id> change out unserviceable swing brake cylinder']
# Type: [maintie_gold.ChangeOut], Label: ['181_change_out'], Comment: ['<id> change out unserviceable swing brake cylinder']
# Type: [maintie_gold.SwingBrakeCylinder], Label: ['181_swing_brake_cylinder'], Comment: ['<id> change out unserviceable swing brake cylinder']
#
# Result 27:
# Type: [maintie_gold.Unserviceable], Label: ['351_unserviceable'], Comment: ['<id> replace unserviceable differential drain plugs']
# Type: [maintie_gold.Replace], Label: ['351_replace'], Comment: ['<id> replace unserviceable differential drain plugs']
# Type: [maintie_gold.DrainPlugs], Label: ['351_drain_plugs'], Comment: ['<id> replace unserviceable differential drain plugs']
#
# Result 28:
# Type: [maintie_gold.Unserviceable], Label: ['796_unserviceable'], Comment: ['<id> air conditioner fan unserviceable - fit new']
# Type: [maintie_gold.Fit], Label: ['796_fit'], Comment: ['<id> air conditioner fan unserviceable - fit new']
# Type: [maintie_gold.Fan], Label: ['796_fan'], Comment: ['<id> air conditioner fan unserviceable - fit new']
#
# Result 29:
# Type: [maintie_gold.Unserviceable], Label: ['970_unserviceable'], Comment: ['remove unserviceable air separator']
# Type: [maintie_gold.Remove], Label: ['970_remove'], Comment: ['remove unserviceable air separator']
# Type: [maintie_gold.AirSeparator], Label: ['970_air_separator'], Comment: ['remove unserviceable air separator']
#
# Result 30:
# Type: [maintie_gold.Unserviceable], Label: ['1032_unserviceable'], Comment: ['replace unserviceable grease distributor']
# Type: [maintie_gold.Replace], Label: ['1032_replace'], Comment: ['replace unserviceable grease distributor']
# Type: [maintie_gold.GreaseDistributor], Label: ['1032_grease_distributor'], Comment: ['replace unserviceable grease distributor']
#
# Result 31:
# Type: [maintie_gold.Unserviceable], Label: ['1033_unserviceable'], Comment: ['replace unserviceable chip indicators']
# Type: [maintie_gold.Replace], Label: ['1033_replace'], Comment: ['replace unserviceable chip indicators']
# Type: [maintie_gold.ChipIndicators], Label: ['1033_chip_indicators'], Comment: ['replace unserviceable chip indicators']
#
# Result 32:
# Type: [maintie_gold.Unserviceable], Label: ['1034_unserviceable'], Comment: ['replace unserviceable ignition switch']
# Type: [maintie_gold.Replace], Label: ['1034_replace'], Comment: ['replace unserviceable ignition switch']
# Type: [maintie_gold.IgnitionSwitch], Label: ['1034_ignition_switch'], Comment: ['replace unserviceable ignition switch']
#
# Result 33:
# Type: [maintie_gold.Unserviceable], Label: ['1035_unserviceable'], Comment: ['replace unserviceable transmission screen and magnet']
# Type: [maintie_gold.Replace], Label: ['1035_replace'], Comment: ['replace unserviceable transmission screen and magnet']
# Type: [maintie_gold.Screen], Label: ['1035_screen'], Comment: ['replace unserviceable transmission screen and magnet']
#
# Result 34:
# Type: [maintie_gold.Unserviceable], Label: ['1035_unserviceable'], Comment: ['replace unserviceable transmission screen and magnet']
# Type: [maintie_gold.Replace], Label: ['1035_replace'], Comment: ['replace unserviceable transmission screen and magnet']
# Type: [maintie_gold.Magnet], Label: ['1035_magnet'], Comment: ['replace unserviceable transmission screen and magnet']
#
# Result 35:
# Type: [maintie_gold.Plugged], Label: ['572_plugged'], Comment: ['<id> - change out plugged fuel filters']
# Type: [maintie_gold.ChangeOut], Label: ['572_change_out'], Comment: ['<id> - change out plugged fuel filters']
# Type: [maintie_gold.FuelFilters], Label: ['572_fuel_filters'], Comment: ['<id> - change out plugged fuel filters']
#
# Result 36:
# Type: [maintie_gold.Failed], Label: ['28_failed'], Comment: ['<id> analyse failed driveline component']
# Type: [maintie_gold.Analyse], Label: ['28_analyse'], Comment: ['<id> analyse failed driveline component']
# Type: [maintie_gold.Driveline], Label: ['28_driveline'], Comment: ['<id> analyse failed driveline component']
#
# Result 37:
# Type: [maintie_gold.Failed], Label: ['707_failed'], Comment: ['<id> - replace failed air conditioner compressor']
# Type: [maintie_gold.Replace], Label: ['707_replace'], Comment: ['<id> - replace failed air conditioner compressor']
# Type: [maintie_gold.Compressor], Label: ['707_compressor'], Comment: ['<id> - replace failed air conditioner compressor']
#
# Result 38:
# Type: [maintie_gold.Broken], Label: ['134_broken'], Comment: ['<id> change out broken bolt on brake pump']
# Type: [maintie_gold.ChangeOut], Label: ['134_change_out'], Comment: ['<id> change out broken bolt on brake pump']
# Type: [maintie_gold.Bolt], Label: ['134_bolt'], Comment: ['<id> change out broken bolt on brake pump']
#
# Result 39:
# Type: [maintie_gold.Broken], Label: ['135_broken'], Comment: ['<id> change out broken prelube bracket']
# Type: [maintie_gold.ChangeOut], Label: ['135_change_out'], Comment: ['<id> change out broken prelube bracket']
# Type: [maintie_gold.Bracket], Label: ['135_bracket'], Comment: ['<id> change out broken prelube bracket']
#
# Result 40:
# Type: [maintie_gold.Broken], Label: ['136_broken'], Comment: ['<id> change out broken stabilizer bar']
# Type: [maintie_gold.ChangeOut], Label: ['136_change_out'], Comment: ['<id> change out broken stabilizer bar']
# Type: [maintie_gold.StabilizerBar], Label: ['136_stabilizer_bar'], Comment: ['<id> change out broken stabilizer bar']
#
# Result 41:
# Type: [maintie_gold.Broken], Label: ['144_broken'], Comment: ['<id> change out exhaust clamp broken on left hand side [t |]']
# Type: [maintie_gold.ChangeOut], Label: ['144_change_out'], Comment: ['<id> change out exhaust clamp broken on left hand side [t |]']
# Type: [maintie_gold.Clamp], Label: ['144_clamp'], Comment: ['<id> change out exhaust clamp broken on left hand side [t |]']
#
# Result 42:
# Type: [maintie_gold.Broken], Label: ['265_broken'], Comment: ['<id> drill out broken bolt see text']
# Type: [maintie_gold.DrillOut], Label: ['265_drill_out'], Comment: ['<id> drill out broken bolt see text']
# Type: [maintie_gold.Bolt], Label: ['265_bolt'], Comment: ['<id> drill out broken bolt see text']
#
# Result 43:
# Type: [maintie_gold.Broken], Label: ['546_broken'], Comment: ['<id> - change out broken grease lines']
# Type: [maintie_gold.ChangeOut], Label: ['546_change_out'], Comment: ['<id> - change out broken grease lines']
# Type: [maintie_gold.GreaseLines], Label: ['546_grease_lines'], Comment: ['<id> - change out broken grease lines']
#
# Result 44:
# Type: [maintie_gold.Broken], Label: ['689_broken'], Comment: ['<id> - repaired <num> x broken lines']
# Type: [maintie_gold.Repaired], Label: ['689_repaired'], Comment: ['<id> - repaired <num> x broken lines']
# Type: [maintie_gold.Lines], Label: ['689_lines'], Comment: ['<id> - repaired <num> x broken lines']
#
# Result 45:
# Type: [maintie_gold.Broken], Label: ['700_broken'], Comment: ['<id> - replace broken onside mirror']
# Type: [maintie_gold.Replace], Label: ['700_replace'], Comment: ['<id> - replace broken onside mirror']
# Type: [maintie_gold.Mirror], Label: ['700_mirror'], Comment: ['<id> - replace broken onside mirror']
#
# Result 46:
# Type: [maintie_gold.Broken], Label: ['768_broken'], Comment: ['<id> Bradken to repair broken clam']
# Type: [maintie_gold.Repair], Label: ['768_repair'], Comment: ['<id> Bradken to repair broken clam']
# Type: [maintie_gold.Clam], Label: ['768_clam'], Comment: ['<id> Bradken to repair broken clam']
#
# Result 47:
# Type: [maintie_gold.Broken], Label: ['850_broken'], Comment: ['collect broken tooth']
# Type: [maintie_gold.Collect], Label: ['850_collect'], Comment: ['collect broken tooth']
# Type: [maintie_gold.Tooth], Label: ['850_tooth'], Comment: ['collect broken tooth']
#
# Result 48:
# Type: [maintie_gold.Broken], Label: ['908_broken'], Comment: ['ignition switch broken replace']
# Type: [maintie_gold.Replace], Label: ['908_replace'], Comment: ['ignition switch broken replace']
# Type: [maintie_gold.IgnitionSwitch], Label: ['908_ignition_switch'], Comment: ['ignition switch broken replace']
#
# Result 49:
# Type: [maintie_gold.Broken], Label: ['1007_broken'], Comment: ['replace broken earth terminal']
# Type: [maintie_gold.Replace], Label: ['1007_replace'], Comment: ['replace broken earth terminal']
# Type: [maintie_gold.EarthTerminal], Label: ['1007_earth_terminal'], Comment: ['replace broken earth terminal']
#
# Result 50:
# Type: [maintie_gold.Blown], Label: ['131_blown'], Comment: ['<id> change out blown o-ring on steering pump']
# Type: [maintie_gold.ChangeOut], Label: ['131_change_out'], Comment: ['<id> change out blown o-ring on steering pump']
# Type: [maintie_gold.Oring], Label: ['131_oring'], Comment: ['<id> change out blown o-ring on steering pump']
#
# Result 51:
# Type: [maintie_gold.Blown], Label: ['132_blown'], Comment: ['<id> change out blown position <num> tyre']
# Type: [maintie_gold.ChangeOut], Label: ['132_change_out'], Comment: ['<id> change out blown position <num> tyre']
# Type: [maintie_gold.Tyre], Label: ['132_tyre'], Comment: ['<id> change out blown position <num> tyre']
#
# Result 52:
# Type: [maintie_gold.Blown], Label: ['133_blown'], Comment: ['<id> change out blown steering hose']
# Type: [maintie_gold.ChangeOut], Label: ['133_change_out'], Comment: ['<id> change out blown steering hose']
# Type: [maintie_gold.Hose], Label: ['133_hose'], Comment: ['<id> change out blown steering hose']
#
# Result 53:
# Type: [maintie_gold.Blown], Label: ['305_blown'], Comment: ['<id> replace blown implement hose']
# Type: [maintie_gold.Replace], Label: ['305_replace'], Comment: ['<id> replace blown implement hose']
# Type: [maintie_gold.ImplementHose], Label: ['305_implement_hose'], Comment: ['<id> replace blown implement hose']
#
# Result 54:
# Type: [maintie_gold.Blown], Label: ['313_blown'], Comment: ['<id> replace blown right hand steering hose']
# Type: [maintie_gold.Replace], Label: ['313_replace'], Comment: ['<id> replace blown right hand steering hose']
# Type: [maintie_gold.Hose], Label: ['313_hose'], Comment: ['<id> replace blown right hand steering hose']
#
# Result 55:
# Type: [maintie_gold.Blown], Label: ['473_blown'], Comment: ['<id> replace blown main pump hose']
# Type: [maintie_gold.Replace], Label: ['473_replace'], Comment: ['<id> replace blown main pump hose']
# Type: [maintie_gold.Hose], Label: ['473_hose'], Comment: ['<id> replace blown main pump hose']
#
# Result 56:
# Type: [maintie_gold.Blown], Label: ['541_blown'], Comment: ['<id> - change out blown hose']
# Type: [maintie_gold.ChangeOut], Label: ['541_change_out'], Comment: ['<id> - change out blown hose']
# Type: [maintie_gold.Hose], Label: ['541_hose'], Comment: ['<id> - change out blown hose']
#
# Result 57:
# Type: [maintie_gold.Blown], Label: ['677_blown'], Comment: ['<id> - repair blown air conditioner hose']
# Type: [maintie_gold.Repair], Label: ['677_repair'], Comment: ['<id> - repair blown air conditioner hose']
# Type: [maintie_gold.Hose], Label: ['677_hose'], Comment: ['<id> - repair blown air conditioner hose']
#
# Result 58:
# Type: [maintie_gold.Blown], Label: ['695_blown'], Comment: ['<id> - replace blown hose']
# Type: [maintie_gold.Replace], Label: ['695_replace'], Comment: ['<id> - replace blown hose']
# Type: [maintie_gold.Hose], Label: ['695_hose'], Comment: ['<id> - replace blown hose']
#
# Result 59:
# Type: [maintie_gold.Blown], Label: ['696_blown'], Comment: ['<id> - replace blown work lights']
# Type: [maintie_gold.Replace], Label: ['696_replace'], Comment: ['<id> - replace blown work lights']
# Type: [maintie_gold.WorkLights], Label: ['696_work_lights'], Comment: ['<id> - replace blown work lights']
#
# Result 60:
# Type: [maintie_gold.Seized], Label: ['1028_seized'], Comment: ['replace seized air conditioner control cable']
# Type: [maintie_gold.Replace], Label: ['1028_replace'], Comment: ['replace seized air conditioner control cable']
# Type: [maintie_gold.ControlCable], Label: ['1028_control_cable'], Comment: ['replace seized air conditioner control cable']
#
# Result 61:
# Type: [maintie_gold.Missing], Label: ['392_missing'], Comment: ['replace missing cutting edge']
# Type: [maintie_gold.Replace], Label: ['392_replace'], Comment: ['replace missing cutting edge']
# Type: [maintie_gold.CuttingEdge], Label: ['392_cutting_edge'], Comment: ['replace missing cutting edge']
#
# Result 62:
# Type: [maintie_gold.Cracked], Label: ['137_cracked'], Comment: ['<id> change out cracked pipe on valve bank']
# Type: [maintie_gold.ChangeOut], Label: ['137_change_out'], Comment: ['<id> change out cracked pipe on valve bank']
# Type: [maintie_gold.Pipe], Label: ['137_pipe'], Comment: ['<id> change out cracked pipe on valve bank']
#
# Result 63:
# Type: [maintie_gold.Cracked], Label: ['138_cracked'], Comment: ['<id> change out cracked position <num> adaptor and tooth']
# Type: [maintie_gold.ChangeOut], Label: ['138_change_out'], Comment: ['<id> change out cracked position <num> adaptor and tooth']
# Type: [maintie_gold.Adaptor], Label: ['138_adaptor'], Comment: ['<id> change out cracked position <num> adaptor and tooth']
#
# Result 64:
# Type: [maintie_gold.Cracked], Label: ['138_cracked'], Comment: ['<id> change out cracked position <num> adaptor and tooth']
# Type: [maintie_gold.ChangeOut], Label: ['138_change_out'], Comment: ['<id> change out cracked position <num> adaptor and tooth']
# Type: [maintie_gold.Tooth], Label: ['138_tooth'], Comment: ['<id> change out cracked position <num> adaptor and tooth']
#
# Result 65:
# Type: [maintie_gold.Cracked], Label: ['146_cracked'], Comment: ['<id> change out front upper window cracked']
# Type: [maintie_gold.ChangeOut], Label: ['146_change_out'], Comment: ['<id> change out front upper window cracked']
# Type: [maintie_gold.Window], Label: ['146_window'], Comment: ['<id> change out front upper window cracked']
#
# Result 66:
# Type: [maintie_gold.Cracked], Label: ['347_cracked'], Comment: ['<id> replace transmission - cracked']
# Type: [maintie_gold.Replace], Label: ['347_replace'], Comment: ['<id> replace transmission - cracked']
# Type: [maintie_gold.Transmission], Label: ['347_transmission'], Comment: ['<id> replace transmission - cracked']
#
# Result 67:
# Type: [maintie_gold.Cracked], Label: ['366_cracked'], Comment: ['<id> front window cracked replace']
# Type: [maintie_gold.Replace], Label: ['366_replace'], Comment: ['<id> front window cracked replace']
# Type: [maintie_gold.Window], Label: ['366_window'], Comment: ['<id> front window cracked replace']
#
# Result 68:
# Type: [maintie_gold.Cracked], Label: ['400_cracked'], Comment: ['<id> replace <num> x cracked windows']
# Type: [maintie_gold.Replace], Label: ['400_replace'], Comment: ['<id> replace <num> x cracked windows']
# Type: [maintie_gold.Windows], Label: ['400_windows'], Comment: ['<id> replace <num> x cracked windows']
#
# Result 69:
# Type: [maintie_gold.Cracked], Label: ['479_cracked'], Comment: ['<id> replace cracked transmission dropbox']
# Type: [maintie_gold.Replace], Label: ['479_replace'], Comment: ['<id> replace cracked transmission dropbox']
# Type: [maintie_gold.Dropbox], Label: ['479_dropbox'], Comment: ['<id> replace cracked transmission dropbox']
#
# Result 70:
# Type: [maintie_gold.Cracked], Label: ['678_cracked'], Comment: ['<id> - repair cracked steering tank mo']
# Type: [maintie_gold.Repair], Label: ['678_repair'], Comment: ['<id> - repair cracked steering tank mo']
# Type: [maintie_gold.Tank], Label: ['678_tank'], Comment: ['<id> - repair cracked steering tank mo']
#
# Result 71:
# Type: [maintie_gold.Cracked], Label: ['703_cracked'], Comment: ['<id> - replace cracked exhaust shield']
# Type: [maintie_gold.Replace], Label: ['703_replace'], Comment: ['<id> - replace cracked exhaust shield']
# Type: [maintie_gold.ExhaustShield], Label: ['703_exhaust_shield'], Comment: ['<id> - replace cracked exhaust shield']
#
# Result 72:
# Type: [maintie_gold.Cracked], Label: ['980_cracked'], Comment: ['repair cracked baffle in hydraulic tank']
# Type: [maintie_gold.Repair], Label: ['980_repair'], Comment: ['repair cracked baffle in hydraulic tank']
# Type: [maintie_gold.Baffle], Label: ['980_baffle'], Comment: ['repair cracked baffle in hydraulic tank']
#
# Result 73:
# Type: [maintie_gold.Cracked], Label: ['981_cracked'], Comment: ['repair cracked roof skin left hand side exhaust']
# Type: [maintie_gold.Repair], Label: ['981_repair'], Comment: ['repair cracked roof skin left hand side exhaust']
# Type: [maintie_gold.RoofSkin], Label: ['981_roof_skin'], Comment: ['repair cracked roof skin left hand side exhaust']
#
# Result 74:
# Type: [maintie_gold.Cracked], Label: ['988_cracked'], Comment: ['repair left hand scoreboard base cracked']
# Type: [maintie_gold.Repair], Label: ['988_repair'], Comment: ['repair left hand scoreboard base cracked']
# Type: [maintie_gold.Base], Label: ['988_base'], Comment: ['repair left hand scoreboard base cracked']
#
# Result 75:
# Type: [maintie_gold.Cracked], Label: ['1012_cracked'], Comment: ['replace cracked glass in entry door']
# Type: [maintie_gold.Replace], Label: ['1012_replace'], Comment: ['replace cracked glass in entry door']
# Type: [maintie_gold.Glass], Label: ['1012_glass'], Comment: ['replace cracked glass in entry door']
#
# Result 76:
# Type: [maintie_gold.Cracked], Label: ['1013_cracked'], Comment: ['replace cracked water separator']
# Type: [maintie_gold.Replace], Label: ['1013_replace'], Comment: ['replace cracked water separator']
# Type: [maintie_gold.WaterSeparator], Label: ['1013_water_separator'], Comment: ['replace cracked water separator']
#
# Result 77:
# Type: [maintie_gold.Worn], Label: ['185_worn'], Comment: ['<id> change out worn position <num> tyre']
# Type: [maintie_gold.ChangeOut], Label: ['185_change_out'], Comment: ['<id> change out worn position <num> tyre']
# Type: [maintie_gold.Tyre], Label: ['185_tyre'], Comment: ['<id> change out worn position <num> tyre']
#
# Result 78:
# Type: [maintie_gold.Worn], Label: ['466_worn'], Comment: ['change out position <num> tyre worn']
# Type: [maintie_gold.ChangeOut], Label: ['466_change_out'], Comment: ['change out position <num> tyre worn']
# Type: [maintie_gold.Tyre], Label: ['466_tyre'], Comment: ['change out position <num> tyre worn']
#
# Result 79:
# Type: [maintie_gold.Worn], Label: ['597_worn'], Comment: ['<id> - change out worn ripper tip ripper tip']
# Type: [maintie_gold.ChangeOut], Label: ['597_change_out'], Comment: ['<id> - change out worn ripper tip ripper tip']
# Type: [maintie_gold.RipperTip], Label: ['597_ripper_tip'], Comment: ['<id> - change out worn ripper tip ripper tip']
#
# Result 80:
# Type: [maintie_gold.Worn], Label: ['776_worn'], Comment: ['<id> GET change out worn cutting edges']
# Type: [maintie_gold.ChangeOut], Label: ['776_change_out'], Comment: ['<id> GET change out worn cutting edges']
# Type: [maintie_gold.CuttingEdges], Label: ['776_cutting_edges'], Comment: ['<id> GET change out worn cutting edges']
#
# Result 81:
# Type: [maintie_gold.Worn], Label: ['1000_worn'], Comment: ['repair worn centrifuge filter']
# Type: [maintie_gold.Repair], Label: ['1000_repair'], Comment: ['repair worn centrifuge filter']
# Type: [maintie_gold.Filter], Label: ['1000_filter'], Comment: ['repair worn centrifuge filter']
#
# Result 82:
# Type: [maintie_gold.WornOut], Label: ['164_worn_out'], Comment: ['<id> change out position <num> and <num> tyre worn out']
# Type: [maintie_gold.ChangeOut], Label: ['164_change_out'], Comment: ['<id> change out position <num> and <num> tyre worn out']
# Type: [maintie_gold.Tyre], Label: ['164_tyre'], Comment: ['<id> change out position <num> and <num> tyre worn out']
#
# Result 83:
# Type: [maintie_gold.Damage], Label: ['170_damage'], Comment: ['<id> change out position <num> tyre damage']
# Type: [maintie_gold.ChangeOut], Label: ['170_change_out'], Comment: ['<id> change out position <num> tyre damage']
# Type: [maintie_gold.Tyre], Label: ['170_tyre'], Comment: ['<id> change out position <num> tyre damage']
#
# Result 84:
# Type: [maintie_gold.Damage], Label: ['191_damage'], Comment: ['<id> change position <num> tyre damage text']
# Type: [maintie_gold.Change], Label: ['191_change'], Comment: ['<id> change position <num> tyre damage text']
# Type: [maintie_gold.Tyre], Label: ['191_tyre'], Comment: ['<id> change position <num> tyre damage text']
#
# Result 85:
# Type: [maintie_gold.Damage], Label: ['452_damage'], Comment: ['<id> replace damage auto-greaser door']
# Type: [maintie_gold.Replace], Label: ['452_replace'], Comment: ['<id> replace damage auto-greaser door']
# Type: [maintie_gold.Door], Label: ['452_door'], Comment: ['<id> replace damage auto-greaser door']
#
# Result 86:
# Type: [maintie_gold.Flat], Label: ['189_flat'], Comment: ['<id> change position <num> flat tyre']
# Type: [maintie_gold.Change], Label: ['189_change'], Comment: ['<id> change position <num> flat tyre']
# Type: [maintie_gold.Tyre], Label: ['189_tyre'], Comment: ['<id> change position <num> flat tyre']
#
# Result 87:
# Type: [maintie_gold.Damaged], Label: ['376_damaged'], Comment: ['<id> replace damaged position <num> tyre and position <num>']
# Type: [maintie_gold.Replace], Label: ['376_replace'], Comment: ['<id> replace damaged position <num> tyre and position <num>']
# Type: [maintie_gold.Tyre], Label: ['376_tyre'], Comment: ['<id> replace damaged position <num> tyre and position <num>']
#
# Result 88:
# Type: [maintie_gold.Damaged], Label: ['427_damaged'], Comment: ['<id> replace damaged tyre on position <num>']
# Type: [maintie_gold.Replace], Label: ['427_replace'], Comment: ['<id> replace damaged tyre on position <num>']
# Type: [maintie_gold.Tyre], Label: ['427_tyre'], Comment: ['<id> replace damaged tyre on position <num>']
#
# Result 89:
# Type: [maintie_gold.Damaged], Label: ['482_damaged'], Comment: ['<id> replace position <num> tyre damaged']
# Type: [maintie_gold.Replace], Label: ['482_replace'], Comment: ['<id> replace position <num> tyre damaged']
# Type: [maintie_gold.Tyre], Label: ['482_tyre'], Comment: ['<id> replace position <num> tyre damaged']
#
# Result 90:
# Type: [maintie_gold.Slow], Label: ['244_slow'], Comment: ['<id> diagnose / repair slow steering']
# Type: [maintie_gold.Repair], Label: ['244_repair'], Comment: ['<id> diagnose / repair slow steering']
# Type: [maintie_gold.Steering], Label: ['244_steering'], Comment: ['<id> diagnose / repair slow steering']
#
# Result 91:
# Type: [maintie_gold.Slow], Label: ['244_slow'], Comment: ['<id> diagnose / repair slow steering']
# Type: [maintie_gold.Diagnose], Label: ['244_diagnose'], Comment: ['<id> diagnose / repair slow steering']
# Type: [maintie_gold.Steering], Label: ['244_steering'], Comment: ['<id> diagnose / repair slow steering']
#
# Result 92:
# Type: [maintie_gold.Faulty], Label: ['280_faulty'], Comment: ['<id> replace faulty brake sensor <num> task']
# Type: [maintie_gold.Replace], Label: ['280_replace'], Comment: ['<id> replace faulty brake sensor <num> task']
# Type: [maintie_gold.Sensor], Label: ['280_sensor'], Comment: ['<id> replace faulty brake sensor <num> task']
#
# Result 93:
# Type: [maintie_gold.Faulty], Label: ['571_faulty'], Comment: ['<id> - change out number <num> faulty injector assembly']
# Type: [maintie_gold.ChangeOut], Label: ['571_change_out'], Comment: ['<id> - change out number <num> faulty injector assembly']
# Type: [maintie_gold.InjectorAssembly], Label: ['571_injector_assembly'], Comment: ['<id> - change out number <num> faulty injector assembly']
#
# Result 94:
# Type: [maintie_gold.Faulty], Label: ['986_faulty'], Comment: ['repair faulty safety valve']
# Type: [maintie_gold.Repair], Label: ['986_repair'], Comment: ['repair faulty safety valve']
# Type: [maintie_gold.SafetyValve], Label: ['986_safety_valve'], Comment: ['repair faulty safety valve']
#
# Result 95:
# Type: [maintie_gold.Mismatched], Label: ['489_mismatched'], Comment: ['<id> replace position <num> tyre - mismatched']
# Type: [maintie_gold.Replace], Label: ['489_replace'], Comment: ['<id> replace position <num> tyre - mismatched']
# Type: [maintie_gold.Tyre], Label: ['489_tyre'], Comment: ['<id> replace position <num> tyre - mismatched']
#
# Result 96:
# Type: [maintie_gold.Blocked], Label: ['694_blocked'], Comment: ['<id> - replace blocked dryer']
# Type: [maintie_gold.Replace], Label: ['694_replace'], Comment: ['<id> - replace blocked dryer']
# Type: [maintie_gold.Dryer], Label: ['694_dryer'], Comment: ['<id> - replace blocked dryer']
#
# Result 97:
# Type: [maintie_gold.Dropped], Label: ['818_dropped'], Comment: ['battery unserviceable dropped cell replace']
# Type: [maintie_gold.Replace], Label: ['818_replace'], Comment: ['battery unserviceable dropped cell replace']
# Type: [maintie_gold.Cell], Label: ['818_cell'], Comment: ['battery unserviceable dropped cell replace']
#
# Result 98:
# Type: [maintie_gold.Locked], Label: ['904_locked'], Comment: ['heat up locked steels']
# Type: [maintie_gold.HeatUp], Label: ['904_heat_up'], Comment: ['heat up locked steels']
# Type: [maintie_gold.Steels], Label: ['904_steels'], Comment: ['heat up locked steels']
#
# Result 99:
# Type: [maintie_gold.Shorted], Label: ['1029_shorted'], Comment: ['replace shorted diode RPC <num>']
# Type: [maintie_gold.Replace], Label: ['1029_replace'], Comment: ['replace shorted diode RPC <num>']
# Type: [maintie_gold.Diode], Label: ['1029_diode'], Comment: ['replace shorted diode RPC <num>']
#
# Result 100:
# Type: [maintie_gold.NotCommunicating], Label: ['1060_not_communicating'], Comment: ['troubleshoot smart meter not communicating']
# Type: [maintie_gold.Troubleshoot], Label: ['1060_troubleshoot'], Comment: ['troubleshoot smart meter not communicating']
# Type: [maintie_gold.SmartMeter], Label: ['1060_smart_meter'], Comment: ['troubleshoot smart meter not communicating']

# %% [markdown]
# **Which larger systems or machines does a specific part belong to?**
# - has_part / is_part_of
# - TODO: return all the ancestors. -- pump -> brake pump -> bolt
#     - pump/brake pump via class hierararchy
#     - brake pump/bolt via object property

# %%
# %%sparql_query
# """
# PREFIX rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#>
# PREFIX owl: <http://www.w3.org/2002/07/owl#>
#
# SELECT DISTINCT ?parent
# WHERE {
#   # Start with instances of Bolt
#   ?bolt rdf:type <file://ONTOLOGY_NAME#Bolt> .
#
#   # Find entities that have Bolt as a part
#   ?parent <file://ONTOLOGY_NAME#has_part> ?bolt .
# }
# """
# Out:
# Results found: 4
#
# [[maintie_gold.44TVAL7Q], [maintie_gold.Q46TTZX9], [maintie_gold.AYXX9F3U], [maintie_gold.79QVG66Q]]
#
# Result 1:
# Type: [maintie_gold.BellyPlate], Label: ['54_belly_plate'], Comment: ['<id> belly plate bolt missing']
#
# Result 2:
# Type: [maintie_gold.Carousel], Label: ['116_carousel'], Comment: ['<id> carousel popped bolt needs Loctite']
#
# Result 3:
# Type: [maintie_gold.Pump], Label: ['134_pump'], Comment: ['<id> change out broken bolt on brake pump']
#
# Result 4:
# Type: [maintie_gold.Dogbone], Label: ['704_dogbone'], Comment: ['<id> - replace dogbone bolt']

# %% [markdown]
# **If Air Conditioner is Broken, what could be the reason?**

# %%
# %%sparql_query
# """
# PREFIX rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#>
#
# SELECT ?part
# WHERE {
#   # Start with instances of AirConditioner
#   ?ac rdf:type <file://ONTOLOGY_NAME#AirConditioner> .
#
#   # Find AirConditioner parts
#   ?ac <file://ONTOLOGY_NAME#has_part> ?part .
#
#   # Find instances of broken states that have air conditioner parts as patients
#   ?brokenInstance rdf:type <file://ONTOLOGY_NAME#Broken> .
#   ?brokenInstance <file://ONTOLOGY_NAME#has_patient> ?part .
# }
# """
# Out:
# Results found: 2
#
# [[maintie_gold.W2RPEL9C], [maintie_gold.YRETXKB0]]
#
# Result 1:
# Type: [maintie_gold.Guard], Label: ['97_guard'], Comment: ['<id> broken air conditioner guard']
#
# Result 2:
# Type: [maintie_gold.Belt], Label: ['791_belt'], Comment: ['<id> air conditioner belt broken']

# %% [markdown]
# <hr>

# %% [markdown]
# **Using propertyChain axiom to find states on ancestors due to parts - `can_be_patient_of_state_due_to_part`**

# %% [raw]
# %%sparql_query
# """
# PREFIX rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#>
#
# SELECT ?ac ?partState
# WHERE {
#   # Start with instances of AirConditioner
#   ?ac rdf:type <file://ONTOLOGY_NAME#AirConditioner> .
#
#   ?ac <file://ONTOLOGY_NAME#can_be_patient_of_state_due_to_part> ?partState .
# }
# """

# %% [markdown]
# **Using propertyChain axiom to find activities on ancestors due to parts - `can_be_patient_of_activity_due_to_part`**

# %% [raw]
# %%sparql_query
# """
# PREFIX rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#>
#
# SELECT ?ac ?partActivity
# WHERE {
#   # Start with instances of AirConditioner
#   ?ac rdf:type <file://ONTOLOGY_NAME#AirConditioner> .
#
#   ?ac <file://ONTOLOGY_NAME#can_be_patient_of_activity_due_to_part> ?partActivity .
# }
# """

# %% [markdown]
# **What objects are being replaced?**

# %%
# %%sparql_query
# """
# PREFIX rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#>
#
# SELECT ?part
# WHERE {
#   ?replace rdf:type <file://ONTOLOGY_NAME#Replace> .
#
#   ?replace <file://ONTOLOGY_NAME#has_patient> ?part .
# }
# """
# Out:
# Results found: 151
#
# [[maintie_gold.CBPTRSCP], [maintie_gold.LV5FSA7C], [maintie_gold.JJVQY9PF], [maintie_gold.KIIKMZ6K], [maintie_gold.8VIGCVU2], [maintie_gold.YJ6J3EZE], [maintie_gold.P80B0XGD], [maintie_gold.YYJS049I], [maintie_gold.19M8JD06], [maintie_gold.4K8YO8DF], [maintie_gold.3AGEEAWY], [maintie_gold.WRRJX5P1], [maintie_gold.K52OLNML], [maintie_gold.F5F3540Z], [maintie_gold.I7CYDLD7], [maintie_gold.QAZJD6SW], [maintie_gold.ADHZ05K3], [maintie_gold.3G7IKH5Y], [maintie_gold.GWN6VZES], [maintie_gold.PKIDWNE1], [maintie_gold.XT4EE4ZY], [maintie_gold.F2W6HW4O], [maintie_gold.N3KTQX2F], [maintie_gold.L7DCXYYJ], [maintie_gold.5CM6MH25], [maintie_gold.O7D1H40I], [maintie_gold.Q0VAJTAY], [maintie_gold.1A0800DC], [maintie_gold.LRZ69Z34], [maintie_gold.CJIHL72L], [maintie_gold.EATMLRS9], [maintie_gold.0VUF9I2N], [maintie_gold.GA5CLDY0], [maintie_gold.735ZM5EN], [maintie_gold.IM7GMB8Z], [maintie_gold.HV0X3MYI], [maintie_gold.SXPFLPFO], [maintie_gold.9HMZS3TZ], [maintie_gold.3ZKV8ZJZ], [maintie_gold.5W94P7BJ], [maintie_gold.0QGMYVRI], [maintie_gold.NNKY9FIV], [maintie_gold.BNXXEOHV], [maintie_gold.9A3T1IVH], [maintie_gold.FU2LB3L1], [maintie_gold.ES643XU7], [maintie_gold.II0WLDVS], [maintie_gold.92KT0K71], [maintie_gold.TNAZBTVT], [maintie_gold.B056L76L], [maintie_gold.9HHD094J], [maintie_gold.1I75V68R], [maintie_gold.ISIRGLBN], [maintie_gold.KO8YVLA7], [maintie_gold.TFZQ6ICK], [maintie_gold.7ZDZYQSO], [maintie_gold.X6XMRMTT], [maintie_gold.PQVRXY89], [maintie_gold.QOORX1A3], [maintie_gold.CF1IOH1X], [maintie_gold.GE79BLYB], [maintie_gold.5PSQE5PL], [maintie_gold.TYUY5BF8], [maintie_gold.POD1HGIA], [maintie_gold.LHC9YU99], [maintie_gold.YC00SGUZ], [maintie_gold.7335KU0K], [maintie_gold.GCIQ5EAB], [maintie_gold.VK88FCC8], [maintie_gold.A0KFUV6R], [maintie_gold.FDFJPGXB], [maintie_gold.4J6LLCE5], [maintie_gold.O4WNU665], [maintie_gold.TE1QGSD8], [maintie_gold.0IXGZZN3], [maintie_gold.YMONXGGP], [maintie_gold.10KB7DI5], [maintie_gold.QE3177XG], [maintie_gold.DH01WG25], [maintie_gold.OBVDAV32], [maintie_gold.5RUIWCSR], [maintie_gold.9OA1PUIU], [maintie_gold.EITUNAAG], [maintie_gold.6I5Q4O0G], [maintie_gold.HK8MJRPO], [maintie_gold.3I6HN7S6], [maintie_gold.1BIV6TFA], [maintie_gold.OJQCB3EA], [maintie_gold.9L7SWMMQ], [maintie_gold.ZZXCXSJA], [maintie_gold.0GGMWMB4], [maintie_gold.TY2924HS], [maintie_gold.QA4ESGY1], [maintie_gold.YU89VSHX], [maintie_gold.1PSN9FQJ], [maintie_gold.OLO5MPWV], [maintie_gold.JNDTUYOP], [maintie_gold.4NK0ELVL], [maintie_gold.OU3OSERU], [maintie_gold.B6MLP1IA], [maintie_gold.48NM56IJ], [maintie_gold.ODL2EPI8], [maintie_gold.71TKQ2ZP], [maintie_gold.2CX8HR8R], [maintie_gold.2Y0YG870], [maintie_gold.NLGUI9ZV], [maintie_gold.5XRCEVVT], [maintie_gold.SFL89WOZ], [maintie_gold.DZ7FIA8D], [maintie_gold.ZBS5QJR9], [maintie_gold.ULEPR3NB], [maintie_gold.8NPHV625], [maintie_gold.3FXWSNZI], [maintie_gold.LNL044BU], [maintie_gold.6QCHT5PR], [maintie_gold.N9GVBPCA], [maintie_gold.49C7DHM6], [maintie_gold.0ECBHQBL], [maintie_gold.UNQ04WNK], [maintie_gold.C0UVQW01], [maintie_gold.X0PFE198], [maintie_gold.4DFPRVUD], [maintie_gold.JBASS0JY], [maintie_gold.0H2W7GUI], [maintie_gold.S6DNCMS6], [maintie_gold.SQ5UY9YS], [maintie_gold.Q2CGM6Q5], [maintie_gold.5T1O9JHA], [maintie_gold.349ESS0Y], [maintie_gold.8GQLPG5X], [maintie_gold.UTAPFIRX], [maintie_gold.YGQ8MO67], [maintie_gold.EF0QEHUY], [maintie_gold.RFPT4DHF], [maintie_gold.0MATF3DD], [maintie_gold.V8XIHJRX], [maintie_gold.OYW9QRAZ], [maintie_gold.LJFHPAXI], [maintie_gold.4HJWVWL6], [maintie_gold.EJFCCYXZ], [maintie_gold.1TDXCKIS], [maintie_gold.7WIZNS7E], [maintie_gold.HBOQ7NKK], [maintie_gold.JYHGPDIY], [maintie_gold.T0VGTMN9], [maintie_gold.6OVZKK0J], [maintie_gold.09X8OEUI], [maintie_gold.F3RR65I3], [maintie_gold.SXEIETN9], [maintie_gold.FK3VGQTZ], [maintie_gold.CZRSLO1X]]
#
# Result 1:
# Type: [maintie_gold.CrowdCylinder], Label: ['235_crowd_cylinder'], Comment: ['<id> crowd cylinder creeping replace']
#
# Result 2:
# Type: [maintie_gold.Rollers], Label: ['276_rollers'], Comment: ['inspect and replace rollers as required']
#
# Result 3:
# Type: [maintie_gold.CrowdHose], Label: ['278_crowd_hose'], Comment: ['<id> replace left hand crowd hose']
#
# Result 4:
# Type: [maintie_gold.Sensor], Label: ['280_sensor'], Comment: ['<id> replace faulty brake sensor <num> task']
#
# Result 5:
# Type: [maintie_gold.Harness], Label: ['284_harness'], Comment: ['<id> replace torque converter wiring harness']
#
# Result 6:
# Type: [maintie_gold.TransferPipe], Label: ['285_transfer_pipe'], Comment: ['<id> replace leaking transfer pipe']
#
# Result 7:
# Type: [maintie_gold.BrakeCylinder], Label: ['293_brake_cylinder'], Comment: ['replace number <num> hoist brake cylinder']
#
# Result 8:
# Type: [maintie_gold.PieWarmer], Label: ['294_pie_warmer'], Comment: ['replace the pie warmer']
#
# Result 9:
# Type: [maintie_gold.Brake], Label: ['297_brake'], Comment: ['CW <id> replace slew brake right hand front <id>']
#
# Result 10:
# Type: [maintie_gold.ImplementHose], Label: ['305_implement_hose'], Comment: ['<id> replace blown implement hose']
#
# Result 11:
# Type: [maintie_gold.LocationPins], Label: ['308_location_pins'], Comment: ['replace lube module location pins']
#
# Result 12:
# Type: [maintie_gold.LightSwitch], Label: ['309_light_switch'], Comment: ['<id> replace light switch for side lamp']
#
# Result 13:
# Type: [maintie_gold.Hose], Label: ['313_hose'], Comment: ['<id> replace blown right hand steering hose']
#
# Result 14:
# Type: [maintie_gold.Bucket], Label: ['315_bucket'], Comment: ['<id> replace bucket surf workshop']
#
# Result 15:
# Type: [maintie_gold.Leaks], Label: ['321_leaks'], Comment: ['<id> replace oil leaks']
#
# Result 16:
# Type: [maintie_gold.Harness], Label: ['322_harness'], Comment: ['replace transmission wiring harness']
#
# Result 17:
# Type: [maintie_gold.Lock], Label: ['324_lock'], Comment: ['<id> replace bucket tooth lock']
#
# Result 18:
# Type: [maintie_gold.ControlValve], Label: ['331_control_valve'], Comment: ['<id> replace steering control valve']
#
# Result 19:
# Type: [maintie_gold.Crankshaft], Label: ['332_crankshaft'], Comment: ['<id> replace front crankshaft TBC']
#
# Result 20:
# Type: [maintie_gold.Actuator], Label: ['334_actuator'], Comment: ['<id> replace fire suppression actuator']
#
# Result 21:
# Type: [maintie_gold.Pins], Label: ['336_pins'], Comment: ['<id> replace dogbone and pins']
#
# Result 22:
# Type: [maintie_gold.Dogbone], Label: ['336_dogbone'], Comment: ['<id> replace dogbone and pins']
#
# Result 23:
# Type: [maintie_gold.TravelMotor], Label: ['340_travel_motor'], Comment: ['replace left hand travel motor']
#
# Result 24:
# Type: [maintie_gold.Tyres], Label: ['346_tyres'], Comment: ['<id> replace all four tyres']
#
# Result 25:
# Type: [maintie_gold.Transmission], Label: ['347_transmission'], Comment: ['<id> replace transmission - cracked']
#
# Result 26:
# Type: [maintie_gold.DrainPlugs], Label: ['351_drain_plugs'], Comment: ['<id> replace unserviceable differential drain plugs']
#
# Result 27:
# Type: [maintie_gold.VentValve], Label: ['358_vent_valve'], Comment: ['<id> replace auto-greaser vent valve']
#
# Result 28:
# Type: [maintie_gold.Clamp], Label: ['359_clamp'], Comment: ['<id> replace grommet / clamp right hand lift cylinder']
#
# Result 29:
# Type: [maintie_gold.Grommet], Label: ['359_grommet'], Comment: ['<id> replace grommet / clamp right hand lift cylinder']
#
# Result 30:
# Type: [maintie_gold.LockPins], Label: ['360_lock_pins'], Comment: ['<id> replace oil cooler lock pins']
#
# Result 31:
# Type: [maintie_gold.PilotHoses], Label: ['363_pilot_hoses'], Comment: ['<id> replace steering pilot hoses']
#
# Result 32:
# Type: [maintie_gold.Window], Label: ['366_window'], Comment: ['<id> front window cracked replace']
#
# Result 33:
# Type: [maintie_gold.UniversalJoint], Label: ['367_universal_joint'], Comment: ['replace bottom steering shaft universal joint']
#
# Result 34:
# Type: [maintie_gold.Tyre], Label: ['369_tyre'], Comment: ['<id> replace one tyre TBC']
#
# Result 35:
# Type: [maintie_gold.LiftCylinder], Label: ['373_lift_cylinder'], Comment: ['<id> replace right hand lift cylinder leaking']
#
# Result 36:
# Type: [maintie_gold.Tyre], Label: ['376_tyre'], Comment: ['<id> replace damaged position <num> tyre and position <num>']
#
# Result 37:
# Type: [maintie_gold.ScavengePump], Label: ['386_scavenge_pump'], Comment: ['<id> replace leaking scavenge pump']
#
# Result 38:
# Type: [maintie_gold.CuttingEdge], Label: ['392_cutting_edge'], Comment: ['replace missing cutting edge']
#
# Result 39:
# Type: [maintie_gold.Disc], Label: ['394_disc'], Comment: ['swing brake <num> replace disc and pads']
#
# Result 40:
# Type: [maintie_gold.Pads], Label: ['394_pads'], Comment: ['swing brake <num> replace disc and pads']
#
# Result 41:
# Type: [maintie_gold.PonyDriveMotor], Label: ['395_pony_drive_motor'], Comment: ['replace hoist pony drive motor']
#
# Result 42:
# Type: [maintie_gold.Tyres], Label: ['397_tyres'], Comment: ['<id> replace all <num> tyres']
#
# Result 43:
# Type: [maintie_gold.Tyres], Label: ['399_tyres'], Comment: ['<id> replace position <num> <num> <num> tyres']
#
# Result 44:
# Type: [maintie_gold.Windows], Label: ['400_windows'], Comment: ['<id> replace <num> x cracked windows']
#
# Result 45:
# Type: [maintie_gold.LubeSystem], Label: ['401_lube_system'], Comment: ['replace lube system <id> drag rope pump']
#
# Result 46:
# Type: [maintie_gold.TransferPipe], Label: ['408_transfer_pipe'], Comment: ['<id> replace crowd cylinder transfer pipe']
#
# Result 47:
# Type: [maintie_gold.Hose], Label: ['410_hose'], Comment: ['<id> replace tilt cylinder hose']
#
# Result 48:
# Type: [maintie_gold.SpacerClamp], Label: ['414_spacer_clamp'], Comment: ['replace spacer clamp on main shaft']
#
# Result 49:
# Type: [maintie_gold.Tyre], Label: ['427_tyre'], Comment: ['<id> replace damaged tyre on position <num>']
#
# Result 50:
# Type: [maintie_gold.Coupling], Label: ['429_coupling'], Comment: ['replace hydraulic pump coupling']
#
# Result 51:
# Type: [maintie_gold.TimingSensor], Label: ['439_timing_sensor'], Comment: ['<id> replace engine timing sensor']
#
# Result 52:
# Type: [maintie_gold.Sprockets], Label: ['445_sprockets'], Comment: ['<num> hour mechanical replace sprockets right hand <id>']
#
# Result 53:
# Type: [maintie_gold.Door], Label: ['452_door'], Comment: ['<id> replace damage auto-greaser door']
#
# Result 54:
# Type: [maintie_gold.TimingSensor], Label: ['457_timing_sensor'], Comment: ['<id> replace timing sensor']
#
# Result 55:
# Type: [maintie_gold.Bearing], Label: ['461_bearing'], Comment: ['replace bearing and taperlock on <id> roller']
#
# Result 56:
# Type: [maintie_gold.Taperlock], Label: ['461_taperlock'], Comment: ['replace bearing and taperlock on <id> roller']
#
# Result 57:
# Type: [maintie_gold.CoolantSensor], Label: ['468_coolant_sensor'], Comment: ['<id> replace coolant sensor']
#
# Result 58:
# Type: [maintie_gold.Dogbone], Label: ['470_dogbone'], Comment: ['<id> replace dogbone']
#
# Result 59:
# Type: [maintie_gold.Hose], Label: ['473_hose'], Comment: ['<id> replace blown main pump hose']
#
# Result 60:
# Type: [maintie_gold.Dropbox], Label: ['479_dropbox'], Comment: ['<id> replace cracked transmission dropbox']
#
# Result 61:
# Type: [maintie_gold.Tyre], Label: ['482_tyre'], Comment: ['<id> replace position <num> tyre damaged']
#
# Result 62:
# Type: [maintie_gold.Tyre], Label: ['489_tyre'], Comment: ['<id> replace position <num> tyre - mismatched']
#
# Result 63:
# Type: [maintie_gold.OilCooler], Label: ['491_oil_cooler'], Comment: ['<id> replace axle oil cooler']
#
# Result 64:
# Type: [maintie_gold.Fans], Label: ['675_fans'], Comment: ['<id> - repair / replace air conditioner blower fans']
#
# Result 65:
# Type: [maintie_gold.FuelLevelSensor], Label: ['690_fuel_level_sensor'], Comment: ['<id> - replace / fuel level sensor']
#
# Result 66:
# Type: [maintie_gold.ControlValve], Label: ['691_control_valve'], Comment: ['<id> - replace STIC steering control valve']
#
# Result 67:
# Type: [maintie_gold.AirFilters], Label: ['692_air_filters'], Comment: ['<id> - replace air filters']
#
# Result 68:
# Type: [maintie_gold.Caps], Label: ['693_caps'], Comment: ['<id> - replace all tooth caps']
#
# Result 69:
# Type: [maintie_gold.Dryer], Label: ['694_dryer'], Comment: ['<id> - replace blocked dryer']
#
# Result 70:
# Type: [maintie_gold.Hose], Label: ['695_hose'], Comment: ['<id> - replace blown hose']
#
# Result 71:
# Type: [maintie_gold.WorkLights], Label: ['696_work_lights'], Comment: ['<id> - replace blown work lights']
#
# Result 72:
# Type: [maintie_gold.Hose], Label: ['697_hose'], Comment: ['<id> - replace boom cylinder hose']
#
# Result 73:
# Type: [maintie_gold.Hoses], Label: ['698_hoses'], Comment: ['<id> - replace both fan motor hoses']
#
# Result 74:
# Type: [maintie_gold.CoolingLines], Label: ['699_cooling_lines'], Comment: ['<id> - replace brake cooling lines <num>']
#
# Result 75:
# Type: [maintie_gold.Mirror], Label: ['700_mirror'], Comment: ['<id> - replace broken onside mirror']
#
# Result 76:
# Type: [maintie_gold.Bucket], Label: ['701_bucket'], Comment: ['<id> - replace bucket']
#
# Result 77:
# Type: [maintie_gold.CoolantProbe], Label: ['702_coolant_probe'], Comment: ['<id> - replace coolant probe']
#
# Result 78:
# Type: [maintie_gold.ExhaustShield], Label: ['703_exhaust_shield'], Comment: ['<id> - replace cracked exhaust shield']
#
# Result 79:
# Type: [maintie_gold.Bolt], Label: ['704_bolt'], Comment: ['<id> - replace dogbone bolt']
#
# Result 80:
# Type: [maintie_gold.DriveShaft], Label: ['705_drive_shaft'], Comment: ['<id> - replace drive shaft']
#
# Result 81:
# Type: [maintie_gold.Studs], Label: ['706_studs'], Comment: ['<id> - replace exhaust manifold studs']
#
# Result 82:
# Type: [maintie_gold.Compressor], Label: ['707_compressor'], Comment: ['<id> - replace failed air conditioner compressor']
#
# Result 83:
# Type: [maintie_gold.HydraulicCylinder], Label: ['708_hydraulic_cylinder'], Comment: ['<id> - replace hydraulic cylinder hoist left']
#
# Result 84:
# Type: [maintie_gold.SteeringCylinder], Label: ['709_steering_cylinder'], Comment: ['<id> - replace leaking steering cylinder']
#
# Result 85:
# Type: [maintie_gold.SteeringCylinder], Label: ['710_steering_cylinder'], Comment: ['<id> - replace left hand side steering cylinder']
#
# Result 86:
# Type: [maintie_gold.Fittings], Label: ['711_fittings'], Comment: ['<id> - replace lift cylinder fittings left hand']
#
# Result 87:
# Type: [maintie_gold.PressureSensor], Label: ['712_pressure_sensor'], Comment: ['<id> - replace pressure sensor']
#
# Result 88:
# Type: [maintie_gold.HydraulicCylinder], Label: ['713_hydraulic_cylinder'], Comment: ['<id> - replace right hand bucket hydraulic cylinder']
#
# Result 89:
# Type: [maintie_gold.FuelLevelSensor], Label: ['714_fuel_level_sensor'], Comment: ['<id> - replace right hand fuel level sensor']
#
# Result 90:
# Type: [maintie_gold.Pin], Label: ['715_pin'], Comment: ['<id> - replace right hand steering cylinder pin and bearing']
#
# Result 91:
# Type: [maintie_gold.Bearing], Label: ['715_bearing'], Comment: ['<id> - replace right hand steering cylinder pin and bearing']
#
# Result 92:
# Type: [maintie_gold.StarterMotor], Label: ['716_starter_motor'], Comment: ['<id> - replace starter motor']
#
# Result 93:
# Type: [maintie_gold.SteeringCylinder], Label: ['717_steering_cylinder'], Comment: ['<id> - replace steering cylinder']
#
# Result 94:
# Type: [maintie_gold.Pins], Label: ['718_pins'], Comment: ['<id> - replace steering cylinder pins and bushes']
#
# Result 95:
# Type: [maintie_gold.Bushes], Label: ['718_bushes'], Comment: ['<id> - replace steering cylinder pins and bushes']
#
# Result 96:
# Type: [maintie_gold.Guard], Label: ['719_guard'], Comment: ['<id> - replace tilt cylinder guard']
#
# Result 97:
# Type: [maintie_gold.Hose], Label: ['720_hose'], Comment: ['<id> - replace tilt cylinder hose']
#
# Result 98:
# Type: [maintie_gold.Tyre], Label: ['721_tyre'], Comment: ['<id> - replace tyre position <num>']
#
# Result 99:
# Type: [maintie_gold.Tyres], Label: ['722_tyres'], Comment: ['<id> - replace tyres']
#
# Result 100:
# Type: [maintie_gold.Horn], Label: ['752_horn'], Comment: ['<id> <id> replace horn']
#
# Result 101:
# Type: [maintie_gold.HydraulicOil], Label: ['753_hydraulic_oil'], Comment: ['<id> <id> replace hydraulic oil leak text']
#
# Result 102:
# Type: [maintie_gold.CuttingEdges], Label: ['777_cutting_edges'], Comment: ['<id> GET replace cutting edges']
#
# Result 103:
# Type: [maintie_gold.Cell], Label: ['818_cell'], Comment: ['battery unserviceable dropped cell replace']
#
# Result 104:
# Type: [maintie_gold.Hose], Label: ['836_hose'], Comment: ['centrifuge hose leaking - replace']
#
# Result 105:
# Type: [maintie_gold.IgnitionSwitch], Label: ['908_ignition_switch'], Comment: ['ignition switch broken replace']
#
# Result 106:
# Type: [maintie_gold.ExpansionTank], Label: ['969_expansion_tank'], Comment: ['remove and replace expansion tank']
#
# Result 107:
# Type: [maintie_gold.Guide], Label: ['975_guide'], Comment: ['repair and replace chain guide']
#
# Result 108:
# Type: [maintie_gold.Oring], Label: ['1001_oring'], Comment: ['replace o-ring on centrifuge filter']
#
# Result 109:
# Type: [maintie_gold.Louver], Label: ['1002_louver'], Comment: ['replace air conditioner louver']
#
# Result 110:
# Type: [maintie_gold.Cables], Label: ['1003_cables'], Comment: ['replace all pump chip indicator cables']
#
# Result 111:
# Type: [maintie_gold.EarthWire], Label: ['1004_earth_wire'], Comment: ['replace alternator earth wire']
#
# Result 112:
# Type: [maintie_gold.Inverter], Label: ['1005_inverter'], Comment: ['replace auxilliary inverter']
#
# Result 113:
# Type: [maintie_gold.BreakoutDies], Label: ['1006_breakout_dies'], Comment: ['replace breakout dies']
#
# Result 114:
# Type: [maintie_gold.EarthTerminal], Label: ['1007_earth_terminal'], Comment: ['replace broken earth terminal']
#
# Result 115:
# Type: [maintie_gold.Brushes], Label: ['1008_brushes'], Comment: ['replace brushes on condenser fan']
#
# Result 116:
# Type: [maintie_gold.Cover], Label: ['1009_cover'], Comment: ['replace cabin air conditioner cover and louver']
#
# Result 117:
# Type: [maintie_gold.Louver], Label: ['1009_louver'], Comment: ['replace cabin air conditioner cover and louver']
#
# Result 118:
# Type: [maintie_gold.DataCable], Label: ['1010_data_cable'], Comment: ['replace CAES data cable']
#
# Result 119:
# Type: [maintie_gold.ChipIndicators], Label: ['1011_chip_indicators'], Comment: ['replace chip indicators ( leaking )']
#
# Result 120:
# Type: [maintie_gold.Glass], Label: ['1012_glass'], Comment: ['replace cracked glass in entry door']
#
# Result 121:
# Type: [maintie_gold.WaterSeparator], Label: ['1013_water_separator'], Comment: ['replace cracked water separator']
#
# Result 122:
# Type: [maintie_gold.Die], Label: ['1014_die'], Comment: ['replace die']
#
# Result 123:
# Type: [maintie_gold.Dies], Label: ['1015_dies'], Comment: ['replace dies <id>']
#
# Result 124:
# Type: [maintie_gold.Diode], Label: ['1016_diode'], Comment: ['replace diode and heat sink']
#
# Result 125:
# Type: [maintie_gold.HeatSink], Label: ['1016_heat_sink'], Comment: ['replace diode and heat sink']
#
# Result 126:
# Type: [maintie_gold.OilCentrifuge], Label: ['1017_oil_centrifuge'], Comment: ['replace engine oil centrifuge see attachment']
#
# Result 127:
# Type: [maintie_gold.PowerSupply], Label: ['1018_power_supply'], Comment: ['replace fridge power supply']
#
# Result 128:
# Type: [maintie_gold.GelCellBatteries], Label: ['1019_gel_cell_batteries'], Comment: ['replace gel cell batteries']
#
# Result 129:
# Type: [maintie_gold.HeatSink], Label: ['1020_heat_sink'], Comment: ['replace heat sink']
#
# Result 130:
# Type: [maintie_gold.Inductor], Label: ['1021_inductor'], Comment: ['replace inductor in auxilliary blower assembly']
#
# Result 131:
# Type: [maintie_gold.Batteries], Label: ['1022_batteries'], Comment: ['replace inverter batteries']
#
# Result 132:
# Type: [maintie_gold.SignalLamp], Label: ['1023_signal_lamp'], Comment: ['replace left hand front signal lamp']
#
# Result 133:
# Type: [maintie_gold.ContaminationSwitch], Label: ['1024_contamination_switch'], Comment: ['replace left hand slew pump contamination switch']
#
# Result 134:
# Type: [maintie_gold.ElectricalIsolator], Label: ['1025_electrical_isolator'], Comment: ['replace main electrical isolator']
#
# Result 135:
# Type: [maintie_gold.MicrowaveOven], Label: ['1026_microwave_oven'], Comment: ['replace microwave oven <id>']
#
# Result 136:
# Type: [maintie_gold.ChipSensor], Label: ['1027_chip_sensor'], Comment: ['replace right hand swing pump chip sensor']
#
# Result 137:
# Type: [maintie_gold.ControlCable], Label: ['1028_control_cable'], Comment: ['replace seized air conditioner control cable']
#
# Result 138:
# Type: [maintie_gold.Diode], Label: ['1029_diode'], Comment: ['replace shorted diode RPC <num>']
#
# Result 139:
# Type: [maintie_gold.Covers], Label: ['1030_covers'], Comment: ['replace steering pilot valve covers']
#
# Result 140:
# Type: [maintie_gold.TravelWarningBeacon], Label: ['1031_travel_warning_beacon'], Comment: ['replace travel warning beacon']
#
# Result 141:
# Type: [maintie_gold.GreaseDistributor], Label: ['1032_grease_distributor'], Comment: ['replace unserviceable grease distributor']
#
# Result 142:
# Type: [maintie_gold.ChipIndicators], Label: ['1033_chip_indicators'], Comment: ['replace unserviceable chip indicators']
#
# Result 143:
# Type: [maintie_gold.IgnitionSwitch], Label: ['1034_ignition_switch'], Comment: ['replace unserviceable ignition switch']
#
# Result 144:
# Type: [maintie_gold.Screen], Label: ['1035_screen'], Comment: ['replace unserviceable transmission screen and magnet']
#
# Result 145:
# Type: [maintie_gold.Magnet], Label: ['1035_magnet'], Comment: ['replace unserviceable transmission screen and magnet']
#
# Result 146:
# Type: [maintie_gold.Boot], Label: ['1037_boot'], Comment: ['replace cyclone boot']
#
# Result 147:
# Type: [maintie_gold.HeadUnit], Label: ['1047_head_unit'], Comment: ['run new aerial and replace head unit']
#
# Result 148:
# Type: [maintie_gold.Oil], Label: ['1051_oil'], Comment: ['sample engine oil and replace oil and filter']
#
# Result 149:
# Type: [maintie_gold.Filter], Label: ['1051_filter'], Comment: ['sample engine oil and replace oil and filter']
#
# Result 150:
# Type: [maintie_gold.Computer], Label: ['1053_computer'], Comment: ['<id> replace computer']
#
# Result 151:
# Type: [maintie_gold.GroundFaultRelay], Label: ['1055_ground_fault_relay'], Comment: ['<id> replace ground fault relay']

# %% [markdown]
# **Are there any recurring issues with specific part across different machines?**
# - has_part / is_part_of

# %% [markdown]
# **Are there specific agents who frequently deal with certain types of maintenance issues?**
# - has_agent / is_agent_of

# %%
# TBD - Need finer-grained typing of agents to use the has_agent precisely here. Otherwise need to ensure that the predicate is a state, not a process as process can have agents that are machines/parts not people, etc.

# %% [markdown]
# **What objects or systems were affected by a specific maintenance activity?**
# - has_patient / is_patient_of

# %% [markdown]
# What maintenance activities have been performed on a specific machine or system?
# - has_patient / is_patient_of

# %% [markdown]
# Are there any patterns in the types of issues certain machines or systems are experiencing?
# - has_patient / is_patient_of

# %% [markdown]
# **What materials or substances are contained within a specific system or component?**
# - contains / is_contained_by

# %% [markdown]
# **Which systems or components contain a particular material or substance?**
# - contains / is_contained_by

# %% [markdown]
# **Are there maintenance issues related to containment, such as leaks or blockages?**
# - contains / is_contained_by

# %% [markdown]
# **What properties (like temperature, pressure, etc.) are associated with a particular physical object?**
# - has_property / is_property_of

# %% [markdown]
# **Which physical objects have a specific property, and what are their values?**
# - has_property / is_property_of

# %% [markdown]
# **Are there correlations between the properties of an object and the types of maintenance activities performed on it?**
# - has_property / is_property_of
